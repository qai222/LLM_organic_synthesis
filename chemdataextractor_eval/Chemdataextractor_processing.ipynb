# %%
import sys

# %%
#sys.path.append('Your path to LLM_organic_synthesis directory goes here, if needed to load ord_diff tools')

# %%
import json

import ord_schema
from ord_schema import message_helpers, validations
from ord_schema.proto import dataset_pb2

from google.protobuf.json_format import MessageToDict

from ord_diff.io import ModelOutput
from ord_diff.utils import json_load
from ord_diff.evaluation import get_compounds

from google.protobuf import json_format
from ord_schema.proto import reaction_pb2

# %% [markdown]
# ## Load LLM extractd output and define parsing logic

# %%
with open('../models_llama/adapter/finetune_20230731/infer-14.json', 'rt') as f:
    data = json.load(f)

# %%
def get_llm_compounds(record, prompt_template, prompt_header, response_header):
    """
    Parse ORD compounds from syntactically correct ORD reaction messages 

    :param record: individual record from LLM output file 
    :type record: dict
    :param prompt template: Full prompt template used
    :type prompt_template: str
    :param prompt_header: prompt template header
    :type prompt_header: str
    :param response_header: prompt respponse header
    :type response_header: str
    :return compounds_from_inputs: list of compounds identified as reactants/inputs
    :rtype compounds_from_inputs: list of ORD compounds, None if parsing error
    :return compounds_from_products: list of compounds identified from reaction products
    :rtype compounds_from_products: list of ORD compounds, None if parsing error
    """
    ref_string = record['output']
    raw = record['response']

    try:
        model_output = ModelOutput.from_raw_alpaca(
            raw=raw,
            ref=ref_string,
            identifier=record['reaction_id'],
            prompt_template=prompt_template,
            prompt_header=prompt_header,
            response_header=response_header,
            instruction=record['instruction'],
        )
    except:
        print(f'Parse error for reaction {record["reaction_id"]}')
        return None, None


    reference_message = json_format.Parse(model_output.ref, reaction_pb2.Reaction())
    # this would error out if inferred string (completion) is syntactically incorrect
    try:
        inferred_message = json_format.Parse(model_output.response, reaction_pb2.Reaction())
    except:
        #print('inferred message error')
        #print(record['reaction_id'])
        return None, None

    compounds_from_inputs = get_compounds(reference_message, extracted_from="inputs")
    compounds_from_outcomes = get_compounds(reference_message, extracted_from="outcomes")

    return compounds_from_inputs, compounds_from_outcomes

# %%
def parse_compound_name(compound):
    """
    Parse the string name from a single compound

    :param compound: chemical compound in ORD format
    :type compound: ORD compound
    :return name: name of compound
    :rtype name: str, None if parse error
    """
    comp_dict = MessageToDict(compound)
    try:
        return comp_dict['identifiers'][0]['value']
    except:
        return None

# %%
def get_llm_species(reaction, prompt_template, prompt_header, response_header):
    """
    Parse the chemical species extractd by LLM model from LLM output for a reaction

    :param reaction: individual record from LLM output file 
    :type reaction: dict
    :param prompt template: Full prompt template used
    :type prompt_template: str
    :param prompt_header: prompt template header
    :type prompt_header: str
    :param response_header: prompt respponse header
    :type response_header: str
    :return species: list of identified chemicals
    :rtype species: list of strings, 'FAILED' if parse error
    """
    compounds_in, compounds_out = get_llm_compounds(reaction, prompt_template, prompt_header, response_header)

    species = []
    if compounds_in is not None:
        for comp in compounds_in:
            species.append(parse_compound_name(comp))
    if compounds_out is not None:
        for comp in compounds_out:
            species.append(parse_compound_name(comp))

    if compounds_in is None:
        return 'FAILED'

    return species

# %% [markdown]
# ## Load chem data extractor output and define parsing logic
#
# This was generated sepearatly using script 'chemdataextract.py' b/c I couldn't get an environment set up with both CDE and jupyter. Follow instructions in readme.md to generate this file.

# %%
chemdata = []
with open('chemdataextractor_output.jsonl', 'rt') as f:
    for line in f:
        chemdata.append(json.loads(line))


chemdata_dict = {reaction['reaction_id']:reaction for reaction in chemdata}

# %%
def find_CDE_compounds(CDE_output):
    """find compounds identified by chem data extractor
    
    :param CDE_output: direct output from ChemDataExtractor
    :type CDE_output: dict 
    :return identified_species: list of identified chemicals
    :rtype identified_species: list of str
    """
    identified_species = []
    for item in CDE_output:
        if 'names' in item.keys():
            identified_species.append(item['names'][0])
    return identified_species

# %% [markdown]
# ## Parse identified species from both parsing methods

# %%
extracted_compounds = {reaction['reaction_id']:{} for reaction in data}

prompt_template = json_load("../../LLM_organic_synthesis/models_llama/adapter/USPTO-t900/params.json")['prompt_template']
prompt_header = prompt_template.split("\n")[0]
response_header = prompt_template.split("\n")[-2]

fail_count = 0

for reaction in data:

    rid = reaction['reaction_id']

    cde_reaction = chemdata_dict[rid]

    llm_species = get_llm_species(reaction, prompt_template, prompt_header, response_header)
    if llm_species =='FAILED':
        fail_count +=1
        continue
    cde_species = find_CDE_compounds(cde_reaction['chemdataextractor_output'])

    extracted_compounds[rid]['llm_species']= llm_species
    extracted_compounds[rid]['cde_species'] = cde_species

# %%
# dump results to file

data_as_ord_key = {record['reaction_id']:record for record in data}

for key, entry in extracted_compounds.items():
    instruction = data_as_ord_key[key]['instruction']
    entry['instruction'] = instruction


with open('extracted_compounds_infer_14.json', 'wt') as f:
    f.write(json.dumps(extracted_compounds))

# %%
print(f'Number of non-parsable LLM outputs: {fail_count}')
# Out:
# Number of non-parsable LLM outputs: 46

# %% [markdown]
# ## Compare extracted outputs and calculate metrics

# %%
def compare_outputs(LLM_species, cde_species):
    """
    Count overlap between LLM and chemdataextractor outputs
    """
    LLM_species = set(LLM_species)
    cde_species = set(cde_species)
    
    overlap_count = len(LLM_species.intersection(cde_species))
    
    llm_extras = LLM_species.difference(cde_species)
    cde_extras = cde_species.difference(LLM_species)
    
    llm_extras_count = len(llm_extras)
    cde_extras_count = len(cde_extras)
    
    return overlap_count, llm_extras_count, cde_extras_count, llm_extras, cde_extras

# %%
total_overlap_count = 0
llm_extra_count = 0
cde_extra_count = 0

llm_total_count = 0
cde_total_count = 0

llm_exclusive_finds = []
cde_exclusive_finds = []

for reaction_id, reaction in extracted_compounds.items():

    if len(reaction) == 0:
        continue
    cde_species = reaction['cde_species']
    LLM_species = reaction['llm_species']
    
    #cde_species = find_CDE_compounds(cde_entry['chemdataextractor_output'])
    #identified_species = []
    #LLM_species = find_ORD_compounds(json.loads(llm_entry['output']), identified_species)
    
    
    overlap_count, llm_count, cde_count, llm_extras, cde_extras = compare_outputs(LLM_species, cde_species)
    
    total_overlap_count += overlap_count
    llm_extra_count += llm_count
    cde_extra_count += cde_count

    llm_total_count += len(LLM_species)
    cde_total_count += len(cde_species)
    
    llm_exclusive_finds.extend(list(llm_extras))
    cde_exclusive_finds.extend(list(cde_extras))

# %%
print(f'Total number of species IDd by both methods: {total_overlap_count}')
print(f'Species IDd exclusively by LLM method: {llm_extra_count}')
print(f'Species IDd exclusively by CDE method: {cde_extra_count}')
print(f'Species IDd in total by LLM: {llm_total_count}')
print(f'Species IDd in total by CDE: {cde_total_count}')
# Out:
# Total number of species IDd by both methods: 5888
# Species IDd exclusively by LLM method: 2137
# Species IDd exclusively by CDE method: 2917
# Species IDd in total by LLM: 8122
# Species IDd in total by CDE: 8805

# %%
len(set(llm_exclusive_finds))
# Out:
# 795

# %%
len(set(cde_exclusive_finds))
# Out:
# 846

# %%
data
# Out:
# [{'reaction_id': 'ord-8b67d21803c44856af23b912ff922d7a',
#   'instruction': 'By a reaction under similar conditions as in Reference Example 234 and using 5-phenyl-1H-pyrrole-3-carbaldehyde (342 mg), sodium hydride (60% in oil, 120 mg), 15-crown-5 (0.60 mL) and 2-chloro-5-pyrimidinesulfonyl chloride (554 mg), the title compound was obtained as a yellow solid (yield 390 mg, 56%).',
#   'output': '{"inputs": {"m5": {"components": [{"identifiers": [{"type": "NAME", "value": "2-chloro-5-pyrimidinesulfonyl chloride"}], "amount": {"mass": {"value": 554.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}]}, "m2": {"components": [{"identifiers": [{"type": "NAME", "value": "5-phenyl-1H-pyrrole-3-carbaldehyde"}], "amount": {"mass": {"value": 342.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}]}, "m3": {"components": [{"identifiers": [{"type": "NAME", "value": "sodium hydride"}], "amount": {"mass": {"value": 120.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}]}, "m4": {"components": [{"identifiers": [{"type": "NAME", "value": "15-crown-5"}], "amount": {"volume": {"value": 0.6, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "title compound"}], "reactionRole": "PRODUCT"}, {"identifiers": [{"type": "NAME", "value": "solid"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 390.0, "units": "MILLIGRAM"}}}, {"type": "YIELD", "details": "PERCENTYIELD", "percentage": {"value": 56.0}}], "texture": {"type": "CUSTOM", "details": "solid"}, "reactionRole": "PRODUCT"}]}], "workups": [{"type": "CUSTOM"}]}',
#   'n_token_example': 651,
#   'response': '### Procedure:\nBy a reaction under similar conditions as in Reference Example 234 and using 5-phenyl-1H-pyrrole-3-carbaldehyde (342 mg), sodium hydride (60% in oil, 120 mg), 15-crown-5 (0.60 mL) and 2-chloro-5-pyrimidinesulfonyl chloride (554 mg), the title compound was obtained as a yellow solid (yield 390 mg, 56%).\n\n### ORD-JSON:\n{"inputs": {"m3": {"components": [{"identifiers": [{"type": "NAME", "value": "15-crown-5"}], "amount": {"volume": {"value": 0.6, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}]}, "m1": {"components": [{"identifiers": [{"type": "NAME", "value": "5-phenyl-1H-pyrrole-3-carbaldehyde"}], "amount": {"mass": {"value": 342.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}]}, "m2": {"components": [{"identifiers": [{"type": "NAME", "value": "sodium hydride"}], "amount": {"mass": {"value": 120.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}]}, "m4": {"components": [{"identifiers": [{"type": "NAME", "value": "2-chloro-5-pyrimidinesulfonyl chloride"}], "amount": {"mass": {"value": 554.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "title compound"}], "reactionRole": "PRODUCT"}, {"identifiers": [{"type": "NAME", "value": "solid"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 390.0, "units": "MILLIGRAM"}}}, {"type": "YIELD", "details": "PERCENTYIELD", "percentage": {"value": 56.0}}], "texture": {"type": "CUSTOM", "details": "solid"}, "reactionRole": "PRODUCT"}]}], "workups": []}'},
#  {'reaction_id': 'ord-129e3181c9dd475fb3ca577cd8857a22',
#   'instruction': '100 mg (0.278 mmol) of 2-chloro-4-(4-{[(2S)-2,3-dihydroxypropyl]oxy}phenyl)-6-methoxypyridine-3,5-dicarbonitrile are initially charged in 5 ml of DMF, 26 mg (0.334 mmol) of sodium sulphide are added and the mixture is stirred at room temperature for 4 hours. The reaction mixture is reacted further without any further purification.',
#   'output': '{"inputs": {"m1_m3": {"components": [{"identifiers": [{"type": "NAME", "value": "2-chloro-4-(4-{[(2S)-2,3-dihydroxypropyl]oxy}phenyl)-6-methoxypyridine-3,5-dicarbonitrile"}], "amount": {"mass": {"value": 100.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "DMF"}], "amount": {"volume": {"value": 5.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}, "m2": {"components": [{"identifiers": [{"type": "NAME", "value": "sodium sulphide"}], "amount": {"mass": {"value": 26.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}]}}, "conditions": {"temperature": {"control": {"type": "AMBIENT"}}, "stirring": {"type": "CUSTOM", "details": "the mixture is stirred at room temperature for 4 hours"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 4.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "4-(4-{[(2S)-2,3-Dihydroxypropyl]oxy}phenyl)-2-methoxy-6-sulphanylpyridine-3,5-dicarbonitrile"}]}]}], "workups": [{"type": "CUSTOM"}]}',
#   'n_token_example': 571,
#   'response': '### Procedure:\n100 mg (0.278 mmol) of 2-chloro-4-(4-{[(2S)-2,3-dihydroxypropyl]oxy}phenyl)-6-methoxypyridine-3,5-dicarbonitrile are initially charged in 5 ml of DMF, 26 mg (0.334 mmol) of sodium sulphide are added and the mixture is stirred at room temperature for 4 hours. The reaction mixture is reacted further without any further purification.\n\n### ORD-JSON:\n{"inputs": {"m1_m3": {"components": [{"identifiers": [{"type": "NAME", "value": "2-chloro-4-(4-{[(2S)-2,3-dihydroxypropyl]oxy}phenyl)-6-methoxypyridine-3,5-dicarbonitrile"}], "amount": {"mass": {"value": 100.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "DMF"}], "amount": {"volume": {"value": 5.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}, "m2": {"components": [{"identifiers": [{"type": "NAME", "value": "sodium sulphide"}], "amount": {"mass": {"value": 26.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}]}}, "conditions": {"temperature": {"control": {"type": "AMBIENT"}}, "stirring": {"type": "CUSTOM", "details": "the mixture is stirred at room temperature for 4 hours"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 4.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "2-chloro-4-(4-{[(2S)-2,3-dihydroxypropyl]oxy}phenyl)-6-methoxy-3,5-pyridine-2,4-dicarbonitrile"}]}]}], "workups": [{"type": "CUSTOM"}]}'},
#  {'reaction_id': 'ord-992026e2505c42178351aaf4efeb7ae2',
#   'instruction': 'In a similar manner to Example 2, 1.28 g (9 mmol) of anisaldehyde, 1.89 g (9 mmol) of 4-carboxybenzenesulfonamide and 20 mg of TsOH in 150 mL of chlorobenzene and under nitrogen were heated for 4.5 hours to yield 2.86 g (96%) of SULF-8 as a white powder: IR (Nujol) 3300-2700 (br), 1693, 1601, 1584, 1155 cm-1 ; 1H NMR (DMSO-d6, TMS ext std)δ 8.91 (s, 1), 8.4-7.7 (m, 8), 3.92 (s, 3).',
#   'output': '{"inputs": {"m1_m2_m3_m4": {"components": [{"identifiers": [{"type": "NAME", "value": "anisaldehyde"}], "amount": {"mass": {"value": 1.28, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "4-carboxybenzenesulfonamide"}], "amount": {"mass": {"value": 1.89, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "TsOH"}], "amount": {"mass": {"value": 20.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "chlorobenzene"}], "amount": {"volume": {"value": 150.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "N-(4-Methoxybenzylidene)-4-carboxybenzenesulfonamide"}]}]}], "workups": [{"type": "CUSTOM"}]}',
#   'n_token_example': 573,
#   'response': '### Procedure:\nIn a similar manner to Example 2, 1.28 g (9 mmol) of anisaldehyde, 1.89 g (9 mmol) of 4-carboxybenzenesulfonamide and 20 mg of TsOH in 150 mL of chlorobenzene and under nitrogen were heated for 4.5 hours to yield 2.86 g (96%) of SULF-8 as a white powder: IR (Nujol) 3300-2700 (br), 1693, 1601, 1584, 1155 cm-1 ; 1H NMR (DMSO-d6, TMS ext std)δ 8.91 (s, 1), 8.4-7.7 (m, 8), 3.92 (s, 3).\n\n### ORD-JSON:\n{"inputs": {"m1_m2_m3_m4": {"components": [{"identifiers": [{"type": "NAME", "value": "anisaldehyde"}], "amount": {"mass": {"value": 1.28, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "4-carboxybenzenesulfonamide"}], "amount": {"mass": {"value": 1.89, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "TsOH"}], "amount": {"mass": {"value": 20.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "chlorobenzene"}], "amount": {"volume": {"value": 150.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "SULF-8"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 2.86, "units": "GRAM"}}}, {"type": "YIELD", "details": "PERCENTYIELD", "percentage": {"value": 96.0}}, {"type": "YIELD", "details": "CALCULATEDPERCENTYIELD", "percentage": {"value": 96.1}}], "isolatedColor": "white", "texture": {"type": "POWDER", "details": "powder"}, "reactionRole": "PRODUCT"}]}], "workups": []}'},
#  {'reaction_id': 'ord-cc62cc7f843041a68530c3cb37189044',
#   'instruction': 'To a solution of 3-(1-{[3-(dimethylamino)propyl]sulfonyl}-4-piperidinyl)-5-[3-(hydroxymethyl)phenyl]-1H-indole-7-carboxamide (230 mg, 0.47 mmol) in THF (60 mL) was added MnO2 (1.3 g, 14.05 mmol). The reaction mixture was stirred at room temperature overnight and filtered through a pad of celite after that. The filtrate was collected and concentrated at reduced pressure to give the crude product (150 mg, 65%), which was used in the next step without further purification.',
#   'output': '{"inputs": {"m1_m2_m3": {"components": [{"identifiers": [{"type": "NAME", "value": "3-(1-{[3-(dimethylamino)propyl]sulfonyl}-4-piperidinyl)-5-[3-(hydroxymethyl)phenyl]-1H-indole-7-carboxamide"}], "amount": {"mass": {"value": 230.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "THF"}], "amount": {"volume": {"value": 60.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}, {"identifiers": [{"type": "NAME", "value": "MnO2"}], "amount": {"mass": {"value": 1.3, "units": "GRAM"}}, "reactionRole": "CATALYST"}]}}, "conditions": {"temperature": {"control": {"type": "AMBIENT"}}, "stirring": {"type": "CUSTOM", "details": "The reaction mixture was stirred at room temperature overnight"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 8.0, "precision": 8.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "crude product"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 150.0, "units": "MILLIGRAM"}}}, {"type": "YIELD", "details": "PERCENTYIELD", "percentage": {"value": 65.0}}, {"type": "YIELD", "details": "CALCULATEDPERCENTYIELD", "percentage": {"value": 64.3}}], "reactionRole": "PRODUCT"}]}], "workups": [{"type": "FILTRATION"}, {"type": "CUSTOM"}, {"type": "CONCENTRATION"}]}',
#   'n_token_example': 716,
#   'response': '### Procedure:\nTo a solution of 3-(1-{[3-(dimethylamino)propyl]sulfonyl}-4-piperidinyl)-5-[3-(hydroxymethyl)phenyl]-1H-indole-7-carboxamide (230 mg, 0.47 mmol) in THF (60 mL) was added MnO2 (1.3 g, 14.05 mmol). The reaction mixture was stirred at room temperature overnight and filtered through a pad of celite after that. The filtrate was collected and concentrated at reduced pressure to give the crude product (150 mg, 65%), which was used in the next step without further purification.\n\n### ORD-JSON:\n{"inputs": {"m1_m3_m2": {"components": [{"identifiers": [{"type": "NAME", "value": "3-(1-{[3-(dimethylamino)propyl]sulfonyl}-4-piperidinyl)-5-[3-(hydroxymethyl)phenyl]-1H-indole-7-carboxamide"}], "amount": {"mass": {"value": 230.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "MnO2"}], "amount": {"mass": {"value": 1.3, "units": "GRAM"}}, "reactionRole": "CATALYST"}, {"identifiers": [{"type": "NAME", "value": "THF"}], "amount": {"volume": {"value": 60.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"temperature": {"control": {"type": "AMBIENT"}}, "stirring": {"type": "CUSTOM", "details": "The reaction mixture was stirred at room temperature overnight"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 8.0, "precision": 8.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "crude product"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 150.0, "units": "MILLIGRAM"}}}, {"type": "YIELD", "details": "PERCENTYIELD", "percentage": {"value": 65.0}}, {"type": "YIELD", "details": "CALCULATEDPERCENTYIELD", "percentage": {"value": 64.9}}], "reactionRole": "PRODUCT"}]}], "workups": [{"type": "FILTRATION"}, {"type": "CUSTOM"}, {"type": "CONCENTRATION"}]}'},
#  {'reaction_id': 'ord-c2acd820ffd54eacaa4cb46ff16afa6d',
#   'instruction': 'By an operation in the same manner as in Reference Example 3 and using cerium chloride (9.25 g), 3 mol/L ethylmagnesium bromide-diethyl ether solution (11.0 mL) and benzyl (2S)-2-isopropyl-3-oxopyrrolidine-1-carboxylate (3.92 g), the title compound was obtained as colorless oil (yield: 2.21 g, yield: 51%).',
#   'output': '{"inputs": {"m2": {"components": [{"identifiers": [{"type": "NAME", "value": "cerium chloride"}], "amount": {"mass": {"value": 9.25, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}, "m3": {"components": [{"identifiers": [{"type": "NAME", "value": "ethylmagnesium bromide diethyl ether"}], "amount": {"volume": {"value": 11.0, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}]}, "m4": {"components": [{"identifiers": [{"type": "NAME", "value": "benzyl (2S)-2-isopropyl-3-oxopyrrolidine-1-carboxylate"}], "amount": {"mass": {"value": 3.92, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "title compound"}], "reactionRole": "PRODUCT"}, {"identifiers": [{"type": "NAME", "value": "oil"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 2.21, "units": "GRAM"}}}, {"type": "YIELD", "details": "PERCENTYIELD", "percentage": {"value": 51.0}}], "texture": {"type": "OIL", "details": "oil"}, "reactionRole": "PRODUCT"}]}], "workups": []}',
#   'n_token_example': 560,
#   'response': '### Procedure:\nBy an operation in the same manner as in Reference Example 3 and using cerium chloride (9.25 g), 3 mol/L ethylmagnesium bromide-diethyl ether solution (11.0 mL) and benzyl (2S)-2-isopropyl-3-oxopyrrolidine-1-carboxylate (3.92 g), the title compound was obtained as colorless oil (yield: 2.21 g, yield: 51%).\n\n### ORD-JSON:\n{"inputs": {"m3": {"components": [{"identifiers": [{"type": "NAME", "value": "benzyl (2S)-2-isopropyl-3-oxopyrrolidine-1-carboxylate"}], "amount": {"mass": {"value": 3.92, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}, "m2": {"components": [{"identifiers": [{"type": "NAME", "value": "ethylmagnesium bromide-diethyl ether"}], "amount": {"volume": {"value": 11.0, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}]}, "m1": {"components": [{"identifiers": [{"type": "NAME", "value": "cerium chloride"}], "amount": {"mass": {"value": 9.25, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "title compound"}], "reactionRole": "PRODUCT"}]}], "workups": []}'},
#  {'reaction_id': 'ord-cbe0ef10e0b04e598fcef528b5c542e4',
#   'instruction': 'A solution of 4-bromo-3-fluoroaniline (56.6 g, 297.87 mmol) and 1,3-diethyl 2-(ethoxymethylidene)propanedioate (72.45 g, 335.06 mmol) in EtOH (560 mL) was stirred at 80° C. for 4 h. The reaction mixture was allowed to cool, the solids collected by filtration and dried in an oven to afford the desired material (90 g, 84%) as an off-white solid which was used without further purification. NMR Spectrum: 1H NMR (400 MHz, DMSO-d6) δ 1.26 (6H, q), 4.14 (2H, q), 4.22 (2H, q), 7.18-7.25 (1H, m), 7.57 (1H, dd), 7.64-7.7 (1H, m), 8.33 (1H, d), 10.62 (1H, d). Mass Spectrum: m/z (ES+)[M+H]+=360.',
#   'output': '{"inputs": {"m1_m2_m3": {"components": [{"identifiers": [{"type": "NAME", "value": "4-bromo-3-fluoroaniline"}], "amount": {"mass": {"value": 56.6, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "1,3-diethyl 2-(ethoxymethylidene)propanedioate"}], "amount": {"mass": {"value": 72.45, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "EtOH"}], "amount": {"volume": {"value": 560.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "desired material"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 90.0, "units": "GRAM"}}}, {"type": "YIELD", "details": "PERCENTYIELD", "percentage": {"value": 84.0}}, {"type": "YIELD", "details": "CALCULATEDPERCENTYIELD", "percentage": {"value": 83.9}}], "isolatedColor": "off-white", "texture": {"type": "CUSTOM", "details": "solid"}, "reactionRole": "PRODUCT"}]}], "workups": [{"type": "TEMPERATURE"}, {"type": "FILTRATION"}, {"type": "CUSTOM"}]}',
#   'n_token_example': 766,
#   'response': '### Procedure:\nA solution of 4-bromo-3-fluoroaniline (56.6 g, 297.87 mmol) and 1,3-diethyl 2-(ethoxymethylidene)propanedioate (72.45 g, 335.06 mmol) in EtOH (560 mL) was stirred at 80° C. for 4 h. The reaction mixture was allowed to cool, the solids collected by filtration and dried in an oven to afford the desired material (90 g, 84%) as an off-white solid which was used without further purification. NMR Spectrum: 1H NMR (400 MHz, DMSO-d6) δ 1.26 (6H, q), 4.14 (2H, q), 4.22 (2H, q), 7.18-7.25 (1H, m), 7.57 (1H, dd), 7.64-7.7 (1H, m), 8.33 (1H, d), 10.62 (1H, d). Mass Spectrum: m/z (ES+)[M+H]+=360.\n\n### ORD-JSON:\n{"inputs": {"m1_m2_m3": {"components": [{"identifiers": [{"type": "NAME", "value": "4-bromo-3-fluoroaniline"}], "amount": {"mass": {"value": 56.6, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "1,3-diethyl 2-(ethoxymethylidene)propanedioate"}], "amount": {"mass": {"value": 72.45, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "EtOH"}], "amount": {"volume": {"value": 560.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "desired material"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 90.0, "units": "GRAM"}}}, {"type": "YIELD", "details": "PERCENTYIELD", "percentage": {"value": 84.0}}, {"type": "YIELD", "details": "CALCULATEDPERCENTYIELD", "percentage": {"value": 83.9}}], "isolatedColor": "off-white", "texture": {"type": "CUSTOM", "details": "solid"}, "reactionRole": "PRODUCT"}]}], "workups": [{"type": "TEMPERATURE"}, {"type": "CUSTOM"}, {"type": "FILTRATION"}, {"type": "CUSTOM"}]}'},
#  {'reaction_id': 'ord-386ae454bbe0448da0a6ac1ab187c8b2',
#   'instruction': 'N-(4-(3-tert-Butoxycarbonylaminomethylpyrrolidin-1-yl)butyl)-1-methyl-1 H-indole-3-carboxamide (1.00 g) as starting compound was reacted and treated in the same manner as in Example 67 using 4-amino-5-chloro-2-cyclopropylmethyloxybenzoic acid (0.56 g) to give N-(4-(3-(4-amino-5-chloro-2-cyclopropylmethyloxybenzoylaminomethyl)-pyrrolidin-1-yl)butyl)-1-methyl-1 H-indole-3-carboxamide.',
#   'output': '{"inputs": {"m2": {"components": [{"identifiers": [{"type": "NAME", "value": "4-amino-5-chloro-2-cyclopropylmethyloxybenzoic acid"}], "amount": {"mass": {"value": 0.56, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}, "m1": {"components": [{"identifiers": [{"type": "NAME", "value": "N-(4-(3-tert-Butoxycarbonylaminomethylpyrrolidin-1-yl)butyl)-1-methyl-1 H-indole-3-carboxamide"}], "amount": {"mass": {"value": 1.0, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "N-(4-(3-(4-amino-5-chloro-2-cyclopropylmethyloxybenzoylaminomethyl)-pyrrolidin-1-yl)butyl)-1-methyl-1 H-indole-3-carboxamide"}], "reactionRole": "PRODUCT"}]}], "workups": [{"type": "CUSTOM"}]}',
#   'n_token_example': 534,
#   'response': '### Procedure:\nN-(4-(3-tert-Butoxycarbonylaminomethylpyrrolidin-1-yl)butyl)-1-methyl-1 H-indole-3-carboxamide (1.00 g) as starting compound was reacted and treated in the same manner as in Example 67 using 4-amino-5-chloro-2-cyclopropylmethyloxybenzoic acid (0.56 g) to give N-(4-(3-(4-amino-5-chloro-2-cyclopropylmethyloxybenzoylaminomethyl)-pyrrolidin-1-yl)butyl)-1-methyl-1 H-indole-3-carboxamide.\n\n### ORD-JSON:\n{"inputs": {"m2": {"components": [{"identifiers": [{"type": "NAME", "value": "4-amino-5-chloro-2-cyclopropylmethyloxybenzoic acid"}], "amount": {"mass": {"value": 0.56, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}, "m1": {"components": [{"identifiers": [{"type": "NAME", "value": "N-(4-(3-tert-Butoxycarbonylaminomethylpyrrolidin-1-yl)butyl)-1-methyl-1 H-indole-3-carboxamide"}], "amount": {"mass": {"value": 1.0, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "N-(4-(3-(4-amino-5-chloro-2-cyclopropylmethyloxybenzoylaminomethyl)-pyrrolidin-1-yl)butyl)-1-methyl-1 H-indole-3-carboxamide"}], "reactionRole": "PRODUCT"}]}], "workups": [{"type": "CUSTOM"}]}'},
#  {'reaction_id': 'ord-9628d5710f6c4dad817942011a70d16b',
#   'instruction': 'A solution of {(S)-2-[(S)-2-(2-benzoimidazol-1-yl-pyridin-4-yl)-pyrrolidin-1-yl]-1-cyclohexyl-2-oxo-ethyl}-carbamic acid tert-butyl ester (70 mg, 0.14 mmol) in DCM (2 mL) is added TFA (2 mL). After stirring at room temperature for 1 h, the reaction mixture is concentrated down to give crude (S)-2-Amino-1-[(S)-2-(2-benzoimidazol-1-yl-pyridin-4-yl)-pyrrolidin-1-yl]-2-cyclohexyl-ethanone, which is used in next step without further purification.',
#   'output': '{"inputs": {"m1_m3_m2": {"components": [{"identifiers": [{"type": "NAME", "value": "{(S)-2-[(S)-2-(2-benzoimidazol-1-yl-pyridin-4-yl)-pyrrolidin-1-yl]-1-cyclohexyl-2-oxo-ethyl}-carbamic acid tert-butyl ester"}], "amount": {"mass": {"value": 70.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "TFA"}], "amount": {"volume": {"value": 2.0, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "DCM"}], "amount": {"volume": {"value": 2.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"temperature": {"control": {"type": "AMBIENT"}}, "stirring": {"type": "CUSTOM", "details": "After stirring at room temperature for 1 h"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 1.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "(S)-2-Amino-1-[(S)-2-(2-benzoimidazol-1-yl-pyridin-4-yl)-pyrrolidin-1-yl]-2-cyclohexyl-ethanone"}], "reactionRole": "PRODUCT"}]}], "workups": [{"type": "CONCENTRATION"}]}',
#   'n_token_example': 656,
#   'response': '### Procedure:\nA solution of {(S)-2-[(S)-2-(2-benzoimidazol-1-yl-pyridin-4-yl)-pyrrolidin-1-yl]-1-cyclohexyl-2-oxo-ethyl}-carbamic acid tert-butyl ester (70 mg, 0.14 mmol) in DCM (2 mL) is added TFA (2 mL). After stirring at room temperature for 1 h, the reaction mixture is concentrated down to give crude (S)-2-Amino-1-[(S)-2-(2-benzoimidazol-1-yl-pyridin-4-yl)-pyrrolidin-1-yl]-2-cyclohexyl-ethanone, which is used in next step without further purification.\n\n### ORD-JSON:\n{"inputs": {"m1_m3_m2": {"components": [{"identifiers": [{"type": "NAME", "value": "{(S)-2-[(S)-2-(2-benzoimidazol-1-yl-pyridin-4-yl)-pyrrolidin-1-yl]-1-cyclohexyl-2-oxo-ethyl}-carbamic acid tert-butyl ester"}], "amount": {"mass": {"value": 70.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "TFA"}], "amount": {"volume": {"value": 2.0, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "DCM"}], "amount": {"volume": {"value": 2.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"temperature": {"control": {"type": "AMBIENT"}}, "stirring": {"type": "CUSTOM", "details": "After stirring at room temperature for 1 h"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 1.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "(S)-2-Amino-1-[(S)-2-(2-benzoimidazol-1-yl-pyridin-4-yl)-pyrrolidin-1-yl]-2-cyclohexyl-ethanone"}], "reactionRole": "PRODUCT"}]}], "workups": [{"type": "CONCENTRATION"}]}'},
#  {'reaction_id': 'ord-d3403ec324124f6ebcef953fdb93a990',
#   'instruction': 'Using trans-4-hydroxycyclohexane carboxylic acid (1.01 g, 7 mmol) and (R)-2-n-hexyloxypropanoyl chloride (1.35 g, 7 mmol), the reaction was carried out in the same manner as described in Example 4, (1), to give the title compound as a pale yellow oil; yield: 750 mg.',
#   'output': '{"inputs": {"m2": {"components": [{"identifiers": [{"type": "NAME", "value": "(R)-2-n-hexyloxypropanoyl chloride"}], "amount": {"mass": {"value": 1.35, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}, "m1": {"components": [{"identifiers": [{"type": "NAME", "value": "trans-4-hydroxycyclohexane carboxylic acid"}], "amount": {"mass": {"value": 1.01, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "title compound"}], "isolatedColor": "pale yellow", "texture": {"type": "OIL", "details": "oil"}, "reactionRole": "PRODUCT"}]}], "workups": []}',
#   'n_token_example': 363,
#   'response': '### Procedure:\nUsing trans-4-hydroxycyclohexane carboxylic acid (1.01 g, 7 mmol) and (R)-2-n-hexyloxypropanoyl chloride (1.35 g, 7 mmol), the reaction was carried out in the same manner as described in Example 4, (1), to give the title compound as a pale yellow oil; yield: 750 mg.\n\n### ORD-JSON:\n{"inputs": {"m1": {"components": [{"identifiers": [{"type": "NAME", "value": "trans-4-hydroxycyclohexane carboxylic acid"}], "amount": {"mass": {"value": 1.01, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}, "m2": {"components": [{"identifiers": [{"type": "NAME", "value": "(R)-2-n-hexyloxypropanoyl chloride"}], "amount": {"mass": {"value": 1.35, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "title compound"}], "isolatedColor": "pale yellow", "texture": {"type": "OIL", "details": "oil"}, "reactionRole": "PRODUCT"}]}], "workups": []}'},
#  {'reaction_id': 'ord-4e77cea7017d447caa39a60511a8276c',
#   'instruction': 'A mixture of 3.6 g 2-amino-nicotinic acid in 450 mL of glacial acetic acid was treated with a solution of 4 mL of bromine in 50 mL of glacial acetic acid over 10-15 min. The resulting mixture was stirred at room temperature for 2 h, diluted with 2 L of diethyl ether, and the ensuing precipitate was filtered and dried to provide 6.1 g of the title compound of Step A as a solid melting at 280° C. (decompose) (lit1. m.p. 280° C., decomposed). 1H NMR (400 MHz, Me2SO-d6): δ 7.38 (br s,2H), 8.08 (s,1H), 8.25 (s,1H), 13.45 (br s,1H). (1 U.S. Pat. No. 3,950,160)',
#   'output': '{"inputs": {"m5": {"components": [{"identifiers": [{"type": "NAME", "value": "diethyl ether"}], "amount": {"volume": {"value": 2.0, "units": "LITER"}}, "reactionRole": "SOLVENT"}]}, "m1_m3": {"components": [{"identifiers": [{"type": "NAME", "value": "2-amino-nicotinic acid"}], "amount": {"mass": {"value": 3.6, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "acetic acid"}], "amount": {"volume": {"value": 450.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}, "m2_m4": {"components": [{"identifiers": [{"type": "NAME", "value": "bromine"}], "amount": {"volume": {"value": 4.0, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "acetic acid"}], "amount": {"volume": {"value": 50.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"temperature": {"control": {"type": "AMBIENT"}}, "stirring": {"type": "CUSTOM", "details": "The resulting mixture was stirred at room temperature for 2 h"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 2.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "title compound"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 6.1, "units": "GRAM"}}}], "texture": {"type": "CUSTOM", "details": "solid"}, "reactionRole": "PRODUCT"}]}], "workups": [{"type": "FILTRATION"}, {"type": "CUSTOM"}]}',
#   'n_token_example': 801,
#   'response': '### Procedure:\nA mixture of 3.6 g 2-amino-nicotinic acid in 450 mL of glacial acetic acid was treated with a solution of 4 mL of bromine in 50 mL of glacial acetic acid over 10-15 min. The resulting mixture was stirred at room temperature for 2 h, diluted with 2 L of diethyl ether, and the ensuing precipitate was filtered and dried to provide 6.1 g of the title compound of Step A as a solid melting at 280° C. (decompose) (lit1. m.p. 280° C., decomposed). 1H NMR (400 MHz, Me2SO-d6): δ 7.38 (br s,2H), 8.08 (s,1H), 8.25 (s,1H), 13.45 (br s,1H). (1 U.S. Pat. No. 3,950,160)\n\n### ORD-JSON:\n{"inputs": {"m1_m3_m2": {"components": [{"identifiers": [{"type": "NAME", "value": "2-amino-nicotinic acid"}], "amount": {"mass": {"value": 3.6, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "bromine"}], "amount": {"volume": {"value": 4.0, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "acetic acid"}], "amount": {"volume": {"value": 450.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"temperature": {"control": {"type": "AMBIENT"}}, "stirring": {"type": "CUSTOM", "details": "The resulting mixture was stirred at room temperature for 2 h"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 2.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "title compound"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 6.1, "units": "GRAM"}}}, {"type": "YIELD", "details": "CALCULATEDPERCENTYIELD", "percentage": {"value": 100.0}}], "reactionRole": "PRODUCT"}]}], "workups": [{"type": "ADDITION", "input": {"components": [{"identifiers": [{"type": "NAME", "value": "diethyl ether"}], "amount": {"volume": {"value": 2.0, "units": "LITER"}}, "reactionRole": "WORKUP"}]}}, {"type": "FILTRATION"}, {"type": "CUSTOM"}]}'},
#  {'reaction_id': 'ord-c07e86bf39de478ca7a81d6dc5d44939',
#   'instruction': 'A mixture of the above-mentioned 1-chloro-2-methyl-3-methoxycarbonylaminobenzene 5.80 g, phosphorus pentachloride 7.53 g and chlorobenzene 50 mL was stirred with heating under reflux for one hour. The reaction mixtures were concentrated under reduced pressure to give 1-chloro-3-isocyanato-2-methylbenzene.',
#   'output': '{"inputs": {"m1_m2_m3": {"components": [{"identifiers": [{"type": "NAME", "value": "1-chloro-2-methyl-3-methoxycarbonylaminobenzene"}], "amount": {"mass": {"value": 5.8, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "phosphorus pentachloride"}], "amount": {"mass": {"value": 7.53, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "chlorobenzene"}], "amount": {"volume": {"value": 50.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"stirring": {"type": "CUSTOM", "details": "was stirred"}, "conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "1-chloro-3-isocyanato-2-methylbenzene"}], "reactionRole": "PRODUCT"}]}], "workups": [{"type": "TEMPERATURE"}, {"type": "TEMPERATURE", "duration": {"value": 1.0, "units": "HOUR"}}, {"type": "CUSTOM"}, {"type": "CONCENTRATION"}]}',
#   'n_token_example': 505,
#   'response': '### Procedure:\nA mixture of the above-mentioned 1-chloro-2-methyl-3-methoxycarbonylaminobenzene 5.80 g, phosphorus pentachloride 7.53 g and chlorobenzene 50 mL was stirred with heating under reflux for one hour. The reaction mixtures were concentrated under reduced pressure to give 1-chloro-3-isocyanato-2-methylbenzene.\n\n### ORD-JSON:\n{"inputs": {"m1_m2_m3": {"components": [{"identifiers": [{"type": "NAME", "value": "1-chloro-2-methyl-3-methoxycarbonylaminobenzene"}], "amount": {"mass": {"value": 5.8, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "phosphorus pentachloride"}], "amount": {"mass": {"value": 7.53, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "chlorobenzene"}], "amount": {"volume": {"value": 50.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"stirring": {"type": "CUSTOM", "details": "was stirred"}, "conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "1-chloro-3-isocyanato-2-methylbenzene"}], "reactionRole": "PRODUCT"}]}], "workups": [{"type": "TEMPERATURE", "duration": {"value": 1.0, "units": "HOUR"}}, {"type": "CONCENTRATION"}]}'},
#  {'reaction_id': 'ord-4650afab87024b47ad22984617ce22c4',
#   'instruction': 'Trimethylsilylbromide (15 ml., 0.1 mole) is added portionwise to methylphenyl phosphinic acid, phenethyl ester (15.2 g.,0.1 mole) at a rate to maintain reflux temperature. Following the addition, the mixture is stirred one hour at ambient temperature. The volatiles are removed in vacuo. The addition of water (10 ml.) to the liquid residue (20.6 g.) results in the separation of a white solid. The mixture is stirred at ambient temperature overnight, followed by filtration, with a recovery of 14 g. of solid. It is recrystallized from dichloromethane (80 ml.) to give methylphenylphosphinic acid, 9.9 g. (72%), m.p. 133°-135°.',
#   'output': '{"inputs": {"m1_m2": {"components": [{"identifiers": [{"type": "NAME", "value": "Trimethylsilylbromide"}], "amount": {"volume": {"value": 15.0, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "methylphenyl phosphinic acid, phenethyl ester"}], "amount": {"mass": {"value": 15.2, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}}, "conditions": {"temperature": {"control": {"type": "AMBIENT"}}, "stirring": {"type": "CUSTOM", "details": "the mixture is stirred one hour at ambient temperature"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 1.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "methylphenylphosphinic acid"}], "reactionRole": "PRODUCT"}]}], "workups": [{"type": "TEMPERATURE"}, {"type": "TEMPERATURE"}, {"type": "ADDITION"}, {"type": "CUSTOM"}, {"type": "ADDITION", "input": {"components": [{"identifiers": [{"type": "NAME", "value": "water"}], "amount": {"volume": {"value": 10.0, "units": "MILLILITER"}}, "reactionRole": "WORKUP"}]}}, {"type": "CUSTOM"}, {"type": "STIRRING", "duration": {"value": 8.0, "precision": 8.0, "units": "HOUR"}, "temperature": {"control": {"type": "AMBIENT"}}}, {"type": "FILTRATION"}, {"type": "CUSTOM", "input": {"components": [{"identifiers": [{"type": "NAME", "value": "dichloromethane"}], "amount": {"volume": {"value": 80.0, "units": "MILLILITER"}}, "reactionRole": "WORKUP"}]}}]}',
#   'n_token_example': 757,
#   'response': '### Procedure:\nTrimethylsilylbromide (15 ml., 0.1 mole) is added portionwise to methylphenyl phosphinic acid, phenethyl ester (15.2 g.,0.1 mole) at a rate to maintain reflux temperature. Following the addition, the mixture is stirred one hour at ambient temperature. The volatiles are removed in vacuo. The addition of water (10 ml.) to the liquid residue (20.6 g.) results in the separation of a white solid. The mixture is stirred at ambient temperature overnight, followed by filtration, with a recovery of 14 g. of solid. It is recrystallized from dichloromethane (80 ml.) to give methylphenylphosphinic acid, 9.9 g. (72%), m.p. 133°-135°.\n\n### ORD-JSON:\n{"inputs": {"m1_m2": {"components": [{"identifiers": [{"type": "NAME", "value": "Trimethylsilylbromide"}], "amount": {"volume": {"value": 15.0, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "methylphenyl phosphinic acid, phenethyl ester"}], "amount": {"mass": {"value": 15.2, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}}, "conditions": {"temperature": {"control": {"type": "AMBIENT"}}, "stirring": {"type": "CUSTOM", "details": "the mixture is stirred one hour at ambient temperature"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 1.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "methylphenylphosphinic acid"}], "reactionRole": "PRODUCT"}]}], "workups": [{"type": "ADDITION"}, {"type": "CUSTOM"}, {"type": "CUSTOM"}, {"type": "ADDITION", "input": {"components": [{"identifiers": [{"type": "NAME", "value": "water"}], "amount": {"volume": {"value": 10.0, "units": "MILLILITER"}}, "reactionRole": "WORKUP"}]}}, {"type": "STIRRING", "duration": {"value": 8.0, "precision": 8.0, "units": "HOUR"}, "temperature": {"control": {"type": "AMBIENT"}}}, {"type": "FILTRATION"}, {"type": "CUSTOM"}, {"type": "CUSTOM", "input": {"components": [{"identifiers": [{"type": "NAME", "value": "dichloromethane"}], "amount": {"volume": {"value": 80.0, "units": "MILLILITER"}}, "reactionRole": "WORKUP"}]}}]}'},
#  {'reaction_id': 'ord-68fb223505b5424594055f26c1c2e670',
#   'instruction': 'A solution of 15 ml of benzylamine in 20 ml of tetrahydrofuran was reacted with a solution of 8.0 g of o-iodobenzoyl chloride in 20 ml of tetrahydrofuran in accordance with the procedure of Example 3. There was obtained by recrystallization from benzene 9.1 g of N-benzyl-o-iodobenzamide, m.p. 122°-123°, Rf 0.78.',
#   'output': '{"inputs": {"m3_m0": {"components": [{"identifiers": [{"type": "NAME", "value": "benzene"}], "amount": {"mass": {"value": 9.1, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}, "m1_m4_m2_m5": {"components": [{"identifiers": [{"type": "NAME", "value": "benzylamine"}], "amount": {"volume": {"value": 15.0, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "o-iodobenzoyl chloride"}], "amount": {"mass": {"value": 8.0, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "tetrahydrofuran"}], "amount": {"volume": {"value": 20.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}, {"identifiers": [{"type": "NAME", "value": "tetrahydrofuran"}], "amount": {"volume": {"value": 20.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "N-benzyl-o-iodobenzamide"}], "reactionRole": "PRODUCT"}]}], "workups": []}',
#   'n_token_example': 543,
#   'response': '### Procedure:\nA solution of 15 ml of benzylamine in 20 ml of tetrahydrofuran was reacted with a solution of 8.0 g of o-iodobenzoyl chloride in 20 ml of tetrahydrofuran in accordance with the procedure of Example 3. There was obtained by recrystallization from benzene 9.1 g of N-benzyl-o-iodobenzamide, m.p. 122°-123°, Rf 0.78.\n\n### ORD-JSON:\n{"inputs": {"m1_m3_m2_m4": {"components": [{"identifiers": [{"type": "NAME", "value": "benzylamine"}], "amount": {"volume": {"value": 15.0, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "o-iodobenzoyl chloride"}], "amount": {"mass": {"value": 8.0, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "tetrahydrofuran"}], "amount": {"volume": {"value": 20.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}, {"identifiers": [{"type": "NAME", "value": "tetrahydrofuran"}], "amount": {"volume": {"value": 20.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "N-benzyl-o-iodobenzamide"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 9.1, "units": "GRAM"}}}, {"type": "YIELD", "details": "CALCULATEDPERCENTYIELD", "percentage": {"value": 99.9}}], "reactionRole": "PRODUCT"}]}], "workups": []}'},
#  {'reaction_id': 'ord-8c86fc0f87ca4cd089dd2c05282a4d7f',
#   'instruction': "To a solution of 1.80 g (10 mmol) of 4-chlorocinnamic acid in 50 mL of THF was added Pd/C (1.04 g, 5% w/w) and the solution was stirred under a hydrogen atmosphere until no further H2 take-up was observed (~1 h). The solution was filtered through Celite and the solvent removed under reduced pressure to yield 1.82 g (9.8 mmol, 98%) of a white solid: mp. 103°-105° C.; 1H NMR (DMSO-d6) δ2.51 (t, 2H, β--CH2), 2.79 (t, 2H, (α--CH2), 7.28 (dd, 4H, aromatic CH's), 12.12 (s, 1H, COOH); MS (EI, calculated for C9H9ClO2, 184.0291) m/e 184.0288 (M+).",
#   'output': '{"inputs": {"m1_m2_m3": {"components": [{"identifiers": [{"type": "NAME", "value": "4-chlorocinnamic acid"}], "amount": {"mass": {"value": 1.8, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "THF"}], "amount": {"volume": {"value": 50.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}, {"identifiers": [{"type": "NAME", "value": "Pd/C"}], "amount": {"mass": {"value": 1.04, "units": "GRAM"}}, "reactionRole": "CATALYST"}]}}, "conditions": {"stirring": {"type": "CUSTOM", "details": "the solution was stirred under a hydrogen atmosphere until no further H2"}, "conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "white solid"}], "measurements": [{"type": "AMOUNT", "details": "AMOUNT", "amount": {"moles": {"value": 9.8, "units": "MILLIMOLE"}}}, {"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 1.82, "units": "GRAM"}}}, {"type": "YIELD", "details": "PERCENTYIELD", "percentage": {"value": 98.0}}, {"type": "YIELD", "details": "CALCULATEDPERCENTYIELD", "percentage": {"value": 98.0}}], "isolatedColor": "white", "texture": {"type": "CUSTOM", "details": "solid"}, "reactionRole": "PRODUCT"}]}], "workups": [{"type": "CUSTOM"}, {"type": "FILTRATION"}, {"type": "CUSTOM"}]}',
#   'n_token_example': 776,
#   'response': '### Procedure:\nTo a solution of 1.80 g (10 mmol) of 4-chlorocinnamic acid in 50 mL of THF was added Pd/C (1.04 g, 5% w/w) and the solution was stirred under a hydrogen atmosphere until no further H2 take-up was observed (~1 h). The solution was filtered through Celite and the solvent removed under reduced pressure to yield 1.82 g (9.8 mmol, 98%) of a white solid: mp. 103°-105° C.; 1H NMR (DMSO-d6) δ2.51 (t, 2H, β--CH2), 2.79 (t, 2H, (α--CH2), 7.28 (dd, 4H, aromatic CH\'s), 12.12 (s, 1H, COOH); MS (EI, calculated for C9H9ClO2, 184.0291) m/e 184.0288 (M+).\n\n### ORD-JSON:\n{"inputs": {"m1_m2_m3": {"components": [{"identifiers": [{"type": "NAME", "value": "4-chlorocinnamic acid"}], "amount": {"mass": {"value": 1.8, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "THF"}], "amount": {"volume": {"value": 50.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}, {"identifiers": [{"type": "NAME", "value": "Pd/C"}], "amount": {"mass": {"value": 1.04, "units": "GRAM"}}, "reactionRole": "CATALYST"}]}}, "conditions": {"stirring": {"type": "CUSTOM", "details": "the solution was stirred under a hydrogen atmosphere until no further H2 take-up"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 1.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "white solid"}], "measurements": [{"type": "AMOUNT", "details": "AMOUNT", "amount": {"moles": {"value": 9.8, "units": "MILLIMOLE"}}}, {"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 1.82, "units": "GRAM"}}}, {"type": "YIELD", "details": "PERCENTYIELD", "percentage": {"value": 98.0}}, {"type": "YIELD", "details": "CALCULATEDPERCENTYIELD", "percentage": {"value": 98.0}}], "isolatedColor": "white", "texture": {"type": "CUSTOM", "details": "solid"}, "reactionRole": "PRODUCT"}]}], "workups": [{"type": "FILTRATION"}, {"type": "CUSTOM"}]}'},
#  {'reaction_id': 'ord-05d03d2a7b5249c49c6efcac55542cba',
#   'instruction': "The title compound was prepared as described in Example 1 using 2-amino-5-[2-fluoro-4-(1-hydroxy-1-methylethyl)phenyl]thiophene-3-carboxamide (150 mg, 0.510 mmol) and 1-(6-bromopyridin-2-yl)-1-morpholin-4-ylpropan-2-ol (168 mg, 0.510 mmol) as starting materials. 1H NMR (600 MHz, d6-DMSO): δ 11.96 (s, 1H), 7.84 (s, 1H), 7.81 (s, 1H), 7.66 (t, 1H), 7.54 (m, 1H), 7.36 (s, 1H), 7.32 (d, 1H), 7.31 (s, 1H), 7.95 (d, 1H), 6.78 (d, 1H), 5.13 (s, 1H), 4.55 (m, 1H), 4.18 (s, 1H), 3.54 (m, 4H), 3.31 (d, 1H), 2.61 (m, 2H), 2.33 (m, 2H), 1.40 (s, 6H), 0.89 (d, 3H). Calc'd for C26H32FN4O4S [M+H]+: 515. found 515.",
#   'output': '{"inputs": {"m2": {"components": [{"identifiers": [{"type": "NAME", "value": "1-(6-bromopyridin-2-yl)-1-morpholin-4-ylpropan-2-ol"}], "amount": {"mass": {"value": 168.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}]}, "m1": {"components": [{"identifiers": [{"type": "NAME", "value": "2-amino-5-[2-fluoro-4-(1-hydroxy-1-methylethyl)phenyl]thiophene-3-carboxamide"}], "amount": {"mass": {"value": 150.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "title compound"}], "reactionRole": "PRODUCT"}]}], "workups": []}',
#   'n_token_example': 689,
#   'response': '### Procedure:\nThe title compound was prepared as described in Example 1 using 2-amino-5-[2-fluoro-4-(1-hydroxy-1-methylethyl)phenyl]thiophene-3-carboxamide (150 mg, 0.510 mmol) and 1-(6-bromopyridin-2-yl)-1-morpholin-4-ylpropan-2-ol (168 mg, 0.510 mmol) as starting materials. 1H NMR (600 MHz, d6-DMSO): δ 11.96 (s, 1H), 7.84 (s, 1H), 7.81 (s, 1H), 7.66 (t, 1H), 7.54 (m, 1H), 7.36 (s, 1H), 7.32 (d, 1H), 7.31 (s, 1H), 7.95 (d, 1H), 6.78 (d, 1H), 5.13 (s, 1H), 4.55 (m, 1H), 4.18 (s, 1H), 3.54 (m, 4H), 3.31 (d, 1H), 2.61 (m, 2H), 2.33 (m, 2H), 1.40 (s, 6H), 0.89 (d, 3H). Calc\'d for C26H32FN4O4S [M+H]+: 515. found 515.\n\n### ORD-JSON:\n{"inputs": {"m2": {"components": [{"identifiers": [{"type": "NAME", "value": "1-(6-bromopyridin-2-yl)-1-morpholin-4-ylpropan-2-ol"}], "amount": {"mass": {"value": 168.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}]}, "m1": {"components": [{"identifiers": [{"type": "NAME", "value": "2-amino-5-[2-fluoro-4-(1-hydroxy-1-methylethyl)phenyl]thiophene-3-carboxamide"}], "amount": {"mass": {"value": 150.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "title compound"}], "reactionRole": "PRODUCT"}]}], "workups": []}'},
#  {'reaction_id': 'ord-5206a230f2d146378396cf547c48ac3c',
#   'instruction': 'To a 1-liter 3-necked flask equipped with a mechanical stirrer, reflux condenser, and thermometer were charged 102 grams of ethylene urea (40 wt %), 39 grams of ethylene glycol, and 97 grams of glyoxal (40 wt %). Initial pH of the mixture was 4.3. The mixture was stirred, heated to 70° C., and held at this temperature for four hours. The product (EEG) was a clear yellow liquid with NV %=43.6%, pH=3.9 and infinite WD. The composition was stable for at least 3 months (clear, no gellation, infinite WD).',
# ...
#   'output': '{"inputs": {"m0_m1_m2_m3_m4": {"components": [{"identifiers": [{"type": "NAME", "value": "(2-aminothiazol-4-yl)acetic acid"}], "amount": {"volume": {"value": 1.0, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "tert-butylisonitrile"}], "amount": {"volume": {"value": 0.575, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "2-methoxybenzaldehyde"}], "amount": {"volume": {"value": 0.5, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "perchloric acid"}], "amount": {"volume": {"value": 10.0, "units": "MICROLITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "Compound 33"}], "reactionRole": "PRODUCT"}]}], "workups": []}',
#   'n_token_example': 513,
#   'response': '### Procedure:\nCompound 33 was prepared in accordance with the general synthesis instructions from 1.0 ml (0.1 mmol) (2-aminothiazol-4-yl)acetic acid solution (0.1 M, MC), 0.575 ml (0.115 mmol) tert-butylisonitrile solution (0.2 M, MC), 0.500 ml (0.15 mmol) 2-methoxybenzaldehyde solution (0.3 M, MC) and 10 μl perchloric acid (w=20%) in a substance library.\n\n### ORD-JSON:\n{"inputs": {"m0_m1_m2_m3_m4": {"components": [{"identifiers": [{"type": "NAME", "value": "(2-aminothiazol-4-yl)acetic acid"}], "amount": {"volume": {"value": 1.0, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "tert-butylisonitrile"}], "amount": {"volume": {"value": 0.575, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "2-methoxybenzaldehyde"}], "amount": {"volume": {"value": 0.5, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "perchloric acid"}], "amount": {"volume": {"value": 10.0, "units": "MICROLITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "Compound 33"}], "reactionRole": "PRODUCT"}]}], "workups": []}'},
#  {'reaction_id': 'ord-18bd0fe75c6d405b98f659a271ed2897',
#   'instruction': 'To a stirred solution of 1.46 g of 2,4-dimethylphenyl isocyanate in 100 ml of hexane was added a solution of 2.63 g of 6-[[(4-butylphenyl)methyl]amino]-1-hexanol (prepared as described in Example 489), in 500 ml of hexane. The mixture was stirred at room temperature for 2 hours. Evaporation gave a gum. The gum was purified by chromatography to yield 2.81 g of the desired product as a colorles gum.',
#   'output': '{"inputs": {"m1_m3_m2": {"components": [{"identifiers": [{"type": "NAME", "value": "2,4-dimethylphenyl isocyanate"}], "amount": {"mass": {"value": 1.46, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "6-[[(4-butylphenyl)methyl]amino]-1-hexanol"}], "amount": {"mass": {"value": 2.63, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "hexane"}], "amount": {"volume": {"value": 100.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}, "m4": {"components": [{"identifiers": [{"type": "NAME", "value": "hexane"}], "amount": {"volume": {"value": 500.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"temperature": {"control": {"type": "AMBIENT"}}, "stirring": {"type": "CUSTOM", "details": "The mixture was stirred at room temperature for 2 hours"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 2.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "desired product"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 2.81, "units": "GRAM"}}}, {"type": "YIELD", "details": "CALCULATEDPERCENTYIELD", "percentage": {"value": 69.0}}], "reactionRole": "PRODUCT"}]}], "workups": [{"type": "CUSTOM"}, {"type": "CUSTOM"}, {"type": "CUSTOM"}]}',
#   'n_token_example': 685,
#   'response': '### Procedure:\nTo a stirred solution of 1.46 g of 2,4-dimethylphenyl isocyanate in 100 ml of hexane was added a solution of 2.63 g of 6-[[(4-butylphenyl)methyl]amino]-1-hexanol (prepared as described in Example 489), in 500 ml of hexane. The mixture was stirred at room temperature for 2 hours. Evaporation gave a gum. The gum was purified by chromatography to yield 2.81 g of the desired product as a colorles gum.\n\n### ORD-JSON:\n{"inputs": {"m1_m3_m2": {"components": [{"identifiers": [{"type": "NAME", "value": "2,4-dimethylphenyl isocyanate"}], "amount": {"mass": {"value": 1.46, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "6-[[(4-butylphenyl)methyl]amino]-1-hexanol"}], "amount": {"mass": {"value": 2.63, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "hexane"}], "amount": {"volume": {"value": 100.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"temperature": {"control": {"type": "AMBIENT"}}, "stirring": {"type": "CUSTOM", "details": "The mixture was stirred at room temperature for 2 hours"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 2.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "desired product"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 2.81, "units": "GRAM"}}}, {"type": "YIELD", "details": "CALCULATEDPERCENTYIELD", "percentage": {"value": 100.0}}], "isolatedColor": "colorles", "texture": {"type": "CUSTOM", "details": "gum"}, "reactionRole": "PRODUCT"}]}], "workups": [{"type": "CUSTOM"}]}'},
#  {'reaction_id': 'ord-5ac6ed6786b047afa95ae4ef4a061792',
#   'instruction': 'A mixture of (R/S) (4-(3-(2-methoxyethoxy)-5-(trifluoromethyl)phenyl)-5-methyl-1-(tetrahydro-2H-pyran-2-yl)-1H-pyrazol-3-yl)methanol (70 mg, 0.17 mmol, 1.00 equiv) and MnO2 (147 mg, 1.69 mmol, 10.01 equiv) in dichloromethane (20 mL) was stirred at 40° C. for 1 h. The solid was removed by filtration. The filtrate was concentrated under vacuum to give 87 mg of crude (R/S) 4-(3-(2-methoxyethoxy)-5-(trifluoromethyl)phenyl)-5-methyl-1-(tetrahydro-2H-pyran-2-yl)-1H-pyrazole-3-carbaldehyde as a brown oil.',
#   'output': '{"inputs": {"m1_m3_m2": {"components": [{"identifiers": [{"type": "NAME", "value": "(R/S) (4-(3-(2-methoxyethoxy)-5-(trifluoromethyl)phenyl)-5-methyl-1-(tetrahydro-2H-pyran-2-yl)-1H-pyrazol-3-yl)methanol"}], "amount": {"mass": {"value": 70.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "dichloromethane"}], "amount": {"volume": {"value": 20.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}, {"identifiers": [{"type": "NAME", "value": "MnO2"}], "amount": {"mass": {"value": 147.0, "units": "MILLIGRAM"}}, "reactionRole": "CATALYST"}]}}, "conditions": {"temperature": {"setpoint": {"value": 40.0, "units": "CELSIUS"}}, "stirring": {"type": "CUSTOM", "details": "was stirred at 40\\u00b0 C. for 1 h"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 1.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "(R/S) 4-(3-(2-methoxyethoxy)-5-(trifluoromethyl)phenyl)-5-methyl-1-(tetrahydro-2H-pyran-2-yl)-1H-pyrazole-3-carbaldehyde"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 87.0, "units": "MILLIGRAM"}}}, {"type": "YIELD", "details": "CALCULATEDPERCENTYIELD", "percentage": {"value": 124.1}}], "isolatedColor": "brown", "texture": {"type": "OIL", "details": "oil"}, "reactionRole": "PRODUCT"}]}], "workups": [{"type": "CUSTOM"}, {"type": "CONCENTRATION"}]}',
#   'n_token_example': 883,
#   'response': '### Procedure:\nA mixture of (R/S) (4-(3-(2-methoxyethoxy)-5-(trifluoromethyl)phenyl)-5-methyl-1-(tetrahydro-2H-pyran-2-yl)-1H-pyrazol-3-yl)methanol (70 mg, 0.17 mmol, 1.00 equiv) and MnO2 (147 mg, 1.69 mmol, 10.01 equiv) in dichloromethane (20 mL) was stirred at 40° C. for 1 h. The solid was removed by filtration. The filtrate was concentrated under vacuum to give 87 mg of crude (R/S) 4-(3-(2-methoxyethoxy)-5-(trifluoromethyl)phenyl)-5-methyl-1-(tetrahydro-2H-pyran-2-yl)-1H-pyrazole-3-carbaldehyde as a brown oil.\n\n### ORD-JSON:\n{"inputs": {"m1_m2_m3": {"components": [{"identifiers": [{"type": "NAME", "value": "(R/S) (4-(3-(2-methoxyethoxy)-5-(trifluoromethyl)phenyl)-5-methyl-1-(tetrahydro-2H-pyran-2-yl)-1H-pyrazol-3-yl)methanol"}], "amount": {"mass": {"value": 70.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "MnO2"}], "amount": {"mass": {"value": 147.0, "units": "MILLIGRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "dichloromethane"}], "amount": {"volume": {"value": 20.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"temperature": {"setpoint": {"value": 40.0, "units": "CELSIUS"}}, "stirring": {"type": "CUSTOM", "details": "was stirred at 40\\u00b0 C. for 1 h"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 1.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "(R/S) 4-(3-(2-methoxyethoxy)-5-(trifluoromethyl)phenyl)-5-methyl-1-(tetrahydro-2H-pyran-2-yl)-1H-pyrazole-3-carbaldehyde"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 87.0, "units": "MILLIGRAM"}}}, {"type": "YIELD", "details": "CALCULATEDPERCENTYIELD", "percentage": {"value": 99.9}}], "isolatedColor": "brown", "texture": {"type": "OIL", "details": "oil"}, "reactionRole": "PRODUCT"}]}], "workups": [{"type": "CUSTOM"}, {"type": "CONCENTRATION"}]}'},
#  {'reaction_id': 'ord-6769afe3f93e45529751b5d6b490635d',
#   'instruction': 'To a suspension of 15.44 g (0.06 mol) of benzhydrylsulphinylacetic acid in 90 ml of methylene chloride are added 6.48 g (0.06 mol, i.e. 6.17 ml) of 2-aminomethylpyridine and 12.36 g (0.06 mol) of dicyclohexylcarbodiimide are added to the solution thus obtained. The mixture is heated at reflux for about 3 to 4 hours, then left to cool.',
#   'output': '{"inputs": {"m2_m3": {"components": [{"identifiers": [{"type": "NAME", "value": "2-aminomethylpyridine"}], "amount": {"volume": {"value": 6.17, "units": "MILLILITER"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "dicyclohexylcarbodiimide"}], "amount": {"mass": {"value": 12.36, "units": "GRAM"}}, "reactionRole": "REACTANT"}]}, "m1_m4": {"components": [{"identifiers": [{"type": "NAME", "value": "benzhydrylsulphinylacetic acid"}], "amount": {"mass": {"value": 15.44, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "methylene chloride"}], "amount": {"volume": {"value": 90.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "N-(2-pyridylmethyl)benzhydrylsulphinylacetamide"}]}]}], "workups": [{"type": "ADDITION"}, {"type": "CUSTOM"}, {"type": "TEMPERATURE"}, {"type": "TEMPERATURE", "duration": {"value": 3.5, "precision": 0.5, "units": "HOUR"}}, {"type": "WAIT"}, {"type": "TEMPERATURE"}]}',
#   'n_token_example': 589,
#   'response': '### Procedure:\nTo a suspension of 15.44 g (0.06 mol) of benzhydrylsulphinylacetic acid in 90 ml of methylene chloride are added 6.48 g (0.06 mol, i.e. 6.17 ml) of 2-aminomethylpyridine and 12.36 g (0.06 mol) of dicyclohexylcarbodiimide are added to the solution thus obtained. The mixture is heated at reflux for about 3 to 4 hours, then left to cool.\n\n### ORD-JSON:\n{"inputs": {"m1_m4_m2_m3": {"components": [{"identifiers": [{"type": "NAME", "value": "benzhydrylsulphinylacetic acid"}], "amount": {"mass": {"value": 15.44, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "2-aminomethylpyridine"}], "amount": {"mass": {"value": 6.48, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "dicyclohexylcarbodiimide"}], "amount": {"mass": {"value": 12.36, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "methylene chloride"}], "amount": {"volume": {"value": 90.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}]}}, "conditions": {"conditionsAreDynamic": true}, "outcomes": [{"products": [{"identifiers": [{"type": "NAME", "value": "2-Aminomethyl-5-[2-(dicyclohexylcarbonyl)ethyl]pyridine"}]}]}], "workups": [{"type": "TEMPERATURE"}, {"type": "TEMPERATURE", "duration": {"value": 3.0, "units": "HOUR"}}, {"type": "TEMPERATURE"}, {"type": "TEMPERATURE"}]}'},
#  {'reaction_id': 'ord-a2caf2f455704478be8b568477984cf2',
#   'instruction': 'To a stirred solution of 66.16E (0.387 g, 1 mmol) in EtOAc (11 mL) at 23° C. was added palladium on carbon (0.1 g, 1 mmol). The reaction was placed under an atmosphere of hydrogen and stirred for 2 hours. The reaction mixture was then filtered and concentrated in vacuo. The residue was purified on silica gel (0-20% EtOAc in hexanes) to yield 66.16F as a colorless oil (0.13 g, 33% yield).',
#   'output': '{"inputs": {"m1_m2_m3": {"components": [{"identifiers": [{"type": "NAME", "value": "66.16E"}], "amount": {"mass": {"value": 0.387, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "EtOAc"}], "amount": {"volume": {"value": 11.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}, {"identifiers": [{"type": "NAME", "value": "palladium on carbon"}], "amount": {"mass": {"value": 0.1, "units": "GRAM"}}, "reactionRole": "CATALYST"}]}}, "conditions": {"stirring": {"type": "CUSTOM", "details": "stirred for 2 hours"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 2.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "66.16F"}], "measurements": [{"type": "AMOUNT", "details": "MASS", "amount": {"mass": {"value": 0.13, "units": "GRAM"}}}, {"type": "YIELD", "details": "PERCENTYIELD", "percentage": {"value": 33.0}}, {"type": "YIELD", "details": "CALCULATEDPERCENTYIELD", "percentage": {"value": 38.0}}], "isolatedColor": "colorless", "texture": {"type": "OIL", "details": "oil"}, "reactionRole": "PRODUCT"}]}], "workups": [{"type": "FILTRATION"}, {"type": "CONCENTRATION"}, {"type": "CUSTOM"}]}',
#   'n_token_example': 635,
#   'response': '### Procedure:\nTo a stirred solution of 66.16E (0.387 g, 1 mmol) in EtOAc (11 mL) at 23° C. was added palladium on carbon (0.1 g, 1 mmol). The reaction was placed under an atmosphere of hydrogen and stirred for 2 hours. The reaction mixture was then filtered and concentrated in vacuo. The residue was purified on silica gel (0-20% EtOAc in hexanes) to yield 66.16F as a colorless oil (0.13 g, 33% yield).\n\n### ORD-JSON:\n{"inputs": {"m1_m2_m3": {"components": [{"identifiers": [{"type": "NAME", "value": "66.16E"}], "amount": {"mass": {"value": 0.387, "units": "GRAM"}}, "reactionRole": "REACTANT"}, {"identifiers": [{"type": "NAME", "value": "EtOAc"}], "amount": {"volume": {"value": 11.0, "units": "MILLILITER"}}, "reactionRole": "SOLVENT"}, {"identifiers": [{"type": "NAME", "value": "palladium on carbon"}], "amount": {"mass": {"value": 0.1, "units": "GRAM"}}, "reactionRole": "CATALYST"}]}}, "conditions": {"stirring": {"type": "CUSTOM", "details": "stirred for 2 hours"}, "conditionsAreDynamic": true}, "outcomes": [{"reactionTime": {"value": 2.0, "units": "HOUR"}, "products": [{"identifiers": [{"type": "NAME", "value": "66.16F"}], "isolatedColor": "colorless", "texture": {"type": "OIL", "details": "oil"}, "reactionRole": "PRODUCT"}]}], "workups": [{"type": "FILTRATION"}, {"type": "CONCENTRATION"}, {"type": "CUSTOM"}]}'},
#  ...]

# %%
extracted_compounds
# Out:
# {'ord-8b67d21803c44856af23b912ff922d7a': {'llm_species': ['15-crown-5',
#    '5-phenyl-1H-pyrrole-3-carbaldehyde',
#    '2-chloro-5-pyrimidinesulfonyl chloride',
#    'sodium hydride',
#    'title compound',
#    'solid'],
#   'cde_species': ['5-phenyl-1H-pyrrole-3-carbaldehyde',
#    'sodium hydride',
#    '15-crown-5',
#    '2-chloro-5-pyrimidinesulfonyl chloride']},
#  'ord-129e3181c9dd475fb3ca577cd8857a22': {'llm_species': ['2-chloro-4-(4-{[(2S)-2,3-dihydroxypropyl]oxy}phenyl)-6-methoxypyridine-3,5-dicarbonitrile',
#    'DMF',
#    'sodium sulphide',
#    '4-(4-{[(2S)-2,3-Dihydroxypropyl]oxy}phenyl)-2-methoxy-6-sulphanylpyridine-3,5-dicarbonitrile'],
#   'cde_species': ['2-chloro-4-(4-{[(2S)-2,3-dihydroxypropyl]oxy}phenyl)-6-methoxypyridine-3,5-dicarbonitrile',
#    'DMF',
#    'sodium sulphide']},
#  'ord-992026e2505c42178351aaf4efeb7ae2': {'llm_species': ['anisaldehyde',
#    '4-carboxybenzenesulfonamide',
#    'TsOH',
#    'chlorobenzene',
#    'N-(4-Methoxybenzylidene)-4-carboxybenzenesulfonamide'],
#   'cde_species': ['anisaldehyde',
#    '4-carboxybenzenesulfonamide',
#    'TsOH',
#    'chlorobenzene',
#    'nitrogen',
#    'SULF-8',
#    'Nujol',
#    '1H',
#    'DMSO-d6']},
#  'ord-cc62cc7f843041a68530c3cb37189044': {'llm_species': ['3-(1-{[3-(dimethylamino)propyl]sulfonyl}-4-piperidinyl)-5-[3-(hydroxymethyl)phenyl]-1H-indole-7-carboxamide',
#    'THF',
#    'MnO2',
#    'crude product'],
#   'cde_species': ['3-(1-{[3-(dimethylamino)propyl]sulfonyl}-4-piperidinyl)-5-[3-(hydroxymethyl)phenyl]-1H-indole-7-carboxamide',
#    'THF',
#    'MnO2']},
#  'ord-c2acd820ffd54eacaa4cb46ff16afa6d': {'llm_species': ['benzyl (2S)-2-isopropyl-3-oxopyrrolidine-1-carboxylate',
#    'cerium chloride',
#    'ethylmagnesium bromide diethyl ether',
#    'title compound',
#    'oil'],
#   'cde_species': ['cerium chloride',
#    'ethylmagnesium',
#    'bromide-diethyl ether',
#    'benzyl (2S)-2-isopropyl-3-oxopyrrolidine-1-carboxylate']},
#  'ord-cbe0ef10e0b04e598fcef528b5c542e4': {'llm_species': ['4-bromo-3-fluoroaniline',
#    '1,3-diethyl 2-(ethoxymethylidene)propanedioate',
#    'EtOH',
#    'desired material'],
#   'cde_species': ['4-bromo-3-fluoroaniline',
#    '1,3-diethyl 2-(ethoxymethylidene)propanedioate',
#    'EtOH',
#    '1H',
#    '2H']},
#  'ord-386ae454bbe0448da0a6ac1ab187c8b2': {'llm_species': ['N-(4-(3-tert-Butoxycarbonylaminomethylpyrrolidin-1-yl)butyl)-1-methyl-1 H-indole-3-carboxamide',
#    '4-amino-5-chloro-2-cyclopropylmethyloxybenzoic acid',
#    'N-(4-(3-(4-amino-5-chloro-2-cyclopropylmethyloxybenzoylaminomethyl)-pyrrolidin-1-yl)butyl)-1-methyl-1 H-indole-3-carboxamide'],
#   'cde_species': ['N-(4-(3-tert-Butoxycarbonylaminomethylpyrrolidin-1-yl)butyl)-1-methyl-1 H-indole-3-carboxamide',
#    '4-amino-5-chloro-2-cyclopropylmethyloxybenzoic acid',
#    'N-(4-(3-(4-amino-5-chloro-2-cyclopropylmethyloxybenzoylaminomethyl)-pyrrolidin-1-yl)butyl)-1-methyl-1 H-indole-3-carboxamide']},
#  'ord-9628d5710f6c4dad817942011a70d16b': {'llm_species': ['{(S)-2-[(S)-2-(2-benzoimidazol-1-yl-pyridin-4-yl)-pyrrolidin-1-yl]-1-cyclohexyl-2-oxo-ethyl}-carbamic acid tert-butyl ester',
#    'TFA',
#    'DCM',
#    '(S)-2-Amino-1-[(S)-2-(2-benzoimidazol-1-yl-pyridin-4-yl)-pyrrolidin-1-yl]-2-cyclohexyl-ethanone'],
#   'cde_species': ['{(S)-2-[(S)-2-(2-benzoimidazol-1-yl-pyridin-4-yl)-pyrrolidin-1-yl]-1-cyclohexyl-2-oxo-ethyl}-carbamic acid tert-butyl ester',
#    'TFA',
#    '(S)-2-Amino-1-[(S)-2-(2-benzoimidazol-1-yl-pyridin-4-yl)-pyrrolidin-1-yl]-2-cyclohexyl-ethanone']},
#  'ord-d3403ec324124f6ebcef953fdb93a990': {'llm_species': ['trans-4-hydroxycyclohexane carboxylic acid',
#    '(R)-2-n-hexyloxypropanoyl chloride',
#    'title compound'],
#   'cde_species': ['trans-4-hydroxycyclohexane carboxylic acid',
#    '(R)-2-n-hexyloxypropanoyl chloride']},
#  'ord-4e77cea7017d447caa39a60511a8276c': {'llm_species': ['2-amino-nicotinic acid',
#    'acetic acid',
#    'diethyl ether',
#    'bromine',
#    'acetic acid',
#    'title compound'],
#   'cde_species': ['2-amino-nicotinic acid',
#    'glacial acetic acid',
#    'bromine',
#    'diethyl ether',
#    '1H']},
#  'ord-c07e86bf39de478ca7a81d6dc5d44939': {'llm_species': ['1-chloro-2-methyl-3-methoxycarbonylaminobenzene',
#    'phosphorus pentachloride',
#    'chlorobenzene',
#    '1-chloro-3-isocyanato-2-methylbenzene'],
#   'cde_species': ['1-chloro-2-methyl-3-methoxycarbonylaminobenzene',
#    'phosphorus pentachloride',
#    'chlorobenzene',
#    '1-chloro-3-isocyanato-2-methylbenzene']},
#  'ord-4650afab87024b47ad22984617ce22c4': {'llm_species': ['Trimethylsilylbromide',
#    'methylphenyl phosphinic acid, phenethyl ester',
#    'methylphenylphosphinic acid'],
#   'cde_species': ['Trimethylsilylbromide',
#    'phenethyl ester',
#    'dichloromethane',
#    'methylphenylphosphinic acid']},
#  'ord-68fb223505b5424594055f26c1c2e670': {'llm_species': ['benzene',
#    'benzylamine',
#    'o-iodobenzoyl chloride',
#    'tetrahydrofuran',
#    'tetrahydrofuran',
#    'N-benzyl-o-iodobenzamide'],
#   'cde_species': ['benzylamine',
#    'tetrahydrofuran',
#    'o-iodobenzoyl chloride',
#    'benzene',
#    'N-benzyl-o-iodobenzamide']},
#  'ord-8c86fc0f87ca4cd089dd2c05282a4d7f': {'llm_species': ['4-chlorocinnamic acid',
#    'THF',
#    'Pd/C',
#    'white solid'],
#   'cde_species': ['4-chlorocinnamic acid',
#    'THF',
#    'Pd / C',
#    'hydrogen',
#    'Celite',
#    'CH2',
#    '2H, ( α -- CH2 )',
#    '1H',
#    'COOH']},
#  'ord-05d03d2a7b5249c49c6efcac55542cba': {'llm_species': ['2-amino-5-[2-fluoro-4-(1-hydroxy-1-methylethyl)phenyl]thiophene-3-carboxamide',
#    '1-(6-bromopyridin-2-yl)-1-morpholin-4-ylpropan-2-ol',
#    'title compound'],
#   'cde_species': ['2-amino-5-[2-fluoro-4-(1-hydroxy-1-methylethyl)phenyl]thiophene-3-carboxamide',
#    '1-(6-bromopyridin-2-yl)-1-morpholin-4-ylpropan-2-ol',
#    '1H',
#    'd6-DMSO',
#    'C26H32FN4O4S']},
#  'ord-5206a230f2d146378396cf547c48ac3c': {'llm_species': ['ethylene urea',
#    'glyoxal',
#    'ethylene glycol',
#    'Ethylene Urea Ethylene Glycol Glyoxal'],
#   'cde_species': ['ethylene urea', 'ethylene glycol', 'glyoxal']},
#  'ord-817634e33cc7416ab9d7ed4d0adad243': {'llm_species': ['3-bromophenylacetic acid',
#    '1,3-dicyclohexylcarbodiimide',
#    'MeOH',
#    'dichloromethane',
#    '4-dimethylaminopyridine',
#    'crude product'],
#   'cde_species': ['3-bromophenylacetic acid',
#    '1,3-dicyclohexylcarbodiimide',
#    'MeOH',
#    '4-dimethylaminopyridine',
#    'silica gel',
#    'CDCl3',
#    'dichloromethane']},
#  'ord-e70c2ad71b0745b1ac4923e032569e88': {'llm_species': ['tert-butyl (1S,2R)-2-(7-fluoro-4-(1-methyl-1H-pyrazol-4-yl)-3-oxo-2,3-dihydro-1H-pyrrolo[3,4-c]pyridin-6-ylamino)cyclohexylcarbamate',
#    'TFA',
#    'DCM',
#    'TFA',
#    'title compound'],
#   'cde_species': ['tert-butyl (1S,2R)-2-(7-fluoro-4-(1-methyl-1H-pyrazol-4-yl)-3-oxo-2,3-dihydro-1H-pyrrolo[3,4-c]pyridin-6-ylamino)cyclohexylcarbamate',
#    '1H',
#    'DMSO-d6',
#    'C17H21FN6O',
#    'TFA']},
#  'ord-b40661beed2e4f2eab99698e17d64ed6': {'llm_species': ['9,10-dibromo-9,10-dihydro-4H-benzo[4,5]cyclohepta[ 1,2-b]thiophen-4-one',
#    'methanol',
#    '9-Bromo-9,10-dihydro-10-methoxy- 4H-benzo [4,5]cyclohepta[1,2-b]-thiophen-4-one'],
#   'cde_species': ['9,10-dibromo-9,10-dihydro-4H-benzo[4,5]cyclohepta[ 1,2-b]thiophen-4-one',
#    'methanol',
#    '9-Bromo-9,10-dihydro-10-methoxy- 4H-benzo [4,5]cyclohepta[1,2-b]-thiophen-4-one']},
#  'ord-539995e517744fd592477d40ee75249d': {'llm_species': ['(S)-3-(4-chlorophenyl)-1-((6-chloropyridin-3-yl)methyl)-4-(3-(trifluoromethyl)phenyl)imidazolidin-2-one',
#    'piperidine',
#    'pyridine',
#    'title compound'],
#   'cde_species': ['(S)-3-(4-chlorophenyl)-1-((6-chloropyridin-3-yl)methyl)-4-(3-(trifluoromethyl)phenyl)imidazolidin-2-one',
#    'piperidine',
#    'pyridine',
#    '1H',
#    'CD3OD',
#    '2H',
#    'C27H26ClF3N4O']},
#  'ord-9257940612104583b854d0a90989b4b0': {'llm_species': ['αethynyl-5,6,7,8-tetrahydro-5,5,8,8-tetramethyl-2-naphthalenemethanol',
#    '4-bromophenylsulfinylmethane',
#    'sulfoxide',
#    '4-(3-hydroxy-3-(5,6,7,8-tetrahydro-5,5,8,8-tetramethyl-2-naphthyl)-1-propynyl)phenylsulfinylmethane'],
#   'cde_species': ['αethynyl-5,6,7,8-tetrahydro-5,5,8,8-tetramethyl-2-naphthalenemethanol',
#    '4-bromophenylsulfinylmethane',
#    'sulfoxide']},
#  'ord-be91a62847614125b043416a826d0c80': {'llm_species': ['9-(2-thienyl)-8-nonenoic acid',
#    'Pd/C',
#    'product'],
#   'cde_species': ['9-(2-thienyl)-8-nonenoic acid',
#    'Pd',
#    'C13H20SO2',
#    '1H',
#    'H']},
#  'ord-12402a79e13f45a6ba7c3ba17809153d': {},
#  'ord-32dce5f0231545b393bb4f24c2726014': {'llm_species': ['4-[4-(trifluoroacetyl)-1-piperazinyl]aniline',
#    'dioxane',
#    'TEA',
#    'Trichloromethylchloroformate',
#    'title compound'],
#   'cde_species': ['4-[4-(trifluoroacetyl)-1-piperazinyl]aniline',
#    'dioxane',
#    'TEA',
#    'Trichloromethylchloroformate']},
#  'ord-6f24dba4987b468f8511415bc5111a00': {'llm_species': ['8-chloro-1-hydroxy-10,11-dihydrodibenzo[a,d]cyclohepten-5-one',
#    '4-(2-chloroethyl)morpholine hydrochloride',
#    'K2CO3',
#    'acetonitrile',
#    'title compound'],
#   'cde_species': ['8-chloro-1-hydroxy-10,11-dihydrodibenzo[a,d]cyclohepten-5-one',
#    '4-(2-chloroethyl)morpholine hydrochloride',
#    'K2CO3',
#    'acetonitrile',
#    'C21H21ClNO3']},
#  'ord-a638210d2e6c4c1296028b718b48653d': {'llm_species': ['4-Hydroxy-3-methoxy-2-nitrobenzaldehyde',
#    'THF',
#    'ammonium hydroxide',
#    'iodine',
#    '4-hydroxy-3-methoxy-2-nitrobenzonitrile'],
#   'cde_species': ['4-Hydroxy-3-methoxy-2-nitrobenzaldehyde',
#    'THF',
#    'ammonium hydroxide',
#    'iodine']},
#  'ord-388c55d8388a4e869f907bfa1673b9ae': {'llm_species': ['(RS)-4-benzyl-1-(tert-butyloxycarbonyl)-2-(2-hydroxyethyl)piperazine',
#    'ethanol',
#    'palladium on charcoal',
#    'title compound'],
#   'cde_species': ['(RS)-4-benzyl-1-(tert-butyloxycarbonyl)-2-(2-hydroxyethyl)piperazine',
#    'ethanol',
#    'palladium',
#    'charcoal',
#    'Kieselguhr',
#    'AP+',
#    'C11H22N2O3']},
#  'ord-b8093ee45c93418bbdb073ed2f232e93': {'llm_species': ['bis(2-methoxytetrafluoroethyl) ketone',
#    '2-chloroethanol',
#    'ether',
#    'K2CO3',
#    '2,2-bis(2-methoxytetrafluoroethyl)-1,3-dioxolane'],
#   'cde_species': ['bis(2-methoxytetrafluoroethyl) ketone',
#    '2-chloroethanol',
#    'ether',
#    'K2CO3',
#    '2,2-bis(2-methoxytetrafluoroethyl)-1,3-dioxolane',
#    'CCl4',
#    'C9H10F8O4C',
#    'H']},
#  'ord-d38e02dffe8b4b98b8ba6e0d17297a59': {'llm_species': ['5-bromothiophene-2-carbaldehyde',
#    'ethylboronic acid',
#    '5-ethylthiophene-2-carbaldehyde'],
#   'cde_species': ['5-bromothiophene-2-carbaldehyde',
#    '5-bromo-2-formylfuran',
#    'ethylboronic acid',
#    'hexylboronic acid',
#    '5-ethylthiophene-2-carbaldehyde']},
#  'ord-23cc430e18054a518e0951299a6d9136': {'llm_species': ['1,4-dihydro-2,6-dimethyl-3-methoxycarbonyl-4-(2-nitrophenyl)-5-(6-phthalimidohexyloxy)carbonyl-pyridine',
#    'hydrazine hydrate',
#    'orange coloured oil',
#    '1,4-Dihydro-2,6-dimethyl-3-methoxycarbonyl-4-(2-nitrophenyl)-5-(6-aminohexyloxy)carbonyl-pyridine'],
#   'cde_species': ['1,4-dihydro-2,6-dimethyl-3-methoxycarbonyl-4-(2-nitrophenyl)-5-(6-phthalimidohexyloxy)carbonyl-pyridine',
#    'hydrazine hydrate']},
#  'ord-b2d51b4fa40c46e883cc821579c3c176': {'llm_species': ["2'-O-pentylguanosine",
#    'trimethylsilyl chloride',
#    'isobutyryl chloride',
#    'pyridine',
#    'product'],
#   'cde_species': ["2'-O-pentylguanosine",
#    'pyridine',
#    'trimethylsilyl chloride',
#    'isobutyryl chloride',
#    'EtOAc',
#    'Hex',
#    '1H',
#    'DMSO-d6',
#    'CH3',
#    'CH2',
#    'OCH2',
#    "5'-OH",
#    "3'-OH",
#    'NH',
#    'C19H29N5O6',
#    'H',
#    'N']},
#  'ord-b586156ef3dc4707bd29584af02f4f66': {'llm_species': ['L-arabinose',
#    'MeOH',
#    'HCl MeOH',
#    'powder'],
#   'cde_species': ['L-arabinose',
#    'HCl',
#    'argon',
#    '1H',
#    'D2O',
#    'OCH3',
#    'H2',
#    'MeOH']},
#  'ord-51bdbf49630c45d38debb08e003a3665': {'llm_species': ['t-butyl N-[5-(2-benzyloxyphenoxy)-2-nitrophenyl]-N-methylcarbamate',
#    'palladium on carbon',
#    'methanol',
#    'title compound'],
#   'cde_species': ['t-butyl N-[5-(2-benzyloxyphenoxy)-2-nitrophenyl]-N-methylcarbamate',
#    'palladium',
#    'carbon',
#    'methanol']},
#  'ord-655b7c333f09466da6596f3a4933101a': {'llm_species': ['17-ethoxyacetoxy-11β,21-dihydroxy-6α-methyl-1,4-pregnadiene-3,20-dione',
#    'tris(triphenylphosphine)rhodium(I) chloride',
#    '17-ethoxyacetoxy-11β,21-dihydroxy-6α-methyl-4-pregnene-3,20-dione'],
#   'cde_species': ['17-ethoxyacetoxy-11β,21-dihydroxy-6α-methyl-1,4-pregnadiene-3,20-dione',
#    'tris(triphenylphosphine)rhodium(I) chloride',
#    '17-ethoxyacetoxy-11β,21-dihydroxy-6α-methyl-4-pregnene-3,20-dione']},
#  'ord-5a58b73a27004f378b94c0887dd85491': {'llm_species': ['3-(N-tert-butyloxycarbonylaminomethyl) azetidine',
#    'N-benzyloxycarbonyl-O-methylisourea',
#    'toluene',
#    'title compound'],
#   'cde_species': ['3-(N-tert-butyloxycarbonylaminomethyl) azetidine',
#    'N-benzyloxycarbonyl-O-methylisourea',
#    'toluene',
#    'EtOAc',
#    'MeOH',
#    'CH2Cl2']},
#  'ord-d8e646032b9f44a6a3ea7a3a298c0212': {'llm_species': ['3-benzyl-10-(2-fluorophenyl)-1,2,3,4,5,6-hexahydroazepino[4,5-b]indole',
#    'hydrochloric acid',
#    'ethanol',
#    'Pd/C',
#    'title compound'],
#   'cde_species': ['3-benzyl-10-(2-fluorophenyl)-1,2,3,4,5,6-hexahydroazepino[4,5-b]indole',
#    '1 N hydrochloric acid',
#    'Pd / C',
#    'ethanol',
#    '1H',
#    'DMSO-d6']},
#  'ord-2a7dd5a2634f4111885a0eec3c2d686d': {'llm_species': ['compound 57',
#    'ethyl 4-(2-aminophenoxy)butyrate',
#    '3-[1-(4-fluorobenzhydryl)indol-5-yl]isocrotonic acid',
#    '4-{2-[3-[1-(4-fluorobenzhydryl)indol-5-yl]isocrotonoylamino]phenoxy}butyric acid'],
#   'cde_species': ['ethyl 4-(2-aminophenoxy)butyrate',
#    '3-[1-(4-fluorobenzhydryl)indol-5-yl]isocrotonic acid']},
#  'ord-b1e7dc91b9c84bf4ad37cab39fab4fcb': {'llm_species': ['2-nitro-4-(1H-pyrazol-5-yl)benzonitrile',
#    '(S)-tert-butyl 1-hydroxypropan-2-ylcarbamate',
#    '(S)-4-(1-(2-aminopropyl)-1H-pyrazol-3-yl)-2-nitrobenzonitrile'],
#   'cde_species': ['(S)-4-(1-(2-aminopropyl)-1H-pyrazol-3-yl)-2-nitrobenzonitrile',
#    '2-nitro-4-(1H-pyrazol-5-yl)benzonitrile',
#    '(S)-tert-butyl 1-hydroxypropan-2-ylcarbamate',
#    'H',
#    'DMSO-d6',
#    '1H']},
#  'ord-bff9ee3c94f649798f11c27bb7506fda': {'llm_species': ['compound',
#    'sodium hydroxide',
#    'methanol',
#    'compound'],
#   'cde_species': ['sodium hydroxide', 'methanol']},
#  'ord-4f9c82453a4140aea0a5614e151f05a1': {'llm_species': ['EDC',
#    '3-amino-4-ethylamino-benzoic acid methyl ester',
#    '2-amino-6-(trifluoromethoxy)benzothiazole',
#    '1,1′-thiocarbonyldiimidazole',
#    '1-Ethyl-2-(6-trifluoromethoxy-benzothiazol-2-ylamino)-1H-benzoimidazole-5-carboxylic acid methyl ester'],
#   'cde_species': ['1-Ethyl-2-(6-trifluoromethoxy-benzothiazol-2-ylamino)-1H-benzoimidazole-5-carboxylic acid methyl ester',
#    '3-amino-4-ethylamino-benzoic acid methyl ester',
#    '2-amino-6-(trifluoromethoxy)benzothiazole',
#    '1,1′-thiocarbonyldiimidazole',
#    '1H',
#    'DMSO-d6',
#    '2H',
#    '— NH']},
#  'ord-c82822285e0f4d799e0dc83d6e3ac1a6': {'llm_species': ['2,5-dichloropyrazine',
#    'ammonium hydroxide',
#    'water',
#    'hydrazine hydrate',
#    'title compound'],
#   'cde_species': ['2,5-dichloropyrazine',
#    'ammonium hydroxide',
#    'hydrazine hydrate']},
#  'ord-26d062f1e11645a6b595d16a30ec229a': {'llm_species': ['4-chloro-3-nitrobenzaldehyde',
#    '2,4-pentanedione',
#    '3-[(4-Chloro-3-nitrophenyl)methylene]-2,4-pentanedione'],
#   'cde_species': ['4-chloro-3-nitrobenzaldehyde', '2,4-pentanedione']},
#  'ord-18d5da8321a4460d8bd1850f622bad39': {'llm_species': ['2-[[1-(4′-fluoro-4-biphenylyl)ethylidene]aminoxy]ethyl methanesulfonate',
#    'compound',
#    'ethyl 2-(4-fluorophenoxy)-3-(4-hydroxyphenyl)propionate',
#    'sodium hydride',
#    'Ethyl 3-[4-[2-[[1-(4′-fluoro-4-biphenylyl)ethylidene]aminoxy]ethoxy]phenyl]-2-(4-fluorophenoxy)propionate'],
#   'cde_species': ['ethyl 2-(4-fluorophenoxy)-3-(4-hydroxyphenyl)propionate',
#    'sodium hydride',
#    '2-[[1-(4′-fluoro-4-biphenylyl)ethylidene]aminoxy]ethyl methanesulfonate']},
#  'ord-1fe18075f06543609f9ea5f8c0d8fab2': {'llm_species': ['Intermediate 24a',
#    'hydrogen chloride methanol',
#    'title compound',
#    'hydrochloride'],
#   'cde_species': ['hydrogen chloride', 'methanol', 'hydrochloride']},
#  'ord-8cb82eda3e0d4d2d82583656be16381f': {'llm_species': ['6-acetyl-3-(4-chlorobutyl)-4,5,6,7-tetrahydro-2-methylthieno[2,3-c]pyridine',
#    '4-(6-fluoro-1,2-benzisoxazol-3-yl)piperidine hydrochloride',
#    '6-acetyl-3-(4-(4-(6-fluoro-1,2-benzisoxazol-3-yl)piperidin-1-yl)butyl)-4,5,6,7-tetrahydro-2-methylthieno[2,3-c]pyridine'],
#   'cde_species': ['6-acetyl-3-(4-chlorobutyl)-4,5,6,7-tetrahydro-2-methylthieno[2,3-c]pyridine',
#    '4-(6-fluoro-1,2-benzisoxazol-3-yl)piperidine hydrochloride',
#    '6-acetyl-3-(4-(4-(6-fluoro-1,2-benzisoxazol-3-yl)piperidin-1-yl)butyl)-4,5,6,7-tetrahydro-2-methylthieno[2,3-c]pyridine',
#    '3 / 2oxalate']},
#  'ord-e2adfacbdf2a4e7ab89c0c99b478f8a5': {'llm_species': ['glutaric anhydride',
#    '(aminomethyl)[(RS)-4-methyl-2-[[(S)-3-methyl-1-(methylcarbamoyl)butyl]carbamoyl]pentyl]phosphinic acid ethyl ester acetate',
#    '(glutarimidomethyl)[(RS)-4-methyl-2-[[(S)-3-methyl-1-(methylcarbamoyl)butyl]carbamoyl]pentyl]phosphinic acid ethyl ester'],
#   'cde_species': ['glutaric anhydride',
#    '(aminomethyl)[(RS)-4-methyl-2-[[(S)-3-methyl-1-(methylcarbamoyl)butyl]carbamoyl]pentyl]phosphinic acid ethyl ester acetate',
#    '(glutarimidomethyl)[(RS)-4-methyl-2-[[(S)-3-methyl-1-(methylcarbamoyl)butyl]carbamoyl]pentyl]phosphinic acid ethyl ester']},
#  'ord-e93ca9dc58e244a8a2ab4de6e858e3e4': {'llm_species': ['4-(1,1-dioxo-1λ6-isothiazolidin-2-yl)-2-methanesulfonylbenzoic acid',
#    '1-(5-cyclopropyl-3-methylpyridin-2-yl)piperazine hydrochloride',
#    'title compound'],
#   'cde_species': ['4-(1,1-dioxo-1λ6-isothiazolidin-2-yl)-2-methanesulfonylbenzoic acid',
#    '1-(5-cyclopropyl-3-methylpyridin-2-yl)piperazine hydrochloride']},
#  'ord-f9cd522a891147cab2b720215f438f42': {'llm_species': ['1-(4-aminobutyl)-1H-imidazo[4,5-c]quinolin-4-amine',
#    '4-benzoylbenzoyl chloride',
#    'N1-[4-(4-amino-1H-imidazo[4,5-c]quinolin1-yl)butyl]-4-benzoylbenzamide'],
#   'cde_species': ['1-(4-aminobutyl)-1H-imidazo[4,5-c]quinolin-4-amine',
#    '4-benzoylbenzoyl chloride',
#    'N1-[4-(4-amino-1H-imidazo[4,5-c]quinolin1-yl)butyl]-4-benzoylbenzamide',
#    '1H',
#    'CDCl3',
#    '2H']},
#  'ord-fce70002d024450094bae8b647014b86': {'llm_species': ['compound 6',
#    '4-methoxybenzyl chloride',
#    'N,N-diethyl-4-[(N-4-methoxybenzyl)-phenyl-piperidin-4-ylidene-methyl]-benzamide'],
#   'cde_species': ['4-methoxybenzyl chloride',
#    'N,N-diethyl-4-[(N-4-methoxybenzyl)-phenyl-piperidin-4-ylidene-methyl]-benzamide']},
#  'ord-11575ae34fdd45909ee7e4de3a874ed3': {'llm_species': ['pyrazolo[1,5-a]pyridin-3-ylmethanol',
#    'PBr3',
#    'DCM',
#    '3-(bromomethyl)pyrazolo[1,5-a]pyridine'],
#   'cde_species': ['pyrazolo[1,5-a]pyridin-3-ylmethanol', 'PBr3']},
#  'ord-e3fc16773b5244158b793ee39179b2ab': {'llm_species': ['triethylamine',
#    '1-(4-methylphenyl)-piperazine',
#    '1-chloro-3-bromopropane',
#    'tetrahydrofuran',
#    '1-(3-chloropropyl)-4-(4-methylphenyl)-piperazine'],
#   'cde_species': ['triethylamine',
#    '1-(4-methylphenyl)-piperazine',
#    '1-chloro-3-bromopropane',
#    'tetrahydrofuran',
#    '1-(3-chloropropyl)-4-(4-methylphenyl)-piperazine']},
#  'ord-e8b5d7e5748749209572093afbc13700': {'llm_species': ['diphenyl(pyridin-2-yl)methanol',
#    'thionylchloride',
#    'acetylchloride',
#    'title compound',
#    'hydrochloride salt'],
#   'cde_species': ['diphenyl(pyridin-2-yl)methanol',
#    'thionylchloride',
#    'acetylchloride',
#    'benzene',
#    'hydrochloride']},
#  'ord-2d40804b3d1d41ef8ed6c0f0aea032a4': {'llm_species': ['ethyl 2-(4-chloro-1-methyl-1H-pyrazol-5-yl)-4-methylpyrimidine-5-carboxylate',
#    'N-bromosuccinimide',
#    'carbon tetrachloride',
#    '2,2′-azo-bis-isobutyronitrile',
#    'desired product'],
#   'cde_species': ['ethyl 2-(4-chloro-1-methyl-1H-pyrazol-5-yl)-4-methylpyrimidine-5-carboxylate',
#    'carbon tetrachloride',
#    'N-bromosuccinimide',
#    '2,2′-azo-bis-isobutyronitrile']},
#  'ord-be6d87371a394ed6af0ed554fbf8c5e7': {'llm_species': ['4-cyanobenzaldehyde',
#    '3,5-heptanedione',
#    '4-[(4-Cyanophenyl)methylene]-3,5-heptanedione'],
#   'cde_species': ['4-cyanobenzaldehyde', '3,5-heptanedione']},
#  'ord-bc86f0ca46214502b58f4712be79c442': {'llm_species': ['6-(3-Methoxyphenyl)-1,3-dihydroindol-2-one',
#    '4-(3-dimethylaminopropyl)-3,5-dimethyl-1H-pyrrole-2-carbaldehyde',
#    '3-[4-(3-dimethylaminopropyl)-3,5-dimethyl-1H-pyrrol-2-ylmethylene]-6-(3-methoxyphenyl)-1,3-dihydroindol-2-one'],
#   'cde_species': ['6-(3-Methoxyphenyl)-1,3-dihydroindol-2-one',
#    '4-(3-dimethylaminopropyl)-3,5-dimethyl-1H-pyrrole-2-carbaldehyde',
#    '3-[4-(3-dimethylaminopropyl)-3,5-dimethyl-1H-pyrrol-2-ylmethylene]-6-(3-methoxyphenyl)-1,3-dihydroindol-2-one']},
#  'ord-447c6eb755b149b3bc34f9518b46303b': {'llm_species': ['2-amino-4-bromobenzoic acid',
#    'formamide',
#    '7-bromo-3H-quinazolin-4-one'],
#   'cde_species': ['2-amino-4-bromobenzoic acid',
#    'formamide',
#    '7-bromo-3H-quinazolin-4-one']},
#  'ord-6ab606abd0d247ac8b503937c339ca67': {'llm_species': ['1,2-dichloroethane',
#    'benzoyl chloride',
#    'aluminum chloride',
#    '4-methoxy-5,5,8,8-tetramethyl-5,6,7,8-tetrahydro-1-naphthalenol',
#    '2-benzyl-4-methoxy-5,5,8,8-tetramethyl-5,6,7,8-tetrahydro-1-naphthalenol'],
#   'cde_species': ['4-methoxy-5,5,8,8-tetramethyl-5,6,7,8-tetrahydro-1-naphthalenol',
#    '1,2-dichloroethane',
#    'benzoyl chloride',
#    'aluminum chloride']},
#  'ord-ec0966861535410a9f5027507c3631a5': {'llm_species': ['compound',
#    'THF',
#    'lithium hydroxide',
#    '3-{[3-(4-Chlorophenyl)-5-oxo-4-(3,3,3-trifluoro-2-hydroxypropyl)-4,5-dihydro-1H-1,2,4-triazol-1-yl]methyl}-2′-(trifluoromethyl)biphenyl-4-carboxylic acid'],
#   'cde_species': ['THF', 'lithium hydroxide', 'N hydrochloric acid']},
#  'ord-8b10c63877de44e4aa3bc0537498ecda': {'llm_species': ['2-(6-methanesulfonyl-benzothiazol-2-ylamino)-1-methyl-1H-benzimidazole-5-carboxylic acid methyl ester',
#    'LiOH',
#    '2-(6-Methanesulfonyl-benzothiazol-2-ylamino)-1-methyl-1H-benzimidazole-5-carboxylic acid'],
#   'cde_species': ['2-(6-Methanesulfonyl-benzothiazol-2-ylamino)-1-methyl-1H-benzimidazole-5-carboxylic acid',
#    '2-(6-methanesulfonyl-benzothiazol-2-ylamino)-1-methyl-1H-benzimidazole-5-carboxylic acid methyl ester',
#    'LiOH']},
#  'ord-3f777f26663b4d41a3a4b5a11529ac69': {'llm_species': ['butyl 1-methylcyclopropane-1-sulfonate',
#    'potassium thiocyanate',
#    '1,4-dioxane water',
#    'potassium 1-methylcyclopropane-1-sulfonate'],
#   'cde_species': ['butyl 1-methylcyclopropane-1-sulfonate',
#    'potassium thiocyanate',
#    '1,4-dioxane',
#    'potassium 1-methylcyclopropane-1-sulfonate',
#    'thionyl chloride',
#    'DMF',
#    'MgSO4',
#    '2H',
#    '1-methylcyclopropane-1-sulfonyl chloride']},
#  'ord-3c42ccae9ddd4984a019729e47f303c8': {'llm_species': ['7-fluoro-6-(2-fluoro-4-iodophenylamino)-3-methylisoxazolo[4,3-b]pyridine-5-carboxylic acid',
#    'toluene',
#    'triethylamine',
#    'diphenylphosphoryl azide',
#    'title compound'],
#   'cde_species': ['7-fluoro-6-(2-fluoro-4-iodophenylamino)-3-methylisoxazolo[4,3-b]pyridine-5-carboxylic acid',
#    'toluene',
#    'triethylamine',
#    'diphenylphosphoryl azide',
#    'Silica gel']},
#  'ord-eae172f539294cb0bbf9ba5aa655dd80': {'llm_species': ['1,4-bis(hydroxyethyl) terephthalate',
#    '4-dimethylaminopyridine',
#    'methylene chloride',
#    'ethyl phosphorodichloridate',
#    'methylene chloride',
#    'BHET EOP'],
#   'cde_species': ['argon',
#    '4-dimethylaminopyridine',
#    '1,4-bis(hydroxyethyl) terephthalate',
#    'methylene chloride',
#    'ethyl phosphorodichloridate']},
#  'ord-328db6b80d354417972f4c10c6e216f8': {'llm_species': ['hydrazine hydrate',
#    'ethyl (S)-8-oxo-11,11a-dihydro-8H,10H-azeto[1,2-a]imidazo[5,1-c]thieno[3,2-e][1,4]diazepine-1-carboxylate',
#    'ethanol',
#    '8-oxo-11,11a-dihydro-8H,10H-azeto[1,2-a]imidazo[5,1-c]thieno-[3,2-e][1,4]diazepine-1-carboxylic acid hydrazide'],
#   'cde_species': ['hydrazine hydrate',
#    'ethyl (S)-8-oxo-11,11a-dihydro-8H,10H-azeto[1,2-a]imidazo[5,1-c]thieno[3,2-e][1,4]diazepine-1-carboxylate',
#    'ethanol']},
#  'ord-259cabe92f604dbcb309ddaecc04233f': {'llm_species': ['N-hydroxybenzotriazole',
#    '3-tert-Butylsulfanylmethyl-4-(5-ethoxycarbonylmethyl-2-methoxy-phenoxy)-benzoic acid',
#    'tert-butylamine',
#    'CH2Cl2',
#    '1-ethyl-3-(3′-dimethylaminopropyl)carbodiimide',
#    'title compound'],
#   'cde_species': ['3-tert-Butylsulfanylmethyl-4-(5-ethoxycarbonylmethyl-2-methoxy-phenoxy)-benzoic acid',
#    'tert-butylamine',
#    '1-ethyl-3-(3′-dimethylaminopropyl)carbodiimide',
#    'N-hydroxybenzotriazole',
#    'CH2Cl2']},
#  'ord-848d8943e0b048b1830b08fa53aba9a1': {'llm_species': ['N-acetyl-4-(7-methanesulfonyl-1-heptenyl)-aniline',
#    'NaI',
#    'acetone',
#    'iodide'],
#   'cde_species': ['N-acetyl-4-(7-methanesulfonyl-1-heptenyl)-aniline',
#    'acetone',
#    'NaI',
#    'iodide 534']},
#  'ord-dbaad722343349bdbe9943fb172c3ffd': {'llm_species': ['product',
#    'methanol',
#    'palladium on carbon',
#    'title compound'],
#   'cde_species': ['methanol',
#    'palladium',
#    'carbon',
#    'hydrogen',
#    '1H',
#    'DMSO-d6']},
#  'ord-b3d302cd1a574eb28f977b9ffd2e1631': {},
#  'ord-b9f6dc0cc1f348caa892b067d1da8e10': {'llm_species': ['methyl 5,6-dihydro-2-isothiocyanato-4H-cyclopenta[b]thiophene-3-carboxylate',
#    '3-(4-methyl-1H-imidazol-1-yl)propan-1-amine',
#    '3-[3-(4-methyl-1H-imidazol-1-yl)propyl]-2-thioxo-1,2,3,5,6,7-hexahydro-4H-cyclopenta[4,5]thieno[2,3-d]pyrimidin-4-one'],
#   'cde_species': ['methyl 5,6-dihydro-2-isothiocyanato-4H-cyclopenta[b]thiophene-3-carboxylate',
#    '3-(4-methyl-1H-imidazol-1-yl)propan-1-amine']},
#  'ord-580f462ef7d04ae5a04bd74bdfd421f2': {'llm_species': ['BSTFA',
#    'benzyl bromide',
#    'CH2Cl2',
#    '2-({6-[(tert-Butoxycarbonyl)amino]pyridin-3-yl}methyl)-3-ethoxy-3-oxopropylphosphinic acid',
#    'benzyl[2-({6-[(tert-butoxycarbonyl)amino]pyridin-3-yl}methyl)-3-ethoxy-3-oxopropyl]phosphinic acid'],
#   'cde_species': ['BSTFA',
#    'benzyl bromide',
#    'CH2Cl2',
#    '2-({6-[(tert-Butoxycarbonyl)amino]pyridin-3-yl}methyl)-3-ethoxy-3-oxopropylphosphinic acid',
#    'benzyl[2-({6-[(tert-butoxycarbonyl)amino]pyridin-3-yl}methyl)-3-ethoxy-3-oxopropyl]phosphinic acid',
#    'Argon']},
#  'ord-426655152976490eb71b9c1308a86212': {'llm_species': ['ammonium formate',
#    '3-(formylamino)-2-thiophenecarboxylic acid methyl ester',
#    'formamide',
#    '3H-thieno[3,2-d]pyrimid-4-one'],
#   'cde_species': ['ammonium formate',
#    'formamide',
#    '3-(formylamino)-2-thiophenecarboxylic acid methyl ester',
#    '3H-thieno[3,2-d]pyrimid-4-one']},
#  'ord-63e7749e91db4aa2ba613a257213b439': {'llm_species': ['Thionyl chloride',
#    'methanol',
#    '3-(4-nitrophenyl)-acrylic acid',
#    'title compound',
#    'crystals'],
#   'cde_species': ['Thionyl chloride',
#    '1H',
#    'DMSO-d6',
#    'HMDSO',
#    '2H',
#    'methanol',
#    '3-(4-nitrophenyl)-acrylic acid']},
#  'ord-940d109b76204565a331fa21e8094727': {'llm_species': ['2-(4-nitrobenzyl)-1,3,2-dioxaphospholane-2-oxide',
#    'palladium-carbon',
#    'methanol',
#    '2-(4-aminobenzyl)-1,3,2-dioxaphospholane-2-oxide'],
#   'cde_species': ['2-(4-nitrobenzyl)-1,3,2-dioxaphospholane-2-oxide',
#    'palladium-carbon',
#    'methanol',
#    'ethanol-hexane',
#    '2-(4-aminobenzyl)-1,3,2-dioxaphospholane-2-oxide']},
#  'ord-d892c17472244c0eb000762b3c79055c': {'llm_species': ['(R)-2-methylpropane-2-sulfinamide',
#    'Intermediate 12A',
#    'THF',
#    'tetraethoxytitanium',
#    '(R,E)-N-(1-(3-Bromo-2-methylphenyl)ethylidene)-2-methylpropane-2-sulfinamide'],
#   'cde_species': ['(R)-2-methylpropane-2-sulfinamide',
#    'THF',
#    'tetraethoxytitanium']},
#  'ord-745b46e86de743059f05fa2396831600': {'llm_species': ['4-Pyridinecarboxaldehyde oxime',
#    'chloroform',
#    'N-hydroxy-4-pyridine-carboximidoyl chloride'],
#   'cde_species': ['4-Pyridinecarboxaldehyde oxime',
#    'chloroform',
#    'N-hydroxy-4-pyridine-carboximidoyl chloride',
#    '2-chloroethanethiol',
#    'triethylamine',
#    '2-chloroethyl N-hydroxy-4-pyridinecarboximidothioate',
#    'ester',
#    'sodium ethoxide',
#    'sodium',
#    'ethanol',
#    'N',
#    'C8H8N2OS',
#    'ether',
#    '5,6-dihydro-3-(4-pyridinyl)-1,4,2-oxathiazine',
#    'H']},
#  'ord-fa1975c3a7b34f7bb85d400bd161b860': {'llm_species': ['methyl 3,4-methylenedioxyphenylacetate',
#    '3-nitrobenzoic acid',
#    'P2O5',
#    'ClCH2CH2Cl',
#    'title compound'],
#   'cde_species': ['methyl 3,4-methylenedioxyphenylacetate',
#    'ClCH2CH2Cl',
#    '3-nitrobenzoic acid',
#    'P2O5',
#    '1H',
#    'CDCl3',
#    '2H']},
#  'ord-e01d0f3be9c34b7c9165be46cfa4c3d2': {'llm_species': ['product',
#    'iodoethane',
#    'desired product'],
#   'cde_species': ['iodoethane']},
#  'ord-d79d28c66ce843e6838bd320be857a5a': {'llm_species': ['solution',
#    'DMF',
#    'methyl iodide',
#    'AcN',
#    'desired product'],
#   'cde_species': ['AcN',
#    'DMF',
#    'silver ( I ) oxide',
#    'methyl iodide',
#    'Celite',
#    'silica gel',
#    'CH2Cl2',
#    'MeOH']},
#  'ord-780d6933f3904cf4b137172dbec4c2c2': {'llm_species': ['EtOH',
#    '4,4-dimethylamino-2-nitro-N-quinolin-8-yl-benzenesulfonamide',
#    'SnCl2',
#    'HCl',
#    'title compound'],
#   'cde_species': ['4,4-dimethylamino-2-nitro-N-quinolin-8-yl-benzenesulfonamide',
#    'SnCl2',
#    '6N HCl',
#    'EtOH']},
#  'ord-4f834d7d8b094e70bbbbe295e10d9d81': {'llm_species': ['3-cyano-1-ethoxycarbonyl- 2-methylthio-4H-quinolizin-4-one',
#    'piperidine',
#    'acetonitrile',
#    '3-cyano-1-ethoxycarbonyl-2-piperidino-4H-quinolizin-4-one'],
#   'cde_species': ['3-cyano-1-ethoxycarbonyl- 2-methylthio-4H-quinolizin-4-one',
#    'piperidine',
#    'acetonitrile',
#    'silica gel',
#    'ethyl acetate',
#    'n-hexane',
#    '3-cyano-1-ethoxycarbonyl-2-piperidino-4H-quinolizin-4-one']},
#  'ord-1aefffd5a52a49589097a4e638caaf66': {'llm_species': ['toluene',
#    '1,4,4a,9a-tetrahydro-anthraquinone',
#    'palladium',
#    '1,2,3,4-tetrahydro-9,10-anthracene-diol',
#    '1,2,3,4,4a,9a-hexahydro-9,10-anthracene-dione'],
#   'cde_species': ['1,4,4a,9a-tetrahydro-anthraquinone',
#    'toluene',
#    'palladium',
#    '1,2,3,4-tetrahydro-9,10-anthracene-diol',
#    '1,2,3,4,4a,9a-hexahydro-9,10-anthracene-dione']},
#  'ord-9b5684e4d4b64e309ddc3f33f75ba163': {'llm_species': ['(S)—N-(3-(4-amino-6-((1-(5-methyl-4-oxo-3-phenyl-3,4-dihydropyrrolo[2,1-f][1,2,4]triazin-2-yl)ethyl)amino)pyrimidin-5-yl)-5-hydroxyphenyl)-4-methoxybenzenesulfonamide',
#    'boron tribromide',
#    'dichloromethane',
#    '(S)—N-(3-(4-Amino-6-((1-(5-methyl-4-oxo-3-phenyl-3,4-dihydropyrrolo[2,1-f][1,2,4]triazin-2-yl)ethyl)amino)pyrimidin-5-yl)-5-hydroxyphenyl)-4-hydroxybenzenesulfonamide'],
#   'cde_species': ['( S )—N-(3-(4-amino-6-((1-(5-methyl-4-oxo-3-phenyl-3,4-dihydropyrrolo[2,1-f][1,2,4]triazin-2-yl)ethyl)amino)pyrimidin-5-yl)-5-hydroxyphenyl)-4-methoxybenzenesulfonamide',
#    'boron tribromide',
#    'dichloromethane']},
#  'ord-7c6f373996344aceb7044a35a5b4e030': {'llm_species': ["4,4'-thiobis(N-phenyl-1,2,3,6-tetrahydrophthalimide)",
#    'sulfur',
#    "4,4'-thiobis(N-phenylphthalimide)"],
#   'cde_species': ["4,4'-thiobis(N-phenyl-1,2,3,6-tetrahydrophthalimide)",
#    'sulfur',
#    'silica gel',
#    'methanol',
#    "4,4'-thiobis(N-phenylphthalimide)",
#    '1H',
#    'DMSO-d6',
#    'dichloromethane']},
#  'ord-9c07b3faec4c4f6a9ef82117e36a8bb9': {'llm_species': ['n-butyl lithium',
#    'isopropyltriphenylphosphonium iodide',
#    '1-tert-butoxycarbonyl-4-[N-methyl-N-(3-(formyl)-2-pyridinyl)amino]piperidine',
#    'title compound'],
#   'cde_species': ['n-butyl lithium',
#    'isopropyltriphenylphosphonium iodide',
#    '1-tert-butoxycarbonyl-4-[N-methyl-N-(3-(formyl)-2-pyridinyl)amino]piperidine',
#    'CDCl3']},
#  'ord-283fd835c1c544ffb04fed3235478541': {'llm_species': ['benzoyl chloride',
#    '1B',
#    'triethylamine',
#    'methylene chloride',
#    '1-benzoyl-3-methyl-2-(nitro(phenylthio)methylene)-imidazolidine'],
#   'cde_species': ['benzoyl chloride',
#    'triethylamine',
#    'methylene chloride',
#    'methanol']},
#  'ord-090d3f57c1194b33ae54de1ec6001444': {'llm_species': ['compound 5',
#    "Lawesson's Reagent",
#    '1,4-dioxane',
#    'compound 6'],
#   'cde_species': ["Lawesson 's Reagent", '1,4-dioxane']},
#  'ord-dfbb4c7f5367419fa644dfef66808de4': {'llm_species': ['N,N-diethylhydroxylamine',
#    'N-phenylmaleimide',
#    'N-Phenyl-3-[(N,N-diethylamino)oxy]pyrrolidine-2,5-dione'],
#   'cde_species': ['N,N-diethylhydroxylamine', 'N-phenylmaleimide']},
#  'ord-d749bf187fc74aa4ba0de212e2348eb1': {'llm_species': ['tributyl-(7-[1,3]dioxan-2-yl-benzofuran-5-yl)stannane',
#    'lead tetraacetate',
#    'mercuric acetate',
#    'chloroform',
#    'title compound'],
#   'cde_species': ['tributyl-(7-[1,3]dioxan-2-yl-benzofuran-5-yl)stannane',
#    'lead tetraacetate',
#    'mercuric acetate',
#    'chloroform',
#    'hexane']},
#  'ord-d63adb2b9d1c408ca1d96feb1cdc8d48': {'llm_species': ['3-(4-chloro-1,2,5-thiadiazol-3-yl)pyridine',
#    'methyl iodide',
#    'acetone',
#    'title compound'],
#   'cde_species': ['3-(4-chloro-1,2,5-thiadiazol-3-yl)pyridine',
#    'methyl iodide',
#    'acetone']},
#  'ord-9ace31efa6e34e51bd0989f6522abf32': {'llm_species': ['4,5-dihydrothieno[3,2-e][1,3]benzothiazol-2-amine',
#    '4-n-propylbenzenesulfonyl chloride',
#    'title compound',
#    'powder'],
#   'cde_species': ['4,5-dihydrothieno[3,2-e][1,3]benzothiazol-2-amine',
#    '4-keto-4,5,6,7-tetrahydrothianaphthene',
#    '4-n-propylbenzenesulfonyl chloride']},
#  'ord-a857ff382b0a4e8abaa8d4ebf918fd2d': {'llm_species': ['compound',
#    '2-benzyl-pyridine',
#    'acetone',
#    'title compound'],
#   'cde_species': ['2-benzyl-pyridine',
#    'acetone',
#    'silica gel',
#    'cyclohexane']},
#  'ord-0e74971d7fe64fde8626ef2e8a1b7f43': {'llm_species': ['1H-benzotriazole',
#    'pyridine-2-carbaldehyde',
#    'tert-butyl 1-piperazine-carboxylate',
#    'benzene',
#    'title compound'],
#   'cde_species': ['pyridine-2-carbaldehyde',
#    'benzene',
#    'nitrogen',
#    'tert-butyl 1-piperazine-carboxylate',
#    '1H-benzotriazole']},
#  'ord-dae3791ec170493989d8ef682a1b7e21': {'llm_species': ['2,4-Dichloropyrimidine',
#    'MeOH',
#    'H2O',
#    '3-amino-4-methylaniline',
#    'N2,N4-bis(3-amino-4-methylphenyl)-2,4-pyrimidinediamine'],
#   'cde_species': ['2,4-Dichloropyrimidine',
#    'MeOH',
#    'H2O',
#    '3-amino-4-methylaniline',
#    'silica gel',
#    'CHCl3-Acetone',
#    '1H',
#    'CD3OD',
#    '2H',
#    'N2,N4-bis(3-amino-4-methylphenyl)-2,4-pyrimidinediamine']},
#  'ord-e9e942f8a1c543739f84664245119587': {'llm_species': ['HATU',
#    'DMF',
#    '2-(4-(piperazin-1-yl)quinazolin-2-yl)phenol',
#    '2-hydroxyhexanoic acid',
#    'DMF',
#    'Triethylamine',
#    '2-hydroxy-1-(4-(2-(2-hydroxyphenyl)quinazolin-4-yl)piperazin-1-yl)-2-methylbutan-1-one'],
#   'cde_species': ['2-(4-(piperazin-1-yl)quinazolin-2-yl)phenol',
#    '2-hydroxyhexanoic acid',
#    'Triethylamine',
#    '2-hydroxy-1-(4-(2-(2-hydroxyphenyl)quinazolin-4-yl)piperazin-1-yl)-2-methylbutan-1-one',
#    'DMF',
#    'CH3CN',
#    'TFA']},
#  'ord-d602c547b2d447c5a70a59f83b9251c5': {'llm_species': ['Octyldimethylamine',
#    'triethylamine borane',
#    'triethylamine',
#    'N-octyl-N,N-dimethylamine borane'],
#   'cde_species': ['Octyldimethylamine',
#    'triethylamine borane',
#    'triethylamine',
#    'N-octyl-N,N-dimethylamine borane',
#    'Hg']},
#  'ord-025c17bd9dbb45488c288c61cdeea04d': {'llm_species': ['methanol',
#    'N-hydroxy-3-(trifluoromethyl)benzimidoylchloride',
#    'methylacetoacetate',
#    'sodium methoxide',
#    'required compound'],
#   'cde_species': ['methanol',
#    'N-hydroxy-3-(trifluoromethyl)benzimidoylchloride',
#    'methylacetoacetate',
#    'sodium methoxide']},
#  'ord-c2bf9a5c7ccf473eadc7eb26bc2a6bfe': {'llm_species': ['3-(3-(2-thienyl)isoxazol-5-yl)butanal',
#    '1-benzylpiperazine',
#    'methylene chloride',
#    'NaBH(OAc)3',
#    'acetic acid',
#    'target compound'],
#   'cde_species': ['3-(3-(2-thienyl)isoxazol-5-yl)butanal',
#    '1-benzylpiperazine',
#    'methylene chloride',
#    'NaBH(OAc)3',
#    'acetic acid']},
#  'ord-e09ee0015e7e4765a30d8c83d04f33c2': {'llm_species': ['2-(2-Methylphenylamino)-4-quinazolone',
#    'phosphoryl chloride',
#    'N,N-dimethylaniline',
#    '4-chloro-2-(2-methylphenylamino)quinazoline hydrochloride'],
#   'cde_species': ['2-(2-Methylphenylamino)-4-quinazolone',
#    'phosphoryl chloride',
#    'N,N-dimethylaniline',
#    'N NaoH',
#    '4-chloro-2-(2-methylphenylamino)quinazoline hydrochloride']},
#  'ord-4c6f9245f5474f7d8e739c2cd5244c84': {'llm_species': ['N-isopropyl-1,3-propanediamine',
#    'isopropyl alcohol',
#    'HCHO',
#    'N-isopropylhexahydropyrimidine'],
#   'cde_species': ['N-isopropyl-1,3-propanediamine',
#    'isopropyl alcohol ( 1 l )',
#    'HCHO',
#    'N-isopropylhexahydropyrimidine',
#    'Bp']},
#  'ord-51045c68a09f46b1835b041101334446': {'llm_species': ['6-chloronicotinic acid',
#    'ethanol',
#    'dicyclohexylcarbodiimide',
#    'dimethylaminopyridine',
#    'methylene chloride',
#    'title compound'],
#   'cde_species': ['6-chloronicotinic acid',
#    'ethanol',
#    'dicyclohexylcarbodiimide',
#    'dimethylaminopyridine',
#    'methylene chloride',
#    'CDCl3',
#    '2H',
#    '1H']},
#  'ord-28497673a4cf40378707ee85515239ef': {'llm_species': ['Ethyl chloroformate',
#    'product',
#    'diisopropylethylamine',
#    'tetrahydrofuran',
#    'title compound'],
#   'cde_species': ['Ethyl chloroformate',
#    'diisopropylethylamine',
#    'tetrahydrofuran',
#    'silica',
#    'SiO2',
#    'ethyl acetate']},
#  'ord-1613439be3ac4d71bb462b15aa1cd772': {'llm_species': ['8-(5-{[2-(2-chlorophenyl)ethyl]amino}pentanoyl)-5,6-dihydro-4H-pyrrolo[3,2,1-ij]quinolin-2 (1H)-one hydrochloride',
#    'oxalic acid',
#    'title compound',
#    'crystals'],
#   'cde_species': ['8-(5-{[2-(2-chlorophenyl)ethyl]amino}pentanoyl)-5,6-dihydro-4H-pyrrolo[3,2,1-ij]quinolin-2 (1H)-one hydrochloride',
#    'oxalic acid']},
#  'ord-f09b80b9632e437da29bd35fd46b753c': {'llm_species': ['29',
#    'phosgene toluene',
#    'DCM TEA',
#    '2-(14-(4-Isocyanatophenoxy)-3,6,9,12-tetraoxatetradecyloxy)tetrahydro-2H-pyran'],
#   'cde_species': ['TEA', 'phosgene', 'toluene']},
#  'ord-56f5a781ae59490eac75bc853f7a69c9': {'llm_species': ['[1-[3-(3-pyridinyl)-propyl)-4-(3-pyridinyl)butyl]carbamic acid 1,1-dimethylethyl ester',
#    'HCl',
#    'alpha-[3-(3-pyridinyl)propyl]-3-pyridinebutanamine'],
#   'cde_species': ['[ 1-[3-(3-pyridinyl)-propyl)-4-(3-pyridinyl)butyl]carbamic acid 1,1-dimethylethyl ester',
#    '1N HCl',
#    'alpha-[3-(3-pyridinyl)propyl]-3-pyridinebutanamine']},
#  'ord-1647560b948c4231a6a19d7216f8b6f6': {'llm_species': ['3-(methylamino)propanol',
#    'iodododecane',
#    'title material'],
#   'cde_species': ['3-(methylamino)propanol', 'iodododecane']},
#  'ord-396ed484b3bb4ac681d044f239142f9d': {'llm_species': ['trifluoro-methanesulfonic acid 6′-methyl-6-trifluoromethyl-[3,4′]bipyridinyl-2′-yl ester',
#    '3-bromo-benzene-boronic acid',
#    'title compound',
#    'solid'],
#   'cde_species': ['trifluoro-methanesulfonic acid 6′-methyl-6-trifluoromethyl-[3,4′]bipyridinyl-2′-yl ester',
#    '3-bromo-benzene-boronic acid']},
#  'ord-9ee7c56139474d89bc50d1e9f75beeed': {'llm_species': ['5-[3,5-bis(trifluoromethyl)benzyl]-9-chloro-6-oxo-7-phenyl-2,3,4,5-tetrahydro-6H-pyrido[2,3-b][1,5]oxazocine',
#    '4-(piperidine-1-yl)piperidine',
#    '5-[3,5-bis(trifluoromethyl)benzyl]-6-oxo-7-phenyl-9-[4-(piperidine-1-yl)piperidine-1-yl]-2,3,4,5-tetrahydro-6H-pyrido[2,3-b][1,5]oxazocine'],
#   'cde_species': ['5-[3,5-bis(trifluoromethyl)benzyl]-9-chloro-6-oxo-7-phenyl-2,3,4,5-tetrahydro-6H-pyrido[2,3-b][1,5]oxazocine',
#    '4-(piperidine-1-yl)piperidine',
#    '5-[3,5-bis(trifluoromethyl)benzyl]-6-oxo-7-phenyl-9-[4-(piperidine-1-yl)piperidine-1-yl]-2,3,4,5-tetrahydro-6H-pyrido[2,3-b][1,5]oxazocine']},
#  'ord-7a1799ae226b4b40a2f156e40c1df13e': {'llm_species': ['methyl (1SR)-1hydroxy-3-[2-(2-benzyloxyeth-1-yloxy)-4-methoxyphenyl]-1-(3,4-methylenedioxy phenyl)-5-propoxyindene-2-carboxylate',
#    'ethanol',
#    'ethylacetate',
#    'white solid'],
#   'cde_species': ['methyl (1SR)-1hydroxy-3-[2-(2-benzyloxyeth-1-yloxy)-4-methoxyphenyl]-1-(3,4-methylenedioxy phenyl)-5-propoxyindene-2-carboxylate',
#    'palladium',
#    'carbon',
#    'ethylacetate',
#    'ethanol']},
#  'ord-4ffe55b3c4464e739ecf9db1906a1b36': {'llm_species': ['omeprazole',
#    '(S)-1,1,2-triphenyl-1,2-ethanediol',
#    'anisole',
#    '(S)-omeprazole'],
#   'cde_species': ['omeprazole',
#    '(S)-1,1,2-triphenyl-1,2-ethanediol',
#    '(S)-omeprazole.2[(S)-1,1,2-triphenyl-1,2-ethanediol]',
#    'anisole']},
#  'ord-4e0d56fe4f864d9092e91eb1a2823e42': {'llm_species': ['2-methoxycarbonyl-3-chloro-4-methylthiophene',
#    'N-bromosuccinimide',
#    'benzoyl peroxide',
#    'benzene',
#    '2-methoxycarbonyl-3-chloro-4-(bromomethyl)thiophene'],
#   'cde_species': ['2-methoxycarbonyl-3-chloro-4-methylthiophene',
#    'dry benzene',
#    'N-bromosuccinimide',
#    'benzoyl peroxide',
#    'silica gel',
#    '2-methoxycarbonyl-3-chloro-4-(bromomethyl)thiophene',
#    'CDCl3']},
#  'ord-82e9aa5df29743018415d1b0b5f015fc': {'llm_species': ['2-amino-N-(1-(3-(2,2,2-trifluoroethoxy)phenyl)ethyl)pyrimidine-4-carboxamide',
#    'acetyl chloride',
#    'title compound'],
#   'cde_species': ['2-amino-N-(1-(3-(2,2,2-trifluoroethoxy)phenyl)ethyl)pyrimidine-4-carboxamide',
#    'acetyl chloride']},
#  'ord-89ec653f905642b08d1b0a31e674c933': {'llm_species': ['(S)-5-hydroxymethylpyrrolidin-2-one',
#    '(4-bromo-2-methanesulfonylphenyl)[4-(5-cyclopropyl-3-methylpyridin-2-yl)piperazin-1-yl]methanone',
#    'title compound'],
#   'cde_species': ['(S)-5-hydroxymethylpyrrolidin-2-one',
#    '(4-bromo-2-methanesulfonylphenyl)[4-(5-cyclopropyl-3-methylpyridin-2-yl)piperazin-1-yl]methanone']},
#  'ord-d677f236747744e390fffb170bb46e9d': {'llm_species': ['4-(1-N-trifluoroacetyl-4-piperazinyl)nitrophenol',
#    'DMF MeOH',
#    'Pd/C',
#    'title compound'],
#   'cde_species': ['4-(1-N-trifluoroacetyl-4-piperazinyl)nitrophenol',
#    'DMF',
#    'MeOH',
#    'Pd / C',
#    'Celite']},
#  'ord-05c33bca3dbe448381e39e4148d39966': {'llm_species': ['hydrazine hydrate',
#    'ethanol',
#    'methyl 2-bromo-3-(but-2-ynyl)-5-formyl-3H-imidazol-4-carboxylate',
#    'ethanol',
#    'acetic acid',
#    '2-bromo-3-(but-2-ynyl)-3,5-dihydro-imidazo[4,5-d]pyridazin-4-one'],
#   'cde_species': ['hydrazine hydrate',
#    'methyl 2-bromo-3-(but-2-ynyl)-5-formyl-3H-imidazol-4-carboxylate',
#    'acetic acid',
#    'diethyl ether',
#    'ethanol']},
#  'ord-31532b70e2fc45128b535801b8deded3': {'llm_species': ['1-(1H-indol-3-yl)-1-prop-2-enone',
#    'imidazole',
#    'title compound'],
#   'cde_species': ['1-(1H-indol-3-yl)-1-prop-2-enone', 'imidazole', 'EtOH']},
#  'ord-e9397904159147669d9ee75f96efd00c': {'llm_species': ['Methyl 5-chloro-4-[(1Z)-1-(1-ethyl-2-methylidenehydrazino)-1-propen-1-yl]-2-thiophenecarboxylate',
#    '1-chloro-2,5-pyrrolidinedione',
#    'THF',
#    'title compound'],
#   'cde_species': ['Methyl 5-chloro-4-[(1Z)-1-(1-ethyl-2-methylidenehydrazino)-1-propen-1-yl]-2-thiophenecarboxylate',
#    '1-chloro-2,5-pyrrolidinedione',
#    'THF',
#    'N2',
#    'silica',
#    'EtOAc',
#    'Hex']},
#  'ord-3032422ebbad406eb2e9afa32addf112': {'llm_species': ['tert-butyl [(3R)-1-(cis-2-azidocyclohexyl)pyrrolidin-3-yl]carbamate',
#    'HCl dioxane',
#    'title compound'],
#   'cde_species': ['tert-butyl [(3R)-1-(cis-2-azidocyclohexyl)pyrrolidin-3-yl]carbamate',
#    'N HCl',
#    'dioxane',
#    'HCl']},
#  'ord-cb88b054dcd74f6cb860c4704ac7fa26': {'llm_species': ['2-aminopyrimidine',
#    'o-bromophenyl chloromethyl sulfide',
#    'xylene',
#    'xylene',
#    'named compound'],
#   'cde_species': ['2-aminopyrimidine',
#    'xylene',
#    'o-bromophenyl chloromethyl sulfide']},
#  'ord-19b784f30ccf444d8f16088a5716e50c': {'llm_species': ['product',
#    'sodium hydrosulfide',
#    'water',
#    'objective compound'],
#   'cde_species': ['sodium hydrosulfide',
#    'nitrogen',
#    'ethyl acetate',
#    'hydrochloric acid',
#    'ethanol']},
#  'ord-e2acb92f3431444ba70e40fd92164ba6': {'llm_species': ['4,4′-(2-phenylbut-1-ene-1,1-diyl)diphenol',
#    '(1-methylpyrrolidin-2-yl)methanol',
#    'desired product'],
#   'cde_species': ['4,4′-(2-phenylbut-1-ene-1,1-diyl)diphenol',
#    '(1-methylpyrrolidin-2-yl)methanol',
#    'DL-proline']},
#  'ord-ba9849323a19496ba81e3a24ad1c1fbf': {'llm_species': ['(7-ethyl-3-methyl-1H-indol-2-yl)methanol',
#    'dichloromethane',
#    'manganese (IV) oxide',
#    'title compound'],
#   'cde_species': ['(7-ethyl-3-methyl-1H-indol-2-yl)methanol',
#    'manganese ( IV ) oxide',
#    'dichloromethane',
#    '1H',
#    'CDCl3',
#    '2H']},
#  'ord-084c9ee515b74fa699a13e7057eb38c9': {'llm_species': ['5-amino-3-(1-tert-butoxycarbonylpiperidin-4-yl)pyrrolo[3,2-b]pyridine',
#    '2-thiophenecarbonyl chloride',
#    'title compound'],
#   'cde_species': ['2-thiophenecarbonyl chloride']},
#  'ord-df132fc2d46d403ea3772ff03878e394': {'llm_species': ['(C2H5)3N',
#    '1,4-dichloro-2-(dichloromethyl)silyl-2-butene',
#    'THF',
#    '(C2H5)2O',
#    'CH3OH',
#    '1,4-dichloro-2-(dimethoxymethyl)silyl-2-butene'],
#   'cde_species': ['1,4-dichloro-2-(dichloromethyl)silyl-2-butene',
#    'THF',
#    'CH3OH',
#    '(C2H5)3N',
#    '(C2H5)2O',
#    '1,4-dichloro-2-(dimethoxymethyl)silyl-2-butene']},
#  'ord-58067f24ed554c33a8e230d7d4ed92f6': {'llm_species': ['5-methoxyoxindole',
#    '(E)-ethyl 3-(6-formyl-1H-indazol-3-yl)acrylate',
#    'title compound'],
#   'cde_species': ['5-methoxyoxindole',
#    '(E)-ethyl 3-(6-formyl-1H-indazol-3-yl)acrylate',
#    '1H',
#    'DMSO-d6',
#    'NH',
#    '2H',
#    '[C22H19N3O4+H]+']},
#  'ord-7d11691e919f4cbeb111796a8ecddd70': {'llm_species': ['4-Phenyl-thiazol-2-ylamine',
#    '4-methyl-benzoyl chloride',
#    'pyridine',
#    '4-Methyl-N-(4-phenyl-thiazol-2-yl)-benzamide'],
#   'cde_species': ['4-Phenyl-thiazol-2-ylamine',
#    '4-methyl-benzoyl chloride',
#    'pyridine']},
#  'ord-00df01cf9253446fa6d90b2b95984076': {'llm_species': ['{4-[3,3-Bis-(4-chloro-phenyl)-allylsulfanyl]-2-methyl-phenoxy}-acetic acid methyl ester',
#    'ethanol',
#    'NaOH',
#    'HCl',
#    'title compound'],
#   'cde_species': ['{4-[3,3-Bis-(4-chloro-phenyl)-allylsulfanyl]-2-methyl-phenoxy}-acetic acid methyl ester',
#    'ethanol',
#    '1N NaOH',
#    '1N HCl',
#    'dichloromethane']},
#  'ord-eeace4fcc43e4777b4feeb1386df0411': {'llm_species': ['compound',
#    'potassium tert-butylate',
#    'ether',
#    'Trans-2-(7-methoxy-1-naphthyl)-1-cyclopropanecarboxylic Acid'],
#   'cde_species': ['ether', 'potassium tert-butylate']},
#  'ord-501aa2d6f0444c1489ef71c17a584f48': {'llm_species': ['sodium hydroxide',
#    'ethyl 3-(4-amino-3-methoxybenzoyl)-2-methyl-1-indolizinecarboxylate',
#    'dioxane',
#    '3-(4-Amino-3-methoxybenzoyl)-2-methylindolizin-1-ylcarboxylic acid'],
#   'cde_species': ['N sodium hydroxide',
#    'ethyl 3-(4-amino-3-methoxybenzoyl)-2-methyl-1-indolizinecarboxylate',
#    'dioxane']},
#  'ord-ba6da012a76c4c85a8fb351576e79c83': {'llm_species': ['3-(3-methoxy-3-methylbut-1-yl)-5-methylcyclohex-5-en-1-one',
#    '2-propanol',
#    'Raney nickel',
#    '3(3-methoxy-3-methylbut-1-yl)-5-methylcyclohexan-1ol'],
#   'cde_species': ['3-(3-methoxy-3-methylbut-1-yl)-5-methylcyclohex-5-en-1-one',
#    '2-propanol',
#    'Raney nickel',
#    'hydrogen',
#    '3(3-methoxy-3-methylbut-1-yl)-5-methylcyclohexan-1ol']},
#  'ord-6a73d5676b19417fadfa2d4d3545f8b9': {'llm_species': ['2-(3′-Chloro-4′-fluoro-biphenyl-3-yl)-1-(R)-(3-methyl-[1,2,4]oxadiazol-5-yl)-ethylamine hydrochloride salt',
#    '4-Methoxy-4′-trifluoromethyl-biphenyl-3-carboxylic acid',
#    '4-Methoxy-4′-trifluoromethyl-biphenyl-3-carboxylic acid [2-(3′-chloro-4′-fluoro-biphenyl-3-yl)-1-(R)-(3-methyl-[1,2,4]oxadiazol-5-yl)-ethyl]-amide'],
#   'cde_species': ['4-Methoxy-4′-trifluoromethyl-biphenyl-3-carboxylic acid [2-(3′-chloro-4′-fluoro-biphenyl-3-yl)-1-(R)-(3-methyl-[1,2,4]oxadiazol-5-yl)-ethyl]-amide',
#    '2-(3′-Chloro-4′-fluoro-biphenyl-3-yl)-1-(R)-(3-methyl-[1,2,4]oxadiazol-5-yl)-ethylamine hydrochloride',
#    '[2-(3′-Chloro-4′-fluoro-biphenyl-3-yl)-1-(R)-(3-methyl-[1,2,4]oxadiazol-5-yl)-ethyl]-carbamic acid tert-butylester',
#    '4-Methoxy-4′-trifluoromethyl-biphenyl-3-carboxylic acid']},
#  'ord-b869f96b244b44c3a8b7079841017ce2': {'llm_species': ['2-(pyrimidin-4-yl)-6,7,8,9-tetrahydro-4H-pyrimido[1,2-a]pyrimidin-4-one',
#    'acetic acid',
#    'N-chlorosuccinimide',
#    '3-Chloro-2-(pyrimidin-4-yl)-6,7,8,9-tetrahydro-4H-pyrimido[1,2-a]pyrimidin-4-one'],
#   'cde_species': ['2-(pyrimidin-4-yl)-6,7,8,9-tetrahydro-4H-pyrimido[1,2-a]pyrimidin-4-one',
#    'acetic acid',
#    'N-chlorosuccinimide']},
#  'ord-4b4ddbc651364dc68a43cf019831a143': {'llm_species': ['(Z)-tert-butyl 2-fluoro-4-(3,3,3-trifluoroprop-1-enyl)benzoate',
#    'CH2Cl2',
#    'TFA',
#    '(Z)-2-fluoro-4-(3,3,3-trifluoroprop-1-enyl)benzoic acid'],
#   'cde_species': ['(Z)-tert-butyl 2-fluoro-4-(3,3,3-trifluoroprop-1-enyl)benzoate',
#    'CH2Cl2',
#    'TFA']},
#  'ord-fb2e79a070a44999bc5a7a7d189ff950': {'llm_species': ['1-(4-aminophenyl)-4-methyl-7,8-methylenedioxy-5H-2,3-benzodiazepine',
#    'glutaric acid anhydride',
#    'dichloromethane',
#    'pure aimed product'],
# ...
#    'CH3CN',
#    '9-fluorenylmethyloxycarbonyl chloride']},
#  'ord-d11ffa31ccc04869aa758baeac91529a': {'llm_species': ['methyl 5-(benzyloxy)-2′,6′-dimethylbiphenyl-3-carboxylate',
#    'lithium aluminum hydride',
#    'tetrahydrofuran',
#    'Sodium sulfate decahydrate',
#    'title compound'],
#   'cde_species': ['methyl 5-(benzyloxy)-2′,6′-dimethylbiphenyl-3-carboxylate',
#    'tetrahydrofuran',
#    'lithium aluminum hydride',
#    'nitrogen',
#    'Sodium sulfate decahydrate']},
#  'ord-0c4c1570577448dab11c90667dfd1cce': {'llm_species': ['3-(3,4-Dichlorophenyl)-3-(5-aminocarbonyl-2-methyl-3-oxo-2,3-dihydro-1H-isoindol-1-yl)propionaldehyde',
#    '4-(2-oxoperhydropyrimidine-1-yl)piperidine',
#    'title compound'],
#   'cde_species': ['3-(3,4-Dichlorophenyl)-3-(5-aminocarbonyl-2-methyl-3-oxo-2,3-dihydro-1H-isoindol-1-yl)propionaldehyde',
#    '4-(2-oxoperhydropyrimidine-1-yl)piperidine',
#    'hydrochloride',
#    'C27H31Cl2N4O2Br.1.0H2O.1.3HCl.0.2C4H10O',
#    'H',
#    'N']},
#  'ord-19fb1797e8c74b04a52ef40c742595c4': {'llm_species': ['compound',
#    'BBr3',
#    'title compound'],
#   'cde_species': ['BBr3', 'dichloromethane']},
#  'ord-f5cbe89a42e24d3787d3e6650e705f74': {'llm_species': ['methyl acrylate',
#    'p-methoxyphenethyl amine',
#    'methanol',
#    'methyl 3-[(4-methoxyphenethyl)amino]-propionate'],
#   'cde_species': ['methyl acrylate',
#    'p-methoxyphenethyl amine',
#    'methanol',
#    'methyl 3-[(4-methoxyphenethyl)amino]-propionate']},
#  'ord-e841a25de3174d1eb0e7fc6be4879094': {'llm_species': ['tert-butyl {2-[(4-bromophenyl)(hydroxy)methyl]-4-chlorophenyl}carbamate',
#    'CH2Cl2',
#    'MnO2',
#    'tert-butyl [2-(4-bromobenzoyl)-4-chlorophenyl]carbamate'],
#   'cde_species': ['tert-butyl {2-[(4-bromophenyl)(hydroxy)methyl]-4-chlorophenyl}carbamate',
#    'CH2Cl2',
#    'MnO2',
#    'tert-butyl [2-(4-bromobenzoyl)-4-chlorophenyl]carbamate',
#    'CDCl3',
#    '1H',
#    '2H']},
#  'ord-2d2b54d9d4dd48b9ae2930084403e056': {'llm_species': ['2-Acetamido-2,3-dimethylbutyric acid',
#    'THF',
#    'dicyclohexylcarbodiimide',
#    'crude product'],
#   'cde_species': ['2-Acetamido-2,3-dimethylbutyric acid',
#    'THF',
#    'CH2Cl2',
#    'dicyclohexylcarbodiimide']},
#  'ord-940e04d2f4fd468dac700b7e4341f145': {'llm_species': ['3-amino-4-methylbenzonitrile',
#    '8-(1-bromoethyl)-N,N-dimethyl-2-morpholino-4-oxo-4H-chromene-6-carboxamide hydrobromide',
#    '8-(1-(5-cyano-2-methylphenylamino)ethyl)-N,N-dimethyl-2-morpholino-4-oxo-4H-chromene-6-carboxamide'],
#   'cde_species': ['3-amino-4-methylbenzonitrile',
#    '8-(1-bromoethyl)-N,N-dimethyl-2-morpholino-4-oxo-4H-chromene-6-carboxamide hydrobromide',
#    '8-(1-(5-cyano-2-methylphenylamino)ethyl)-N,N-dimethyl-2-morpholino-4-oxo-4H-chromene-6-carboxamide',
#    'DMSOd6',
#    '1H']},
#  'ord-7dc04fe88e2c46eca670ec2a243cf6c0': {'llm_species': ['3-bromo-5-methyl-2-pyrazinamine',
#    '2,3-dichlorobenzenesulphonyl chloride',
#    'N-(3-Bromo-5-methyl-2-pyrazinyl)-2,3-dichlorobenzenesulphonamide'],
#   'cde_species': ['3-bromo-5-methyl-2-pyrazinamine',
#    '2,3-dichlorobenzenesulphonyl chloride']},
#  'ord-f95ecd8dcdee4b2791153fd7bcb46304': {'llm_species': ['6-(2-(Diphenylmethylene)hydrazinyl)quinoline',
#    '4-methyl-3-oxo-pentanenitrile',
#    '5-isopropyl-2-quinolin-6-yl-2H-pyrazol-3-ylamine'],
#   'cde_species': ['6-(2-(Diphenylmethylene)hydrazinyl)quinoline',
#    '4-methyl-3-oxo-pentanenitrile',
#    '5-isopropyl-2-quinolin-6-yl-2H-pyrazol-3-ylamine',
#    'CDCl3',
#    'H',
#    '2 H',
#    '1H']},
#  'ord-8959462339fc4fa39d40a4aaa8d1a18d': {'llm_species': ['Compound 11A',
#    'EtOAc',
#    'Pd/C',
#    'compound 11B'],
#   'cde_species': ['EtOAc',
#    'Pd / C',
#    'hydrogen',
#    '11B',
#    'methanol',
#    'H3PO4',
#    'Bicyclo[2.2.2]oct-2-ene-2-carbonyl chloride']},
#  'ord-cd2c7cdc310e47c08ccff6cf3df05cce': {'llm_species': ['3-methyl-3-(2-methoxy-5-fluorophenyl)butan-1-ol',
#    'methylene chloride',
#    'pyridinium chlorochromate',
#    '3-methyl-3-(2-methoxy-5-fluorophenyl)butyraldehyde',
#    'oil'],
#   'cde_species': ['3-methyl-3-(2-methoxy-5-fluorophenyl)butan-1-ol',
#    'methylene chloride',
#    'pyridinium chlorochromate',
#    'CELITE',
#    'silica gel',
#    'methylene chloride-hexane',
#    '3-methyl-3-(2-methoxy-5-fluorophenyl)butyraldehyde']},
#  'ord-53f02e5540364c7a80628e67b63888f6': {'llm_species': ['1-(1-methylethyl)5-(1,1-dimethylethoxy)carbonyl-5,6-dihydro -4H-thieno[3,4-c]pyrrole',
#    'trifluoroacetic acid',
#    'oily product'],
#   'cde_species': ['1-(1-methylethyl)5-(1,1-dimethylethoxy)carbonyl-5,6-dihydro -4H-thieno[3,4-c]pyrrole',
#    'trifluoroacetic acid']},
#  'ord-5590f37583a74e1b85b117f6f93457a5': {'llm_species': ['pyrrolidine',
#    'methanol',
#    'product',
#    'methanol',
#    'acetone',
#    'ethanol',
#    't-butyl-trimethyl-fulvene'],
#   'cde_species': ['acetone',
#    'ethanol',
#    'pyrrolidine',
#    'acetic acid',
#    'methanol']},
#  'ord-0f5bf584fca649009176f05f6dd80157': {'llm_species': ['HBr',
#    'tryptophan',
#    'water',
#    'Caffeine',
#    'Tryptophan isopropyl ester'],
#   'cde_species': ['tryptophan', 'Caffeine']},
#  'ord-610597396aeb4c6cb99617a20917a083': {'llm_species': ['(R)-4-(4-chlorobenzyl)-3-methyl-5-(pyrrolidin-2-yl)isoxazole',
#    '1-isocyanato-4-(trifluoromethyl)benzene',
#    'dichloromethane',
#    '(R)-2-(4-(4-chlorobenzyl)-3-methylisoxazol-5-yl)-N-(4-(trifluoromethyl)phenyl)pyrrolidine-1-carboxamide'],
#   'cde_species': ['(R)-4-(4-chlorobenzyl)-3-methyl-5-(pyrrolidin-2-yl)isoxazole',
#    'dichloromethane',
#    '1-isocyanato-4-(trifluoromethyl)benzene',
#    '(R)-2-(4-(4-chlorobenzyl)-3-methylisoxazol-5-yl)-N-(4-(trifluoromethyl)phenyl)pyrrolidine-1-carboxamide']},
#  'ord-c67f6d5f4f534bac8ae90bb6b05f3225': {'llm_species': ['1-{5-chloro-2-[4-(3,5-dimethylpyridin-2-yl)piperazine-1-carbonyl]phenyl}pyrrolidin-2-one',
#    'oxazolidin-2-one',
#    'title compound'],
#   'cde_species': ['1-{5-chloro-2-[4-(3,5-dimethylpyridin-2-yl)piperazine-1-carbonyl]phenyl}pyrrolidin-2-one',
#    'oxazolidin-2-one']},
#  'ord-6b2569ff8300415cb0bed72a5c48416d': {'llm_species': ['potassium hydroxide',
#    'ethanol',
#    'N-(4-anilinophenyl) acrylamide',
#    'ethanol',
#    '2-mercaptoethyl ether',
#    "N,N'-bis(4-anilinophenyl)-4,10-dithia-7-oxatridecanediamide"],
#   'cde_species': ['N-(4-anilinophenyl) acrylamide',
#    '2-mercaptoethyl ether',
#    'potassium hydroxide',
#    'ethanol']},
#  'ord-2e3530ca4b614634be86e4d674e6c585': {'llm_species': ['2-butyl-1,2,4-thiadiazolo[4,5-a]benzi-midazole-3(2H)-one',
#    'bromoacetonitrile',
#    'dichloromethane',
#    'title compound'],
#   'cde_species': ['2-butyl-1,2,4-thiadiazolo[4,5-a]benzi-midazole-3(2H)-one',
#    'bromoacetonitrile',
#    'dichloromethane',
#    'white precipitate',
#    '1H',
#    '2H',
#    'CH2',
#    'ArH']},
#  'ord-d683953168ce4b919df9fb74b8806755': {'llm_species': ['Fluvastatin methyl ester',
#    'acetone',
#    'NaOH',
#    'MeOH',
#    'fluvastatin sodium'],
#   'cde_species': ['Fluvastatin methyl ester',
#    'NaOH',
#    'MeOH',
#    'nitrogen',
#    'fluvastatin sodium',
#    'acetone']},
#  'ord-24c0c737e5e64ec6866df845a5903e33': {'llm_species': ['4-chlorobenzyl alcohol',
#    '5-amino-4-oxopentanoic acid hydrochloride',
#    '4-Chlorobenzyl 5-amino-4-oxopentanoate hydrochloride'],
#   'cde_species': ['4-chlorobenzyl alcohol',
#    '5-amino-4-oxopentanoic acid hydrochloride']},
#  'ord-d0cc213a3ad34b31a93c49ceb17fd77f': {'llm_species': ['pentachloropyridine',
#    'ammonium sulfate',
#    'zinc',
#    '2,3,5,6-tetrachloropyridine'],
#   'cde_species': ['pentachloropyridine',
#    'zinc',
#    'ammonium sulfate',
#    '2,3,5,6-tetrachloropyridine',
#    '2,3,5-trichloropyridine',
#    '2,3,6-trichloropyridine']},
#  'ord-5fadd0db07f84682989871823a5ea7ef': {'llm_species': ['DMSO',
#    '4′-chloro-6-fluoro-2′-methylbiphenyl-2-ol',
#    'potassium carbonate',
#    'allyl bromide',
#    '2′-allyloxy-4-chloro-6′-fluoro-2-methylbiphenyl'],
#   'cde_species': ['4′-chloro-6-fluoro-2′-methylbiphenyl-2-ol',
#    'potassium carbonate',
#    'allyl bromide',
#    'DMSO',
#    '2′-allyloxy-4-chloro-6′-fluoro-2-methylbiphenyl']},
#  'ord-2b8a1cb1be894b19b83a342e865226cc': {'llm_species': ['2-fluoro-5-nitro-benzaldehyde',
#    'ethylene glycol',
#    'acetic acid',
#    'BF3 Et2O',
#    'title compound'],
#   'cde_species': ['2-fluoro-5-nitro-benzaldehyde',
#    'ethylene glycol',
#    'acetic acid',
#    'BF3 -Et2O']},
#  'ord-0fb1d49b8ba94d0485de9a17cba759e8': {'llm_species': ['4-[3-[5-Methoxy-2-[[(2-phenylethyl)imino]methyl]phenoxy]propyl]morpholine',
#    'sodium borohydride',
#    'methanol',
#    'title compound'],
#   'cde_species': ['4-[3-[5-Methoxy-2-[[(2-phenylethyl)imino]methyl]phenoxy]propyl]morpholine',
#    'sodium borohydride',
#    'methanol',
#    'Hg']},
#  'ord-ae22514fe72c406094bafe5da0cee0bf': {'llm_species': ['4-amino-1-[4-(3,4-dichlorophenoxy)piperidin-1-yl]butan-2-ol',
#    '2-(methylsulphonyl)benzoic acid',
#    'title compound',
#    'solid'],
#   'cde_species': ['4-amino-1-[4-(3,4-dichlorophenoxy)piperidin-1-yl]butan-2-ol',
#    '2-(methylsulphonyl)benzoic acid']},
#  'ord-ddb9033ef0464a3cb2a6aed0cc75640f': {'llm_species': ['(2-amino-5-ethoxy-4-trifluoromethyl-phenyl)-carbamic acid tert.-butyl ester',
#    '3-(2-cyano-pyridin-4-yl)-3-oxo-propionic acid tert.-butyl ester',
#    'title compound',
#    'solid'],
#   'cde_species': ['(2-amino-5-ethoxy-4-trifluoromethyl-phenyl)-carbamic acid tert.-butyl ester',
#    '3-(2-cyano-pyridin-4-yl)-3-oxo-propionic acid tert.-butyl ester']},
#  'ord-524d0e37165d440c9bbba2f04e5602f2': {'llm_species': ['1-(4-nitrophenyl)-4-(tetrahydro-2H-pyran-4-yl)piperazine',
#    'ethanol',
#    'tetrahydrofuran',
#    'palladium',
#    '4-[4-(tetrahydro-2H-pyran-4-yl)piperazin-1-yl]aniline'],
#   'cde_species': ['1-(4-nitrophenyl)-4-(tetrahydro-2H-pyran-4-yl)piperazine',
#    'ethanol',
#    'tetrahydrofuran',
#    'palladium',
#    'carbon',
#    'hydrogen',
#    '4-[4-(tetrahydro-2H-pyran-4-yl)piperazin-1-yl]aniline']},
#  'ord-ccac2e30f0a54139b16eabeaf29587f7': {'llm_species': ['5-Amino-3-ethyl-1-methyl pyrazole',
#    '1-acetyl-2-imidazolinone',
#    '1-acetyl -2-(3-ethyl-1-methyl-5-pyrazolyl) amino-2-imidazoline'],
#   'cde_species': ['5-Amino-3-ethyl-1-methyl pyrazole',
#    '1-acetyl-2-imidazolinone',
#    '1-acetyl -2-(3-ethyl-1-methyl-5-pyrazolyl) amino-2-imidazoline']},
#  'ord-5a8a2be2930642a091e38a1f82354092': {'llm_species': ['DMF acetonitrile',
#    '4-(N,N-dimethylaminocarbonyl)-4-phenylpiperidine',
#    'compound',
#    'K2CO3',
#    'expected product'],
#   'cde_species': ['4-(N,N-dimethylaminocarbonyl)-4-phenylpiperidine',
#    'K2CO3',
#    'DMF',
#    'acetonitrile']},
#  'ord-6db3acf9bea14bda995306ee62c393c1': {'llm_species': ['tetrahydrofuran',
#    '2-(Acetoxymethyl)-5-[[bis(allyloxy)phosphoryl]oxymethyl]benzoic acid',
#    'oxalyl chloride',
#    'N,N-dimethylformamide',
#    '2-(acetoxymethyl)-5-[[bis(allyloxy)phosphoryl]oxymethyl]benzoyl chloride'],
#   'cde_species': ['2-(Acetoxymethyl)-5-[[bis(allyloxy)phosphoryl]oxymethyl]benzoic acid',
#    'tetrahydrofuran',
#    'oxalyl chloride',
#    'N,N-dimethylformamide',
#    '2-(acetoxymethyl)-5-[[bis(allyloxy)phosphoryl]oxymethyl]benzoyl chloride']},
#  'ord-f9d62a1b57d74f5fbc56bf9fb1869481': {'llm_species': ['2-(N-ethyl-N-phenylamino)ethanol',
#    'SOCl2',
#    'CH2Cl2',
#    'intermediate 15a'],
#   'cde_species': ['2-(N-ethyl-N-phenylamino)ethanol',
#    'CH2Cl2',
#    'SOCl2',
#    'silica gel',
#    '1H',
#    'CDCl3',
#    '2H',
#    'C10H15ClN']},
#  'ord-d8fc7d95c6514e20833bbfd97c4524de': {'llm_species': ['2A',
#    'acetic acid',
#    'iron',
#    'methanol',
#    '4-isopropoxy-3-(trifluoromethyl)aniline'],
#   'cde_species': ['iron',
#    'acetic acid',
#    'methanol',
#    '4-isopropoxy-3-(trifluoromethyl)aniline']},
#  'ord-53e05ef7ebdc40468db89719772c0a19': {'llm_species': ['3-(4-Bromo-2-methyl-2H-pyrazol-3-yl)-4-methoxy-phenylamine',
#    'α,α,α-trifluoro-m-tolyl isocyanate',
#    'CH2Cl2',
#    'Compound 11'],
#   'cde_species': ['3-(4-Bromo-2-methyl-2H-pyrazol-3-yl)-4-methoxy-phenylamine',
#    'α,α,α-trifluoro-m-tolyl isocyanate',
#    'CH2Cl2',
#    'M+H81Br',
#    '1H',
#    'acetone-d6']},
#  'ord-db80e4db199b480a97512429479f9c64': {'llm_species': ['3-fluoro-6-(phenylthio)-benzyl alcohol',
#    'benzene',
#    'thionyl chloride',
#    '3-fluoro-6-(phenylthio)-benzyl chloride'],
#   'cde_species': ['3-fluoro-6-(phenylthio)-benzyl alcohol',
#    'benzene',
#    'thionyl chloride',
#    '3-fluoro-6-(phenylthio)-benzyl chloride']},
#  'ord-195b07c9b7384f1a96d81dc87e87dadc': {'llm_species': ['3-methyl-1-butyne-3-ol',
#    '2-chloroethylpropyl ether',
#    '3-(2-n-propoxyethoxy)-3-methyl-1-butyne'],
#   'cde_species': ['3-methyl-1-butyne-3-ol',
#    '2-chloroethylpropyl ether',
#    '3-(2-n-propoxyethoxy)-3-methyl-1-butyne']},
#  'ord-ac6d5208cab4418181094428aa4f4c12': {'llm_species': ['1-[(5-chloro-pyridin-2-ylcarbamoyl)-methyl]-2-(1-cyclopropyl-piperidin-4-ylcarbamoyl)-1H-benzoimidazole-4-carboxylic acid',
#    'cyclopropyl-methanol',
#    '1-[(5-Chloro-pyridin-2-ylcarbamoyl)-methyl]-2-(1-cyclopropyl-piperidin-4-ylcarbamoyl)-1H-benzoimidazole-4-carboxylic acid cyclopropylmethyl ester'],
#   'cde_species': ['1-[(5-Chloro-pyridin-2-ylcarbamoyl)-methyl]-2-(1-cyclopropyl-piperidin-4-ylcarbamoyl)-1H-benzoimidazole-4-carboxylic acid cyclopropylmethyl ester',
#    '1-[(5-chloro-pyridin-2-ylcarbamoyl)-methyl]-2-(1-cyclopropyl-piperidin-4-ylcarbamoyl)-1H-benzoimidazole-4-carboxylic acid',
#    'cyclopropyl-methanol']},
#  'ord-fd1fcd54b4af4b3284f18d41a8e8f2d1': {'llm_species': ['4-({3-chloro-4-[(1-methyl-1H-imidazol-2-yl)sulfanyl]phenyl}amino)-7-fluoro-6-(2-methoxyethoxy)-3-quinolinecarbonitrile',
#    '1-ethyl-4-(3-hydroxypropyl)piperazine',
#    '4-({3-chloro-4-[(1-methyl-1H-imidazol-2-yl)sulfanyl]phenyl}amino)-7-[3-(4-ethyl-1-piperazinyl)propoxy]-6-(2-methoxyethoxy)-3-quinolinecarbonitrile'],
#   'cde_species': ['4-({3-chloro-4-[(1-methyl-1H-imidazol-2-yl)sulfanyl]phenyl}amino)-7-fluoro-6-(2-methoxyethoxy)-3-quinolinecarbonitrile',
#    '1-ethyl-4-(3-hydroxypropyl)piperazine',
#    '4-({3-chloro-4-[(1-methyl-1H-imidazol-2-yl)sulfanyl]phenyl}amino)-7-[3-(4-ethyl-1-piperazinyl)propoxy]-6-(2-methoxyethoxy)-3-quinolinecarbonitrile']},
#  'ord-7d869aff218b4fdfabb1eff2077cfd97': {'llm_species': ['bis(2-methoxytetrafluoroethyl)ketone',
#    '2-chloroethanol',
#    'ether',
#    'K2CO3',
#    '2,2-bis(2-methoxytetrafluoroethyl)-1,3-dioxolane'],
#   'cde_species': ['bis(2-methoxytetrafluoroethyl)ketone',
#    '2-chloroethanol',
#    'ether',
#    'K2CO3',
#    '2,2-bis(2-methoxytetrafluoroethyl)-1,3-dioxolane',
#    'CCl4']},
#  'ord-894e29847bb047a59cc85a88db1c88fd': {'llm_species': ['(2-aminothiazol-4-yl)acetic acid',
#    'tert-butylisonitrile',
#    '2-methoxybenzaldehyde',
#    'perchloric acid',
#    'Compound 33'],
#   'cde_species': ['(2-aminothiazol-4-yl)acetic acid',
#    'tert-butylisonitrile',
#    '2-methoxybenzaldehyde',
#    'perchloric acid']},
#  'ord-18bd0fe75c6d405b98f659a271ed2897': {'llm_species': ['hexane',
#    '2,4-dimethylphenyl isocyanate',
#    '6-[[(4-butylphenyl)methyl]amino]-1-hexanol',
#    'hexane',
#    'desired product'],
#   'cde_species': ['2,4-dimethylphenyl isocyanate',
#    'hexane',
#    '6-[[(4-butylphenyl)methyl]amino]-1-hexanol']},
#  'ord-5ac6ed6786b047afa95ae4ef4a061792': {'llm_species': ['(R/S) (4-(3-(2-methoxyethoxy)-5-(trifluoromethyl)phenyl)-5-methyl-1-(tetrahydro-2H-pyran-2-yl)-1H-pyrazol-3-yl)methanol',
#    'dichloromethane',
#    'MnO2',
#    '(R/S) 4-(3-(2-methoxyethoxy)-5-(trifluoromethyl)phenyl)-5-methyl-1-(tetrahydro-2H-pyran-2-yl)-1H-pyrazole-3-carbaldehyde'],
#   'cde_species': ['(4-(3-(2-methoxyethoxy)-5-(trifluoromethyl)phenyl)-5-methyl-1-(tetrahydro-2H-pyran-2-yl)-1H-pyrazol-3-yl)methanol',
#    'MnO2',
#    'dichloromethane',
#    '4-(3-(2-methoxyethoxy)-5-(trifluoromethyl)phenyl)-5-methyl-1-(tetrahydro-2H-pyran-2-yl)-1H-pyrazole-3-carbaldehyde']},
#  'ord-6769afe3f93e45529751b5d6b490635d': {'llm_species': ['2-aminomethylpyridine',
#    'dicyclohexylcarbodiimide',
#    'benzhydrylsulphinylacetic acid',
#    'methylene chloride',
#    'N-(2-pyridylmethyl)benzhydrylsulphinylacetamide'],
#   'cde_species': ['benzhydrylsulphinylacetic acid',
#    'methylene chloride',
#    '2-aminomethylpyridine',
#    'dicyclohexylcarbodiimide']},
#  'ord-a2caf2f455704478be8b568477984cf2': {'llm_species': ['66.16E',
#    'EtOAc',
#    'palladium on carbon',
#    '66.16F'],
#   'cde_species': ['palladium',
#    'carbon',
#    'hydrogen',
#    'silica gel',
#    'hexanes',
#    'EtOAc']},
#  ...}

# %%
llm_exclusive_finds
# Out:
# ['solid',
#  'title compound',
#  '4-(4-{[(2S)-2,3-Dihydroxypropyl]oxy}phenyl)-2-methoxy-6-sulphanylpyridine-3,5-dicarbonitrile',
#  'N-(4-Methoxybenzylidene)-4-carboxybenzenesulfonamide',
#  'crude product',
#  'ethylmagnesium bromide diethyl ether',
#  'oil',
#  'title compound',
#  'desired material',
#  'DCM',
#  'title compound',
#  'acetic acid',
#  'title compound',
#  'methylphenyl phosphinic acid, phenethyl ester',
#  'white solid',
#  'Pd/C',
#  'title compound',
#  'Ethylene Urea Ethylene Glycol Glyoxal',
#  'crude product',
#  'DCM',
#  'title compound',
#  'title compound',
#  '4-(3-hydroxy-3-(5,6,7,8-tetrahydro-5,5,8,8-tetramethyl-2-naphthyl)-1-propynyl)phenylsulfinylmethane',
#  'product',
#  'Pd/C',
#  'title compound',
#  'title compound',
#  '4-hydroxy-3-methoxy-2-nitrobenzonitrile',
#  'palladium on charcoal',
#  'title compound',
#  'orange coloured oil',
#  '1,4-Dihydro-2,6-dimethyl-3-methoxycarbonyl-4-(2-nitrophenyl)-5-(6-aminohexyloxy)carbonyl-pyridine',
#  'product',
#  'powder',
#  'HCl MeOH',
#  'palladium on carbon',
#  'title compound',
#  'title compound',
#  'title compound',
#  'hydrochloric acid',
#  'Pd/C',
#  '4-{2-[3-[1-(4-fluorobenzhydryl)indol-5-yl]isocrotonoylamino]phenoxy}butyric acid',
#  'compound 57',
#  'compound',
#  'EDC',
#  'water',
#  'title compound',
#  '3-[(4-Chloro-3-nitrophenyl)methylene]-2,4-pentanedione',
#  'Ethyl 3-[4-[2-[[1-(4′-fluoro-4-biphenylyl)ethylidene]aminoxy]ethoxy]phenyl]-2-(4-fluorophenoxy)propionate',
#  'compound',
#  'hydrogen chloride methanol',
#  'Intermediate 24a',
#  'title compound',
#  'title compound',
#  'compound 6',
#  'DCM',
#  '3-(bromomethyl)pyrazolo[1,5-a]pyridine',
#  'hydrochloride salt',
#  'title compound',
#  'desired product',
#  '4-[(4-Cyanophenyl)methylene]-3,5-heptanedione',
#  '2-benzyl-4-methoxy-5,5,8,8-tetramethyl-5,6,7,8-tetrahydro-1-naphthalenol',
#  'compound',
#  '3-{[3-(4-Chlorophenyl)-5-oxo-4-(3,3,3-trifluoro-2-hydroxypropyl)-4,5-dihydro-1H-1,2,4-triazol-1-yl]methyl}-2′-(trifluoromethyl)biphenyl-4-carboxylic acid',
#  '1,4-dioxane water',
#  'title compound',
#  'BHET EOP',
#  '8-oxo-11,11a-dihydro-8H,10H-azeto[1,2-a]imidazo[5,1-c]thieno-[3,2-e][1,4]diazepine-1-carboxylic acid hydrazide',
#  'title compound',
#  'iodide',
#  'palladium on carbon',
#  'product',
#  'title compound',
#  '3-[3-(4-methyl-1H-imidazol-1-yl)propyl]-2-thioxo-1,2,3,5,6,7-hexahydro-4H-cyclopenta[4,5]thieno[2,3-d]pyrimidin-4-one',
#  'title compound',
#  'crystals',
#  '(R,E)-N-(1-(3-Bromo-2-methylphenyl)ethylidene)-2-methylpropane-2-sulfinamide',
#  'Intermediate 12A',
#  'title compound',
#  'product',
#  'desired product',
#  'solution',
#  'desired product',
#  'title compound',
#  'HCl',
#  '(S)—N-(3-(4-amino-6-((1-(5-methyl-4-oxo-3-phenyl-3,4-dihydropyrrolo[2,1-f][1,2,4]triazin-2-yl)ethyl)amino)pyrimidin-5-yl)-5-hydroxyphenyl)-4-methoxybenzenesulfonamide',
#  '(S)—N-(3-(4-Amino-6-((1-(5-methyl-4-oxo-3-phenyl-3,4-dihydropyrrolo[2,1-f][1,2,4]triazin-2-yl)ethyl)amino)pyrimidin-5-yl)-5-hydroxyphenyl)-4-hydroxybenzenesulfonamide',
#  'title compound',
#  '1-benzoyl-3-methyl-2-(nitro(phenylthio)methylene)-imidazolidine',
#  '1B',
#  'compound 6',
#  "Lawesson's Reagent",
#  'compound 5',
#  'N-Phenyl-3-[(N,N-diethylamino)oxy]pyrrolidine-2,5-dione',
#  'title compound',
#  'title compound',
#  'powder',
#  'title compound',
#  'compound',
#  'title compound',
#  'title compound',
#  'HATU',
#  'required compound',
#  'target compound',
#  'isopropyl alcohol',
#  'title compound',
#  'product',
#  'title compound',
#  'title compound',
#  'crystals',
#  'DCM TEA',
#  '29',
#  '2-(14-(4-Isocyanatophenoxy)-3,6,9,12-tetraoxatetradecyloxy)tetrahydro-2H-pyran',
#  'phosgene toluene',
#  '[1-[3-(3-pyridinyl)-propyl)-4-(3-pyridinyl)butyl]carbamic acid 1,1-dimethylethyl ester',
#  'HCl',
#  'title material',
#  'solid',
#  'title compound',
#  'white solid',
#  '(S)-omeprazole',
#  'benzene',
#  'title compound',
#  'title compound',
#  'title compound',
#  'DMF MeOH',
#  'Pd/C',
#  '2-bromo-3-(but-2-ynyl)-3,5-dihydro-imidazo[4,5-d]pyridazin-4-one',
#  'title compound',
#  'title compound',
#  'HCl dioxane',
#  'title compound',
#  'named compound',
#  'product',
#  'water',
#  'objective compound',
#  'desired product',
#  'manganese (IV) oxide',
#  'title compound',
#  'title compound',
#  '5-amino-3-(1-tert-butoxycarbonylpiperidin-4-yl)pyrrolo[3,2-b]pyridine',
#  'title compound',
#  '4-Methyl-N-(4-phenyl-thiazol-2-yl)-benzamide',
#  'title compound',
#  'NaOH',
#  'HCl',
#  'compound',
#  'Trans-2-(7-methoxy-1-naphthyl)-1-cyclopropanecarboxylic Acid',
#  'sodium hydroxide',
#  '3-(4-Amino-3-methoxybenzoyl)-2-methylindolizin-1-ylcarboxylic acid',
#  '2-(3′-Chloro-4′-fluoro-biphenyl-3-yl)-1-(R)-(3-methyl-[1,2,4]oxadiazol-5-yl)-ethylamine hydrochloride salt',
#  '3-Chloro-2-(pyrimidin-4-yl)-6,7,8,9-tetrahydro-4H-pyrimido[1,2-a]pyrimidin-4-one',
#  '(Z)-2-fluoro-4-(3,3,3-trifluoroprop-1-enyl)benzoic acid',
#  'pure aimed product',
#  "Lawesson's reagent",
#  'title compound',
#  'compound ( F )',
#  'water',
#  'HCl',
#  'palladium on carbon',
#  'title compound',
#  'title compound',
#  'Compound 2b',
#  'Compound 2a',
#  'title compound',
#  'title compound',
#  'DCM',
#  'N-[5-Chloro-4-(tetrahydro-pyran-2-yloxymethyl)-pyridin-3-ylmethyl]-isobutyramide',
#  'product',
#  'expected product',
#  '2,3-Dihydro-2-oxo-1H-benzimidazole-1-carbonyl chloride',
#  'title compound',
#  'Compound',
#  'title compound',
#  'product',
#  'tert-Butyl 3-(4′-fluorobiphenyl-4-yloxymethyl)-pyrrolidine-1-carboxylate',
#  'title compound',
#  'title compound',
#  'titled compound',
#  'chlorine',
#  'title compound',
#  'title compound',
#  'Ethyl acetate petroleum ether',
#  'title compound',
#  'water',
#  '4-amino-piperidine-4-carboxylic amide',
#  "Hunig's base",
#  'title compound',
#  'Pd/C',
#  '4-(2,4-Dimethoxy-phenyl)-piperidine',
#  'solid',
#  'title compound',
#  'hydrochloric acid',
#  'title compound',
#  'Compound 23',
#  'Compound 100',
#  'title compound',
#  'title compound',
#  'final product',
#  'solid',
#  'solid',
#  'title compound',
#  'title compound',
#  'title compound',
#  'Intermediate 1',
#  'title compound',
#  'ice',
#  'title compound',
#  'potassium carbonate',
#  'compound',
#  'title compound',
#  'desired compound ( 1a )',
#  'product',
#  'N-(1-Carboethoxy-3-aminopropyl)-L-alanyl-1,2,3,4-tetrahydroisoquinoline-3-carboxylic acid',
#  'oil',
#  'LAH',
#  'product',
#  'title compound',
#  'oil',
#  'title compound',
#  'title compound',
#  'title compound',
#  'HATU',
#  '1-Acetyl-6-(2-[4-methoxyphenyl]ethylamino)carbonyl-4-phenyl-1,2,3,4-tetrahydro-2,2,4-trimethylquinoline',
#  'product',
#  'dimethylformamide dimethylacetal',
#  'title compound',
#  '4-methyl-2-(2-nitro-phenylamino)-benzonitrile',
#  'HCl',
#  'desired compound',
#  'product',
#  'title compound',
#  'title compound',
#  'DCM',
#  'product',
#  'palladium/carbon',
#  'title compound',
#  'title compound',
#  '{2-Methyl-4-[3-(3-morpholin-4-yl-propoxy)-5-(3-phenyl-prop-1-ynyl)benzylsulfanyl]-phenoxy}-acetic Acid Ethyl Ester',
#  'title compound',
#  '4-(4-Nitro-thiophen-2-ylmethyl)-2H-phthalazin-1-one',
#  'product',
#  'title compound',
#  'title compound',
#  '4-Methoxybenzoic Acid',
#  '4-methoxybenzoic acid, 6-aminohexyl ester',
#  'oil',
#  'water',
#  'colorless solid',
#  'water',
#  'solid',
#  'title compound',
#  'desired product',
#  'N1-(4-nitrobenzyl)-N4-[(4-acetamido)phenacyl]piperazine dihydrochloride',
#  'title compound',
#  'Zinc',
#  '37',
#  '6-Chloro-N′-dodecanoyl-4-hydroxy-1-methyl-2-oxo-1,2-dihydroquinoline-3-carbohydrazide',
#  'title compound',
#  '6-(1-aminoethyl)-3,3-dimethylbenzo[c][1,2]oxaborol-1(3H)-ol',
#  'desired compound',
#  'hydrochloride salt',
#  '5,6-dihydro-6-(4-nitrophenyl)-5-oxo-pyrido[2′,1′:2,3]imidazo[4,5-c]isoquinolin-9-carboxylic acid',
#  'compound 11',
#  '159c',
#  '159b',
#  'water',
#  'title compound',
#  '3-thiophenehexanol',
#  'palladium/carbon',
#  'solution',
#  '(S)-N-[1-(3-Hydroxy-phenyl)-2-pyrrolidin-1-yl-ethyl]-2-(4-methanesulfonyl-phenyl)-N-methyl-acetamide',
#  '(2S,3S,4S)-4-Fluoro-3-methoxy-pyrrolidine-2-carboxylic acid 3-chloro-2-fluoro-benzylamide trifluoroacetate',
#  '2-morpholin-4-yl-5-(5H-pyrrolo[2,1-c][1,4]benzodiazepin-10(11H)-ylcarbonyl)benzenesulfonamide',
#  'water',
#  'title compound',
#  '1,4-dioxane',
#  "Lawesson's Reagent",
#  'product',
#  '1L',
#  'title compound',
#  'NBS',
#  '3-Isopropyl-5-[2-(2,3-epoxypropoxy)-styryl]-isoxazole',
#  'title compound',
#  'crude product',
#  'NCS',
#  'title compound',
#  'product',
#  'water',
#  'title compound',
#  'palladium on carbon',
#  '( VII )',
#  'product',
#  'N-(1H-indol-4-yl)-4-methoxy-benzamide',
#  'tert.-butylamine',
#  'solid',
#  'title compound',
#  'title compound',
#  'solution A',
#  'Compound 42',
#  'palladium on charcoal',
#  'hydrochloride salt',
#  'titled compound',
#  'title compound',
#  'title compound',
#  'titled compound',
#  'desired product',
#  '4-({3-[3-(2-Chlorophenyl)-1,2,4-oxadiazol-5-yl]-5-(4-ethylphenyl)piperidin-1-yl}carbonyl)-morpholine',
#  'product',
#  '3-(3,4-Dihydroxy-5-nitrophenyl)-1-(2-hydroxyphenyl)prop-2-en-1-one',
#  'title compound',
#  'title compound',
#  '3-(tert.-Butoxycarbonylamino-methyl)-3-methoxy-pyrrolidine',
#  'Pd carbon',
#  'title compound',
#  'desired product',
#  '4-(3,5-dimethylpiperidino)-butyronitrile',
#  'title compound',
#  'rhodium acetate dimer',
#  'title compound',
#  'Intermediate 38',
#  'Example 16',
#  'Intermediate 45',
#  'title compound',
#  'HCl',
#  'compound',
#  'title compound',
#  'ethyl acetate methanol',
#  'product',
#  'title compound',
#  'title compound',
#  'Methyl (6S,9R)-9-[(tert-butoxycarbonyl)amino]-6-(2,3-difluorophenyl)-6,7,8,9-tetrahydro-5H-imidazo[1,2-a]azepine-3-carboxylate',
#  '(trimethylsilyl)diazomethane',
#  'palladium on carbon',
#  'title compound',
#  '4-[3-tert-Butyl-5-(1,1-dimethoxyethyl)-2-methoxyphenyl]morpholine',
#  '(±)-BINAP',
#  'crude product',
#  'title compound',
#  '2-(tert-butyl-dimethyl-silanyloxy)-1-(2-phenyl-6,7-dihydro-4H-oxazolo[5,4-c]pyridin-5-yl)-butan-1-thione',
#  "Lawesson's reagent",
#  'solid',
#  'title compound',
#  'desired product',
#  'solid',
#  'ice water',
#  'desired product',
#  'product',
#  '2-Acetoxymethyl-6-bromomethyl-7-chloro-3,4-dihydroquinazolin-4-one',
#  'title compound',
#  'ammonium cerium (IV) nitrate',
#  'title compound',
#  'title compound',
#  "p,p' diphenyl methane diisocyanate",
#  '4-bromo-2,2′-bipyridyl-N-oxide',
#  'THF',
#  'white solid',
#  '1-(6-Bromo-pyridin-2-ylmethyl)-3-(4-methyl-pyridine-2-carbonyl)-1H-quinolin-4-one',
#  'crude product',
#  'powder',
#  'title compound',
#  'lime',
#  'title compound',
#  'title compound',
#  'title compound',
#  'title compound',
#  'cyclopropylmagnesium bromide THF',
#  'oil',
#  'title compound',
#  'title compound',
#  'product',
#  'mixture',
#  'title compound',
#  'title compound',
#  'Pd/C',
#  'titled product',
#  'toluene MeOH',
#  'title compound',
#  'product',
#  'palladium-on-charcoal',
#  'title compound',
#  'white powdered solid',
#  'title compound',
#  'intermediate 25',
#  'product 233',
#  'title compound',
#  '7-(2,3-Dihydroxypropyl)-3-methylxanthine',
#  'title compound',
#  'Pd2dba3',
#  '5-Methoxy-N-(4(7-methoxy-1,5-naphthyridin-4-yloxy)phenyl)pyridazin-3-amine',
#  'white solid',
#  'title compound',
#  'solution',
#  'title compound',
#  'base',
#  'title compound',
#  '(S)-2-(4-((1,2,3,4-Tetrahydroisoquinolin-3-yl)methyl)piperazin-1-yl)ethanol',
#  'crude compound',
#  'Racemic N-[(2-Adamantyloxy)carbonyl]-3-(imidazo[1,5-a]pyridin-3-yl)-2-methyl-alanine methyl ester',
#  '2-(Chloromethyl)thieno[3,2-b]pyridine',
#  'title compound',
#  'water',
#  'crude product',
#  'title product',
#  'title product',
#  '5-(N-methyl-thiocarbamoyl)-4,5,6,7-tetrahydroimidazo-[4,5-c]-pyridine',
#  'residue',
#  'title compound',
#  'title compound',
#  '(±)-tert-Butyl 1-(1-(3-cyanobenzyl)-1H-imidazol-2-yl)-2-(7-methyl-2-((2-(trimethylsilyl)ethoxy)methyl)-2H-indazol-5-yl)ethylcarbamate',
#  'title compound',
#  'methanol',
#  '(2R, 5S)-(5-chloro-2-{2-[4-(4-fluoro-benzyl)-2,5-dimethyl-piperazin-1-yl]-2-oxo-ethoxy}-phenyl)-carbamic acid 4-nitro-phenyl ester',
#  'title compound',
#  'title compound',
#  'DCM',
#  'title compound',
#  '1-ethyl-3-(naphthalen-2-yl)-1H-pyrazolo[3,4-d]pyrimidin-4-amine',
#  'water',
#  'product',
#  'Pd/C',
#  'crude product',
#  'Pd(OH)2/C',
#  'title compound',
#  'product',
#  'title compound',
#  '6-(2,6-Dichlorophenyl)-8-methyl-2-[(pyridin-3-ylmethyl)-amino]-8H-pyrido[2,3-d]pyrimidin-7-one',
#  'title compound',
#  'title compound',
#  'title compound',
#  'water',
#  'title product',
#  'solid',
#  'title compound',
#  'desired product',
#  'above compound 18',
#  'expected product',
#  'N-[(1R,2S)-1-[1-(4-fluorophenyl)indazol-5-yl]oxy-1-(3-methoxyphenyl)propan-2yl]-1H-pyrazole-3-carboxamide',
#  '4-(2-Amino-5-methyl-phenoxy)-1H-indole-2-carboxylic acid ethyl ester',
#  '134',
#  'hydrogen bromide ethanol',
#  'title compound',
#  'DIAD',
#  'compound 2',
#  'title compound 28e',
#  'intermediate 35',
#  'intermediate 34',
#  'ethyl 2-(7-amino-9-benzyl-3-oxa-9-azabicyclo[3.3.1]nonan-7-yl)acetate',
#  'title compound',
#  'Pd/C',
#  'MeOH DCM',
#  '(3-azidopropyl)-piperazine',
#  'palladium on activated carbon',
#  '(4-bromo-2-fluorophenyl) [4-(3,5,6-trimethylpyridin-2-yl)piperazin-1-yl]methanone',
#  'title compound',
#  'benzene',
#  'title compound',
#  'title compound',
#  'DIC',
#  'Compound 1',
#  'desired product',
#  'Pd/C',
#  'title compound',
#  'expected product',
#  'intended compound',
#  'white solid',
#  'title compound',
#  'water',
#  'title compound',
#  '4-nitrobenzyl (1S,5R,6S)-6-((1R)-1-hydroxyethyl)-1-methyl-2-[5-methylthio-7-(pyridin-3-yl)carbonylimidazo[5,1-b]thiazol-2-yl]-1-carbapen-2-em-3-carboxylate',
#  'title compound',
#  '2-[2-(2-{4-[3-(2-methoxy-phenyl)-5-phenyl-4,5-dihydro-pyrazol-1-yl]-phenyl}-vinyl)-6-phenyl-pyran-4-ylidene]-malononitrile',
#  'expected product',
#  'solid',
#  'title compound',
#  'title compound',
#  'water',
#  'title compound',
#  'title compound',
#  '11c',
#  'title compound',
#  '3-(S)-amino-1-ethoxycarbonylmethyl-2,3,4,5-tetrahydro-1H-[1]benzazepin-2-one tartrate salt',
#  'title intermediate',
#  'palladium/charcoal',
#  'HCl-',
#  'product',
#  'Pd/C',
#  'desired product',
#  'water',
#  'title compound',
#  'product',
#  'water',
#  '2-Ethylhexylnicotinamide',
#  'Intermediate 3',
#  'title compound',
#  'Title compound',
#  'dichloromethane',
#  'Pd/C',
#  'title compound',
#  '1,1′-trimethylenedi[4-[4-(3,4,5-trimethoxyphenyl)benzoyl]hexahydro-1,4-diazepine]',
#  'title compound',
#  'desired product',
#  'resultant precipitate',
#  'dibenzyl N-(N-tert-butoxycarbonyl-L-valyl)-L-glutamate',
#  'desired product',
#  'title compound',
#  'solid',
#  'title compound',
#  'product',
#  'N-(1H-indol-4-yl)-4-methoxy-benzamide',
#  'tert.-butylamine',
#  'EtOH AcOH',
#  '23',
#  'title compound',
#  '5-amino-3-(1-methylpiperidin-4-yl)-1H-indole',
#  'title compound',
#  '4-(4-Chloro-3-sulfamoylphenyl)-3-methyl-2-(2-methoxypropylimino)-1,3-thiazolidine-4-ol-hydrobromide',
#  '(2-{[4-chloro-3-(6-chloro-4-methyl-pyridin-3-yl)-benzoyl]-methyl-amino}-phenoxy)-acetic acid methyl ester',
#  'title compound',
#  'solid',
#  'Intermediate 4',
#  'crude product',
#  'solid',
#  'title compound',
#  '3-(3,4-Dihydroxy-5-trifluoromethylphenyl)-1-phenylprop-2-en-1-one',
#  'title compound',
#  'title compound',
#  'title compound ( E118 )',
#  'water',
#  'NBS',
#  'solid',
#  'title compound',
#  'Pd/C',
#  'crude product',
#  '1a',
#  '2,4-dichloro-3-{(E)-[(cyclopropylmethoxy)imino]methyl}-N-(4-methyl-1,2,5-oxadiazol-3-yl)benzamide',
#  '3-Chloro-6-(2-hydroxyethoxy)benzaldehyde',
#  'water',
#  'methylmagnesium bromide diethyl ether',
#  'oil',
#  'title compound',
#  '4-chloro-3-((trifluoromethyl)phenyl)-N′-(4-(3-methylcarbamoylphenyl)carboxyaminophenyl) urea',
#  '4-chloro-3-((trifluoromethyl)phenyl)-N′-(4-(3-carbomethoxyphenyl) carboxyaminophenyl) urea',
#  'title compound',
#  'D-gluconamide',
#  '3-(Quinolin-3-yl)-3-(5-1,2,3,4-tetrahydro-pyrido[2,3-b]pyrazin-6-yl-pentanoylamino)-propionic acid',
#  '5-8',
#  'product',
#  'methylene chloride DMF',
#  'product',
#  'title compound',
#  'solid',
#  'title compound',
#  'hydrochloride salt',
#  "Lawesson's reagent",
#  'desired compound',
#  '48',
#  'HCl dioxane',
#  'palladium on carbon',
#  'intermediates',
#  'title compound',
#  'Ion-Exchange',
#  'water',
#  'Pd/C',
#  '1-(6-Hydrazinopyrimidin-4-yl)azetidin-3-ol',
#  'butyl acrylate',
#  'methyl methacrylate',
#  'water',
#  'monomers ( A )',
#  'trans ethyl 1-ethoxycarbonyl-3-(diethylphosphonomethyl)-pyrrolidine-2-carboxylate',
#  'Pd/C',
#  'palladium on carbon',
#  'titled product',
#  'compound',
#  '3-Cyano-N-{4-methyl-3-[6-(1H-pyrazol-4-yl)-1H-imidazo[1,2-b]pyrazol-1-yl]phenyl}-5-(pentafluoro-λ6-sulphanyl)benzamide',
#  'product',
#  'Pd on carbon',
#  'EtOH THF',
#  "Meldrum's acid",
#  'title compound',
#  'desired product',
#  '(1S,2S)—N,N′-dimethylcyclohexane-1,2-diamine',
#  'desired product',
#  '(RS)—S-(4-aminophenyl)-N-(2-methoxy-ethyl)-S-methylsulphoximide',
#  'desired product',
#  'tert.-butylamine',
#  'product',
#  "Lawesson's Reagent",
#  'title compound',
#  'I2',
#  '6a',
#  'Pd/C',
#  'title compound',
#  '3-(4-isopropoxyphenyl)-2-methyl-5-{[2′-(5-oxo-4,5-dihydro-1,2,4-oxadiazol-3-yl)biphenyl-4-yl]methyl}-6-propylpyrimidin-4(3H)-one sodium salt',
#  'water',
#  'title compound',
#  'Intermediate 3',
#  'titled compound',
#  'Intermediate 4',
#  '(Z)-2-Acetylamino-3-dimethylamino-but-2-enoic acid ethyl ester',
#  'Pd/C',
#  'desired product',
#  'dimethylformamide dimethylacetal',
#  '3-7',
#  'ethanol NH4OH H2O',
#  '3-8',
#  'H2SO4 H2O',
#  'title compound',
#  '3-nitrobenzenesulfonic acid sodium salt',
#  'water',
#  'title compound',
#  'acetone',
#  'Cryptophycin 39',
#  'product',
#  '[5-(Ethoxycarbonyl)-1H-pyrrol-3-yl]-N,N,N-trimethyl-methanaminium iodide',
#  'desired product',
#  'NCS',
#  '5-(4-chloro-phenyl)-2-[2-(2-pyrrolidin-1-yl-ethoxy)-pyridin-5-yl-ethynyl]-pyridine',
#  '2-Benzoyl-4-benzyl-1,2,4-thiadiazolidine-3,5-dione',
#  'title compound',
#  'Compound 32',
#  '2-Methylamino-5-(4-trifluoromethyl-piperidin-1-yl)aniline',
#  'Pd/C',
#  'aimed compound',
#  '1-chloro-4-acetoxynonane',
#  'TFA DCM',
#  'product',
#  'solid',
#  'title compound',
#  'product',
#  '6,7-Dimethoxy-4-(5,6,7,8,-tetrahydro-naphthalen-1-ylamino)-quinoline-3-carbonitrile',
#  'title compound',
#  '1-Acetyl-4-phenyl-1,2,3,4-tetrahydro-6-(4-[trifluoromethyl]benzoyl)amino-2,2,4-trimethylquinoline',
#  'title compound',
#  'title compound',
#  'potassium tert.-butylate',
#  'ice water',
#  'title compound',
#  '1-[2-(1-benzofuran-2-yl)-2-oxoethyl]-4-[hydroxy(diphenyl)methyl]-1-azoniabicyclo[2.2.2]octane bromide',
#  'water',
#  'liquid',
#  'title compound',
#  '(2-chlorophenyl) diphenyl methanol',
#  '(2-Chlorophenyl) diphenyl chloromethane',
#  'title compound',
#  'palladium on carbon',
#  'crude product',
#  'title compound',
#  'title product',
#  'crude product',
#  'title compound',
#  '2,3-Dichloro-N-[5-methyl-3-(3-pyridazinylmethoxy)-2-pyrazinyl]benzenesulphonamide',
#  'TEA',
#  '(6-chloro-pyrimidin-4-yl)-(2,7-dimethyl-1H-benzimidazol-5-yl)-amine',
#  'title compound',
#  'title compound',
#  'compound 5',
#  'mixture',
#  'title compound',
#  'product',
#  'Pd/C',
#  'title compound',
#  'desired product',
#  'EDC',
#  'white solid',
#  'title compound',
#  'water',
#  'NaOH',
#  '2.70',
#  'title compound',
#  'desired compound',
#  'Pd/C',
#  'title compound',
#  'water',
#  'title compound',
#  'acetic acid',
#  'title compound',
#  '10-cyano-2-cyclopentyldecanoic acid',
#  '2-[5-(4-chloro-phenyl)-pyridin-2-ylethynyl]-1-methyl-5-pyrrolidin-1-ylmethyl-1H-benzimidazole',
#  'desired subtitle intermediate',
#  'title compound',
#  'title compound',
#  'water',
#  'title compound',
#  'oil',
#  'title compound',
#  'Compound 354',
#  'Compound 2',
#  'title compound',
#  'CH3OH NH3',
#  'intermediate 19',
#  'intermediate 20',
#  'title compound',
#  'intermediate 25',
#  'product 211',
#  '(3-trifluoromethylbenzyl) methanesulfonate',
#  '1-Amino-3,4-dimethyl-1,3-dihydroimidazol-2-one',
#  'title compound',
#  '(R)—N-(1-(7H-pyrrolo[2,3-d]pyrimidin-4-yl)pyrrolidin-3-yl)-2-chloro-N-methylpyrimidin-4-amine',
#  'title compound',
#  '(3-((tert-butoxycarbonyl)amino)propyl)triphenylphosphonium bromide',
#  'title compound',
#  'Compound 42',
#  'title compound',
#  'desired product',
#  '5-(5-(2,4-Dichlorophenethyl)-1,3,4-thiadiazol-2-yl)-1H-benzo[d]imidazole',
#  "Lawesson's reagent",
#  'water',
#  '5-(4-((1R,2S)-2-amino-3-fluoro-1-hydroxypropyl)-phenyl)picolinonitrile',
#  'title compound',
#  'palladium on activated charcoal',
#  '2-Amino-4-hydroxybutyric acid methyl ester hydrochloride',
#  'hydrogen chloride ethyl acetate',
#  'title compound',
#  '4-(4-Chloro-3-sulfamoylphenyl)-2-(2-furylmethylimino)-3-methyl-1,3-thiazolidine-4-ol-hydrobromide',
#  '3,5-Difluoropyridine-2-carbonyl chloride',
#  'DCM',
#  '187',
#  'ST PM',
#  'title compound',
#  'product',
#  'desired product',
#  'desired product',
#  'palladium on carbon',
#  'Intermediate 5',
#  'title compound',
#  'Water',
#  '(+,-) cis 4-(7-Benzyloxy-3-phenyl-chroman-4-yl)-phenol',
#  '(+,-) cis Methanesulfonic acid 4-(7-benzyloxy-3-phenyl-chroman-4-yl)-phenyl ester',
#  'solid',
#  'title compound',
#  'crude product',
#  'title compound',
#  '2,4-Diamino-5-(2,3-dichlorphenyl)pyrimidine',
#  'N2-[4-(aminomethyl)phenyl]-9-fluoro-5,6-dihydro-4H-benzo-[6,7]cyclohepta[d][1,3]thiazol-2-amine tert-butyl N-(4-aminobenzyl)carbamate',
#  'N-{4-Chloro-3-[3-(trans-4-trifluoromethyl-cyclohexylcarbamoyl)-2-(2,2-difluoro-ethoxy)-6-methylamino-pyridin-5-ylthioureido]benzyl}-2,2-dimethyl-propionamide',
#  'HATU',
#  'title compound',
#  '4-(4-Fluoro-2-methylanilino)-6-methoxy-3-quinolinecarboxamide',
#  'ethanol',
#  'Acetic acid Ethanol',
#  'product',
#  'title compound',
#  'title compound',
#  'water',
#  'title compound',
#  'gum',
#  'water',
#  'title compound',
#  'solid',
#  'title compound',
#  '(10 RS)-10-amino-10-(3-phenylpropyl)-5H,10H-imidazo[1,2-a]indeno[1,2-e]pyrazin-4-one hydrochloride',
#  'hydrochloric acid',
#  '(10 RS)-10-acetamido-10-(3-phenylpropyl)-5H,10H-imidazo[1,2-a]-indeno[1,2-e]pyrazin-4-one',
#  'mixture',
#  'water',
#  'solid',
#  'title compound',
#  '{3-[4-(3-Bromo-phenylamino)-[1,3,5]triazin-2-ylamino]-phenyl)-acetic acid methyl ester',
#  '{3-[4-(3-bromo-phenylamino)-[1,3, 5]triazin-2-ylamino]-phenyl}-acetic acid',
#  'LiOH water',
#  'title compound',
#  'title compound',
#  'bis(triphenylphosphine) palladium (II) chloride',
#  'Copper (I) iodide',
#  'solid',
#  '6-Chloro-3-(pyrimidin-5-ylamino)-pyridine-2-carboxylic acid (1-methyl-5-methylcarbamoyl-1H-pyrazol-4-yl)-amide',
#  'tert-Butyl 4-(1-hexyl-4-hydroxy-2-oxo-1,2-dihydroquinoline-3-carboxamido)benzoate',
#  'Cyclopropanecarboxylic acid {5-[4-(2-diethylamino-ethylamino)-phenyl]-[1,2,4]triazolo[1,5-a]pyridin-2-yl}-amide',
#  'Pd/C',
#  'water',
#  'Pt(S)/C',
#  'NMP',
#  '3-[6′-chloro-4′-(3,4-dimethyl-2-oxo-2,3-dihydro-benzoxazole-6-carbonyl)-3,4,5,6-tetrahydro-2H-[1,2′]bipyridinyl-4-yl]-7-methoxy-1,3,4,5-tetrahydro-benzo[d][1,3]diazepin-2-one',
#  'desired product',
#  '1,2-diamino-3-cyano-4-benzylamino-6-(2,6-dimethylmorpholin-4-yl)quinolinium tosylate',
#  'solid',
#  'title compound',
#  'product',
#  'Compound 34',
#  'desired compound',
#  'Pd/C',
#  'product',
#  'oil',
#  'solid',
#  'title compound',
#  'Pd/C',
#  'title compound',
#  'catalyst',
#  'water',
#  'water',
#  'hydrogen chloride ethyl acetate',
#  'title compound',
#  'solid',
#  'title compound',
#  'title compound',
#  'trifluoroacetic acid dichloromethane',
#  'title compound',
#  'solid',
#  'title compound',
#  'expected product',
#  "Lawesson's reagent",
#  'title compound',
#  '4-(2,4-Dimethoxy-benzyl)-7-methylsulfanyl-3,4-dihydro-1H-benzo[e][1,4]diazepine-2,5-dione',
#  '7C',
#  'hydrogen chloride salts',
#  'water',
#  'title compound',
#  '6-chloro-3-methylquinolin-2(1H)-one-4-carbonyl chloride',
#  'EtOAc EtOH',
#  'Pd/C',
#  'title compound',
#  'title compound',
#  'Methyl 5′-(difluoromethyl)-2-(2,2-dimethylcyclopentyl)-2′-fluoro-1,1′-biphenyl-4-carboxylate',
#  '66.50B',
#  'MeOH',
#  'title compound',
#  'product',
#  'ethyl acetate ethanol',
#  'title compound',
#  'DCM',
#  'title compound',
#  '1,1-Dimethylethyl 3-[5-(5-{3-cyano-4-[(1-methylethyl)oxy]phenyl}-1,2,4-oxadiazol-3-yl)-1-isoquinolinyl]propanoate',
#  'ethyl 4-carboxymethylsulfenyl-2-chlorobenzoate',
#  '3-(4-butylthio-1,2,5-thiadiazol-3-yl)-1-methylpyridinium iodide',
#  'sodium hydroxide',
#  'title compound',
#  '(S)—N-[1-(3-Bromophenyl)ethyl]Acetamide',
#  '3-aminopyridine',
#  'title compound',
#  '2-Isopropylsulfanyl-2-methyl-propionic acid ethyl ester',
#  'title compound',
#  'yellow solid',
#  '3-[(S)-1-(4-cyano-phenyl)-pyrrolidin-3-yloxy]-benzoic acid',
#  'desired product',
#  'HOBT',
#  'EDC',
#  'product',
#  'TFA',
#  '5-amino-3-(1-ethylpiperidin-4-yl)pyrrolo[3,2-b]pyridine',
#  'title compound',
#  'title compound',
#  'Hydrochloric acid',
#  'water',
#  'product',
#  'EtOAc EtOH',
#  'title compound',
#  'expected product',
#  'palladium on charcoal',
#  '2-((R)-4-[1,3′]Bipyrrolidinyl-1′-yl-3-fluorophenyl)-6-((Z)-pent-1-enyl)-2H-isoquinolin-1-one',
#  '6-Amidino-2-naphthyl 5-(4-carboxybutyrylaminomethyl)furan-2-carboxylate hydrochloride',
#  'title compound',
#  'water',
#  'title compound',
#  '2-Cyclopentyl-5-ethyl-7-(2-methylcyclopropyl)imidazo[5,1-f][1,2,4]triazin-4(3H)-one',
#  'trans-4-trifluoromethylcyclohexyl trans-4-pentylcyclohexanecarboxylate',
#  'palladium-charcoal',
#  'desired product',
#  '7-(1-Benzoyl-4-piperidinyl)-5-ethyl-2-phenylimidazo[5,1-f][1,2,4]triazin-4(3H)-one',
#  'platinum (IV) oxide',
#  'title compound',
#  'title compound',
#  'title compound',
#  'xylene',
#  'solid',
#  'white solid',
#  'Ethyl 3-amino-2-chloro-4-methyl-2-pentenoate',
#  'title compound',
#  "Lawesson's reagent",
#  'title compound',
#  'title compound',
#  '3-Benzyl-2,5-dioxoimidazolidine 1-pentylcarboxamide',
#  'title compound',
#  'HCl EtOAc',
#  'title compound',
#  'water',
#  'title compound',
#  'title compound',
#  'product',
#  'solid',
#  'title compound',
#  'diisobutylaluminum hydride toluene',
#  '( 51 )',
#  'CO3',
#  'target product',
#  'desired product',
#  'title compound',
#  '4-({3-(4-Ethylphenyl)-5-[3-(3-methoxyphenyl)-1,2,4-oxadiazol-5-yl]piperidin-1-yl}carbonyl)-morpholine',
#  'water',
#  'title compound',
#  'product',
#  'yellow solid',
#  'title compound',
#  'desired product',
#  '4-chlorobutyronitrile',
#  'title compound',
#  'compound 2',
#  'Compound 5',
#  'water',
#  'tetrahydro- 1-(5-t-butyl-1,3,4-thiadiazol-2-yl)-3-methyl-6-[α-(3,5 -dinitrophenyl)acetyloxy] -2 (1H)-pyrimidinone',
#  'hydrochloric acid 1,4-dioxane',
#  '2-bromo-[1,2,4]triazolo[1,5-a]pyridin-7-amine hydrochloride',
#  '8-azabicyclo[3.2.1]octan-3-one hydrochloride salt',
#  'p-tert-butoxystyrene styrene',
#  'title compound',
#  'palladium on charcoal',
#  'title compound',
#  'crude title compound',
#  'product',
#  '(R)—N-tert-butoxycarbonyl-pyrrolidin-3-carboxylic acid hydrazide',
#  'title compound',
#  'solid',
#  'title compound',
#  'title compound',
#  'product',
#  'title compound',
#  'title compound',
#  'Pd/C',
#  'title compound',
#  'title compound',
#  'title compound',
#  'title compound',
#  'title compound 7',
#  'MTBE acetone water',
#  'title compound',
#  'solid',
#  'title compound',
#  'desired product',
#  'N-{1-[3-(3-Nitrophenyl)-5-oxo-4,5-dihydro-1,2,4-triazin-6-yl]propyl}cyclopentanecarboxamide',
#  'HCl',
#  'water',
#  'title compound',
#  '( 15 )',
#  'residue',
#  'water',
#  'title compound',
#  'title compound',
#  'NBS',
#  'title compound',
#  'title compound 158',
#  'compound 125',
#  '6-methoxymethyl-5-methyl-2-chloro4-(1-methyl-1,2,3,4-tetrahydroisoquinolin-2-yl)pyrimidine',
#  '2-methyl-4-fluoroaniline',
#  'titled compound',
#  'dimethylformamide',
#  'title compound',
#  'water',
#  'title compound',
#  'title compound',
#  'water',
#  'title compound',
#  'solid',
#  'title compound',
#  'title compound',
#  'hydrogen chloride acetic acid',
#  'title compound',
#  'TFA DCM MeOH',
#  'desired product',
#  'title compound',
#  '1-Benzyl-3-dimethylaminomethyl-3-hydroxypyrrolidine',
#  'title compound',
#  'target compound',
#  '10',
#  'DMSO dioxane',
#  'desired compound',
#  'title compound',
#  'solid',
#  'ODSA',
#  'title compound',
#  'water',
#  '2,4-Dichloro-N-[6-(4-chloro-benzyloxymethyl)-pyridin-2-yl]-6-methyl-benzenesulfonamide',
#  'title compound',
#  'solid',
#  'title compound',
#  '2-({(2-(4-Chlorophenyl)-1,3-thiazol-4-yl)methyl}sulfanyl)-6-((2,2-difluoroethyl)amino)-4-(4-(2-hydroxyethoxy)phenyl)pyridine-3,5-dicarbonitrile',
#  'desired product',
#  'water',
#  'suspension',
#  "N,N'-bis[2,4,6-triiodo-3,5-bis(2,3-dihydroxypropylaminocarbonvl)phenyl]-N-hydroxyethyl-urea",
#  'water',
#  'powder',
#  '6-(3-Nitro-phenyl)4-methyl-3,4-dihydro-1H-quinoxalin-2-one',
#  '5-(4-Hydroxy-3-methoxyphenyl)-penta-2E,4E-dienoic acid 3,4-dihydroxybenzylamide',
#  'title compound',
#  '2-ethyl-N,N′-bis(3-hydroxyphenyl)pyrimidine-4,6-diamine',
#  'ether',
#  'title compound',
#  'compound 5e',
#  'TMSBr',
#  'compound 57c',
#  'title compound',
#  'product',
#  'HCl',
#  'title compound',
#  'compound',
#  '2-Iodo-5-Nitrobenzoic Acid',
#  '3',
#  'ice',
#  'title compound',
#  'title compound',
#  ...]

# %%
cde_exclusive_finds
# Out:
# ['SULF-8',
#  'Nujol',
#  'DMSO-d6',
#  'nitrogen',
#  '1H',
#  'bromide-diethyl ether',
#  'ethylmagnesium',
#  '2H',
#  '1H',
#  'glacial acetic acid',
#  '1H',
#  'phenethyl ester',
#  'dichloromethane',
#  'Pd / C',
#  '2H, ( α -- CH2 )',
#  'CH2',
#  'Celite',
#  'COOH',
#  'hydrogen',
#  '1H',
#  'd6-DMSO',
#  '1H',
#  'C26H32FN4O4S',
#  'silica gel',
#  'CDCl3',
#  '1H',
#  'C17H21FN6O',
#  'DMSO-d6',
#  'C27H26ClF3N4O',
#  '2H',
#  'CD3OD',
#  '1H',
#  'C13H20SO2',
#  'H',
#  'Pd',
#  '1H',
#  'C21H21ClNO3',
#  'palladium',
#  'Kieselguhr',
#  'AP+',
#  'charcoal',
#  'C11H22N2O3',
#  'CCl4',
#  'C9H10F8O4C',
#  'H',
#  '5-bromo-2-formylfuran',
#  'hexylboronic acid',
#  'EtOAc',
#  '1H',
#  'Hex',
#  "5'-OH",
#  'N',
#  'DMSO-d6',
#  'CH2',
#  'NH',
#  'OCH2',
#  "3'-OH",
#  'C19H29N5O6',
#  'CH3',
#  'H',
#  'OCH3',
#  'argon',
#  'H2',
#  'HCl',
#  'D2O',
#  '1H',
#  'carbon',
#  'palladium',
#  'CH2Cl2',
#  'EtOAc',
#  'MeOH',
#  'Pd / C',
#  '1H',
#  '1 N hydrochloric acid',
#  'DMSO-d6',
#  'H',
#  '1H',
#  'DMSO-d6',
#  'DMSO-d6',
#  '2H',
#  '1H',
#  '— NH',
#  'methanol',
#  'hydrogen chloride',
#  '3 / 2oxalate',
#  '2H',
#  'CDCl3',
#  '1H',
#  'benzene',
#  'hydrochloride',
#  'N hydrochloric acid',
#  '1,4-dioxane',
#  'MgSO4',
#  'DMF',
#  '1-methylcyclopropane-1-sulfonyl chloride',
#  '2H',
#  'thionyl chloride',
#  'Silica gel',
#  'argon',
#  'iodide 534',
#  'palladium',
#  'DMSO-d6',
#  'carbon',
#  'hydrogen',
#  '1H',
#  'Argon',
#  'HMDSO',
#  '2H',
#  '1H',
#  'DMSO-d6',
#  'ethanol-hexane',
#  'ester',
#  '2-chloroethanethiol',
#  'sodium',
#  '5,6-dihydro-3-(4-pyridinyl)-1,4,2-oxathiazine',
#  'N',
#  '2-chloroethyl N-hydroxy-4-pyridinecarboximidothioate',
#  'ethanol',
#  'sodium ethoxide',
#  'C8H8N2OS',
#  'triethylamine',
#  'ether',
#  'H',
#  '2H',
#  'CDCl3',
#  '1H',
#  'silver ( I ) oxide',
#  'CH2Cl2',
#  'MeOH',
#  'silica gel',
#  'Celite',
#  '6N HCl',
#  'n-hexane',
#  'silica gel',
#  'ethyl acetate',
#  '( S )—N-(3-(4-amino-6-((1-(5-methyl-4-oxo-3-phenyl-3,4-dihydropyrrolo[2,1-f][1,2,4]triazin-2-yl)ethyl)amino)pyrimidin-5-yl)-5-hydroxyphenyl)-4-methoxybenzenesulfonamide',
#  'methanol',
#  'DMSO-d6',
#  'dichloromethane',
#  'silica gel',
#  '1H',
#  'CDCl3',
#  'methanol',
#  "Lawesson 's Reagent",
#  'hexane',
#  '4-keto-4,5,6,7-tetrahydrothianaphthene',
#  'silica gel',
#  'cyclohexane',
#  'nitrogen',
#  'CD3OD',
#  'CHCl3-Acetone',
#  'silica gel',
#  '2H',
#  '1H',
#  'CH3CN',
#  'TFA',
#  'Hg',
#  'N NaoH',
#  'isopropyl alcohol ( 1 l )',
#  'Bp',
#  '2H',
#  'CDCl3',
#  '1H',
#  'SiO2',
#  'silica',
#  'ethyl acetate',
#  'toluene',
#  'TEA',
#  'phosgene',
#  '[ 1-[3-(3-pyridinyl)-propyl)-4-(3-pyridinyl)butyl]carbamic acid 1,1-dimethylethyl ester',
#  '1N HCl',
#  'carbon',
#  'palladium',
#  '(S)-omeprazole.2[(S)-1,1,2-triphenyl-1,2-ethanediol]',
#  'silica gel',
#  'CDCl3',
#  'dry benzene',
#  'Pd / C',
#  'DMF',
#  'Celite',
#  'MeOH',
#  'diethyl ether',
#  'EtOH',
#  'Hex',
#  'EtOAc',
#  'N2',
#  'silica',
#  'N HCl',
#  'dioxane',
#  'HCl',
#  'nitrogen',
#  'ethanol',
#  'hydrochloric acid',
#  'ethyl acetate',
#  'DL-proline',
#  'manganese ( IV ) oxide',
#  '2H',
#  'CDCl3',
#  '1H',
#  '[C22H19N3O4+H]+',
#  'DMSO-d6',
#  'NH',
#  '2H',
#  '1H',
#  'dichloromethane',
#  '1N NaOH',
#  '1N HCl',
#  'N sodium hydroxide',
#  'hydrogen',
#  '2-(3′-Chloro-4′-fluoro-biphenyl-3-yl)-1-(R)-(3-methyl-[1,2,4]oxadiazol-5-yl)-ethylamine hydrochloride',
#  '[2-(3′-Chloro-4′-fluoro-biphenyl-3-yl)-1-(R)-(3-methyl-[1,2,4]oxadiazol-5-yl)-ethyl]-carbamic acid tert-butylester',
#  '2H',
#  'CDCl3',
#  '1H',
#  "Lawesson 's reagent",
#  'ethanol',
#  'C-N',
#  '6N-HCl',
#  'hydrogen',
#  'carbon',
#  'palladium',
#  'nitrogen',
#  'diethyl ether',
#  'silica gel',
#  'EtOH',
#  'silica gel',
#  'CHCl3',
#  'methanolisopropanol',
#  'hexane',
#  '— C═O',
#  '2H',
#  'CDCl3',
#  '1H-NMR',
#  'silica gel',
#  'dichloromethane',
#  'hexane',
#  '1 : 4 ethyl acetate',
#  'dichloromethane',
#  'silica gel',
#  'silica gel',
#  'chlorine gas',
#  'silica gel',
#  'M+H',
#  'N2',
#  'Ethyl acetate',
#  'hydrochloric acid',
#  '4-amino-piperidine-4-carboxylic amide 2TFA',
#  'methanol',
#  'methanol',
#  'dichloromethane',
#  'Pd / C',
#  'argon',
#  'hydrogen',
#  '2H',
#  'CDCl3',
#  '1H',
#  'N hydrochloric acid',
#  '1H',
#  'CDCl3',
#  '2H',
#  'EtOAc',
#  'H2O',
#  'Et2O / hexanes',
#  'CDCl3',
#  '1H',
#  'silica gel',
#  'hexane',
#  'ethyl acetate',
#  '3 H',
#  'H',
#  '1H',
#  'DMSO-d6',
#  '2H',
#  'CDCl3',
#  '1H',
#  'SiO2',
#  'Amine-8',
#  'dry potassium carbonate',
#  'H',
#  'MeOD',
#  '1H',
#  'H',
#  '1H-NMR',
#  'charcoal',
#  'yellow precipitate',
#  'MeOH',
#  'SiO2',
#  '9-carbamoyl-9-(3-oxo-propyl)fluorene',
#  'silica gel',
#  'EtOAc',
#  'hexanes',
#  'dihydrochloride',
#  'dimethylacetal',
#  'dimethylformamide',
#  'Combine 4-methyl-2-(2-nitro-phenylamino)-benzonitrile',
#  '5N HCl',
#  '1H',
#  '[(M+H)+] 432',
#  'METHANOL-d4',
#  'toluene',
#  'nitrogen',
#  'Celite',
#  'carbon',
#  'palladium',
#  '2H',
#  'd6-DMSO',
#  '1H',
#  'nitrogen',
#  'M+H',
#  'hexanes',
#  'hexane',
#  '2H',
#  '1H',
#  'ethyl acetate',
#  'CDCl3',
#  'silica gel',
#  'Chromatograph',
#  '2H',
#  '1H',
#  '4-methoxybenzoic acid',
#  '6-aminohexyl ester',
#  'DMSO-d6',
#  '2H',
#  '1H',
#  'methanol',
#  'silica gel',
#  '1,2-dichloroethane',
#  'isopropanol',
#  'CHCl3',
#  'IV-18',
#  'silica gel',
#  'Zinc powder',
#  'methanol',
#  'silicagel',
#  'methylene chloride',
#  'hydrochloride salt of 5,6-dihydro-6-(4-nitrophenyl)-5-oxo-pyrido[2′,1′:2,3]imidazo[4,5-c]isoquinolin-9-carboxylic acid',
#  '(3S,4R):(3S,4S)',
#  'Celite',
#  'hydrogen',
#  '3-Thiophenehexanol',
#  'carbon',
#  'palladium',
#  'Hg',
#  'Celite',
#  'carbon',
#  'Et2O',
#  '2-morpholin-4-yl-5-(5H-pyrrolo[2,1-c][1,4]benzodiazepin-10(11H)-ylcarbonyl)benzenesulfonamide of Step B',
#  'dry 1,4-dioxane',
#  "Lawesson 's Reagent",
#  'ethyl acetate',
#  '4-(4′-(4″-hydroxyphenyl)cyclohexyl)-2,6-dimethyl-1-hydroxybenzene',
#  'hexane',
#  'EtOAc',
#  '2H',
#  'CDCl3',
#  '1H',
#  'C35H38N2O6',
#  'M+H',
#  'hydrochloride',
#  'ester CH3',
#  '1H',
#  'palladium',
#  'DMSO-d6',
#  'ester CH2',
#  'CH2',
#  'Ar',
#  'carbon',
#  'C22H35NO3.1 / 20 H2O',
#  '2H',
#  'NH2',
#  'hydrogen',
#  'H',
#  "ester CH2's",
#  'benzoate',
#  'butylamine',
#  'isopropanol',
#  'benzoic acid',
#  'Step B',
#  'nitrogen',
#  'methoxyphenylmagnesiumbromide',
#  'Hexane',
#  'CDCl3',
#  '1H',
#  'nitrogen',
#  'toluene',
#  'charcoal',
#  'palladium',
#  '1N HCl',
#  'hydrochloride',
#  'M+H',
#  '1H',
#  'CD3OD',
#  'M+H',
#  'carbon',
#  'silica gel',
#  'C22H19NO2F9',
#  '1H',
#  '3 H',
#  'MeOH',
#  'H',
#  '2 H',
#  '2H',
#  '1H',
#  'DMSO-d6',
#  '1 H',
#  'MeOD',
#  'H',
#  '1H-NMR',
#  'dibromide',
#  'MeOH',
#  '2H',
#  '1H',
#  'DMSO-d6',
#  'glycidyl methacrylate',
#  'benzyltriethylammonium chloride',
#  'Pd-carbon',
#  'NH4OAc',
#  '2H',
#  'D2O',
#  '1H',
#  'heptane',
#  'CDCl3',
#  'Nitrogen',
#  '1H',
#  'rhodium acetate',
#  'silica gel',
#  'nitrogen',
#  '[5267-39-0]',
#  'cyclohexane',
#  'SiO2',
#  'ethyl acetate',
#  'DMSO-d6',
#  'MeOH',
#  '2H',
#  '1H NMR',
#  '1H',
#  '6N hydrochloric acid',
#  'bishydrochloride',
#  'HCl-saturated ether',
#  'diisopropyl ether',
#  'methanol',
#  'C19H23N3.1.2C4H4O4.0.3H2O',
#  'MeOH-d4',
#  '1H',
#  'ethyl acetate',
#  'N',
#  'NH3',
#  'DCl',
#  'H',
#  'diethyl ether',
#  'ether',
#  'carbon',
#  'palladium',
#  'nitrogen',
#  'nitrogen',
#  'ethyl acetate-hexane',
#  'silica gel',
#  'silica gel',
#  'cyclohexane',
#  "Lawesson 's reagent",
#  'methanol',
#  '2369-19-9',
#  '143-33-9',
#  "4-difluoromethoxy-pyrazolidine-N,N'-dicarboxylic acid di-tert-butyl ester",
#  '1H',
#  'C13H18O3 : C',
#  'H',
#  'N3—H',
#  'ethyl acetate',
#  'chloroform',
#  'argon',
#  '1H-NMR',
#  'DMSO-d6',
#  '6-CH2',
#  'CH3CO',
#  '2-CH2',
#  '1H',
#  'Step B',
#  'ammonium cerium ( IV ) nitrate',
#  'cresylic acid',
#  'phenol',
#  "p,p ' diphenyl methane diisocyanate",
#  'C22H16BrN3O2',
#  '2H',
#  'CDCl3',
#  '1H',
#  'MeOH',
#  'TFA',
#  'H2O',
#  '2H',
#  'NH3',
#  '1H',
#  'methanol-d4',
#  'cyclopropylmagnesium',
#  'bromide',
#  'THF',
#  'silica gel',
#  'ethyl acetate',
#  '3 H',
#  'CDCl3',
#  'hexane',
#  'silica',
#  'H',
#  '1H',
#  'Pd / C',
#  'MeOH',
#  'toluene',
#  'N2',
#  'H2O',
#  '2H',
#  '1H',
#  'DMSO-d6',
#  'charcoal',
#  'palladium',
#  'EtOAc-heptane',
#  '[440083-74-9]',
#  '2H',
#  'Et2O',
#  '1H',
#  'DMSO-d6',
#  'silica gel',
#  'Chromatograph',
#  'MeOH',
#  'argon',
#  'silica gel',
#  'ammonium hydroxide',
#  'DMDO-d6',
#  '1H',
#  'silica gel',
#  'methylene chloride',
#  'N HC1',
#  'polyamidoamine',
#  'sodium bromide',
#  'isopropyl alcohol',
#  'hydrobromide',
#  'hexane',
#  'N',
#  'monohydrate',
#  'C29H31N3O2H2O HBr',
#  'H',
#  '2,4-DCBTC',
#  'C-4',
#  'silica gel',
#  'hexane',
#  'ethyl acetate',
#  'ethyl acetate',
#  'argon',
#  'dichloromethane',
#  'silica',
#  'nitrogen',
#  '5-(N-methyl-thiocarbamoyl)-4,5,6,7-tetrahydro-imidazo-[4,5-c]-pyridine',
#  'white precipitate',
#  'hydrochloric acid',
#  'M+H',
#  'dry methanol',
#  'silica gel',
#  '( 2R, 5S)-(5-chloro-2-{2-[4-(4-fluoro-benzyl)-2,5-dimethyl-piperazin-1-yl]-2-oxo-ethoxy}-phenyl)-carbamic acid 4-nitro-phenyl ester',
#  'dichloromethane:methanol',
#  'silica',
#  'N-aminopyrrolidine HCl',
#  'Pd / C',
#  'hydrogen',
#  'nitrogen',
#  '- red filtrate',
#  '1H',
#  'pentane',
#  '9H aromatic+1H ethylenic',
#  '2H',
#  '1H',
#  '2-[(2-aminoethyl)thiomethyl]-3-chloropyridine',
#  'H2',
#  'Pd(OH)2 / C',
#  'SOCl2',
#  '1H',
#  '2H',
#  '1H',
#  'DMSO-d6',
#  'EtOAc',
#  '4-(4-chlorophenyl)-6-isothiocyanatopyrimidine',
#  'ethyl acetate-hexanes',
#  'dichloromethane',
#  'silica gel',
#  'N,N-dimethylformamide',
#  'hydrogen bromide-ethanol',
#  '3H, 3 × CH',
#  '12H',
#  'CH',
#  'Et2O',
#  '1H-NMR',
#  'CH2',
#  '2H',
#  'CH3',
#  '1H',
#  'ethyl 2-(7-amino-9-benzyl-3-oxa-9-azabicyclo[3.3.1]nonan-7-yl)acetate 146c',
#  'silica gel',
#  'hexanes',
#  'Pd / C',
#  'H2',
#  '2H',
#  '160(M+H+)',
#  '1H',
#  'DCM',
#  'tert-Butyl-methyl ether',
#  'MeOH',
#  'hydrogen',
#  'carbon',
#  'palladium',
#  '( 4-bromo-2-fluorophenyl ) [4-(3,5,6-trimethylpyridin-2-yl)piperazin-1-yl]methanone',
#  'dichloromethane',
#  'MeOH',
#  'diethyl ether',
#  'SiO2',
#  'dry benzene',
#  'Pd',
#  'bis(diphenylphosphino)ferrocene-palladium(II)dichloride dichloromethane',
#  'methanol',
#  '(1S,5R,6S)-6-((1R)-1-hydroxyethyl)-1-methyl-2-[5-methylthio-7-(pyridin-3-yl)carbonylimidazo[5,1-b]thiazol-2-yl]-1-carbapen-2-em-3-carboxylate',
#  '4-nitrobenzyl',
#  'ethanol',
#  '2H',
#  'CDCl3',
#  '1H',
#  'N-[3-(dimethylamino)propyl]methacrylamide',
#  'methylhydroquinone',
#  'diethyl ether',
#  'white precipitate',
#  'trimethylchlorosilane',
#  '3-(S)-amino-1-ethoxycarbonylmethyl-2,3,4,5-tetrahydro-1H-[1]benzazepin-2-one tartrate',
#  'magnesium sulfate',
#  'methylene chloride',
#  'ammonium hydroxide',
#  '3-(S)-amino-1-ethoxycarbonylmethyl-2,3,4,5-tetrahydro-1H -[1]benzazepin-2-one',
#  'H2O',
#  'CD3OD',
#  '1H',
#  'charcoal',
#  'hydrogen',
#  'palladium',
#  'Pd / C',
#  'HCl',
#  'DMSO − d6 +d4-acetic acid',
#  '2H',
#  'ether',
#  'hydrogen',
#  'Ethereal',
#  'hydrochloric acid',
#  'H2',
#  'methyl isothiocyanate',
#  'cysteamine hydrochloride',
#  'ethanol-ether',
#  'thiourea',
#  'chloroform',
#  'isopropyl acetate',
#  'sodium hydroxide',
#  'ethanol',
#  'acetonitrile',
#  'amine',
#  'ether',
#  "N-methyl-N'-[2-((4-bromo-3-isothiazolyl)methylthio)ethyl]thiourea",
#  'nitrogen',
#  'dry dichloromethane',
#  'Pd / C',
#  'hydrogen',
#  'diethyl ether',
#  '2H',
#  'DMSO',
#  '1H',
#  'diethyl ether',
#  'argon',
#  'dibenzyl',
#  'N-(N-tert-butoxycarbonyl-L-valyl)-L-glutamate',
#  'C19H24N6O',
#  'H',
#  'N',
#  'H2 gas',
#  'Celite',
#  'n-hexane',
#  'EtOAc',
#  'benzoate',
#  'butylamine',
#  'isopropanol',
#  'benzoic acid',
#  'Step B',
#  'H2',
#  'Ar',
#  'AcOH',
#  'Celite',
#  'EtOH',
#  '(2-{[4-chloro-3-(6-chloro-4-methyl-pyridin-3-yl)-benzoyl]-methyl-amino}-phenoxy)-acetic acid methyl ester 3-1',
#  'toluene',
#  'Benzyloxycarbonyl chloride',
#  'chloroform',
#  'sodium hydroxide',
#  '(R)-3-azido-4-(1-benzyloxycarbonylaminoethyl)benzoic acid',
#  'silica gel',
#  '2N hydrochloric acid',
#  'chloroform:methanol',
#  'Step A',
#  'argon',
#  'paradium carbon',
#  'Celite',
#  'hydrogen',
#  'EtOAc-heptane',
#  'CDCl3',
#  '1H',
#  'H2O—CH3CN',
#  'formic acid',
#  'HCl',
#  'TFA',
#  'CH3CN',
#  'H2O',
#  'acetonitrile',
#  '2H',
#  'CDCl3',
#  '1H',
#  '1H-NMR',
#  'ethyl acetate',
#  'CDCl3',
#  'silica gel',
#  'nitrogen',
#  '2H',
#  '1H',
#  '[(M+H)+]',
#  'phytocassane',
#  'ethyl acetate',
#  'Pd / C',
#  'H2',
#  '2,6,6-trimethyl-1-cyclohexenyl methyl ketone',
#  '2,6,6-trimethyl-2-cyclohexenyl methyl ketone',
#  'methylmagnesium bromide-diethyl ether',
#  'THF',
#  'EtOAc',
#  'hydrogenated tallowaminopropyl D-gluconamide',
#  'isopropanol',
#  'DMF',
#  'methylene chloride',
#  'M+H',
#  '1 hexane-EtOAc',
#  'Step H',
#  'N2',
#  'silica gel',
#  'hexane-EtOAc',
#  'CDCl3',
#  '1H',
#  'hydrochloride',
#  "Lawesson 's reagent",
#  'dioxane',
#  '4N HCl',
#  'hydrochloride',
#  'palladium',
#  'argon',
#  'carbon',
#  'Step B',
#  'Celite',
#  'ethyl acetate-hexane',
#  'hydrogen',
#  'N HCl',
#  'SDA',
#  'Pd / C',
#  'acetate',
#  'nitrogen',
#  'methyl methacrylate, 10 g of butyl acrylate',
#  'Pd / C',
#  'ethyl 1-ethoxycarbonyl-3-(diethylphosphonomethyl)-pyrrolidine-2-carboxylate',
#  'hydrogen',
#  'carbon',
#  'palladium',
#  'MeOH',
#  'secondary amine',
#  '8-[2-(3-fluoro-4-trifluoromethyl-phenyl)-ethyl]-1-iodo-3-methyl-5,6-dihydro-8H-imidazo[1,5-a]pyrazine-7-carboxylic acid tert-butyl ester',
#  'Pd',
#  'THF',
#  'carbon',
#  'Celite',
#  'H',
#  'EtOH',
#  "Meldrum 's acid",
#  'ethyl acetate',
#  'CH2Cl2',
#  'silica gel',
#  'MeOH',
#  '( 1S,2S )—N,N′-dimethylcyclohexane-1,2-diamine',
#  'dichloromethane',
#  'ethanol',
#  'silica gel',
#  'S-(4-aminophenyl)-N-(2-methoxy-ethyl)-S-methylsulphoximide',
#  '1H rotomer',
#  'C16H13BrN2O2S3',
#  'M+H',
#  'DMSO-d6',
#  '1H',
#  'acetone',
#  'ether',
#  'N-cyclohexyl-sulphamate',
#  'butylamine',
#  'diisopropyl ether',
#  'DMSO-d6',
#  '2H',
#  "Lawesson 's Reagent",
#  '1H',
#  'silica gel',
#  'ethyl acetate',
#  'EtOAc',
#  'silica gel',
#  '1Cl',
#  'Pd',
#  '3-(4-isopropoxyphenyl)-2-methyl-5-{[2′-(5-oxo-4,5-dihydro-1,2,4-oxadiazol-3-yl)biphenyl-4-yl]methyl}-6-propylpyrimidin-4(3H)-one sodium',
#  'argon',
#  '1H-NMR',
#  '1H',
#  'DMSO-d6',
#  'white crystal',
#  'methanol',
#  'dichloromethane',
#  'silica gel',
#  'H2',
#  'Pd',
#  'SiO2',
#  'hexane',
#  'N',
#  'H',
#  'C15H13NO',
#  'dimethylacetal',
#  '2-chloro-5-trifluoromethylpyridine',
#  'dimethylformamide',
#  'potassium carbonate',
#  'ethanol',
#  'silica',
#  'NH4OH',
#  'H2O',
#  'H2SO4',
#  'n-hexane',
#  'EtOAc',
#  'H2O',
#  '3-nitrobenzenesulfonic acid sodium',
#  'dichloromethane',
#  'C26H31NO3S',
#  'silica gel',
#  'dry toluene',
#  'silica gel',
#  'Cryptophycin 37',
#  'dry acetone',
#  '1H',
#  'DMSO-d6',
#  'potassium carbonate',
#  'Pd / C',
#  'hydrogen',
#  'toluene',
#  'dichloromethane',
#  'TFA',
#  'trifluoroacetic acid',
#  '(4S)-2-oxo-3-{[(phenylmethyl)oxy]carbonyl}-4-imidazolidinecarboxylic acid',
#  'silica gel',
#  'M+H',
#  'C22H16N3O2Cl(M+)',
#  '2H',
#  'CDCl3',
#  '1H',
#  '2-methyl phenylacetic acid',
#  'nitrogen',
#  '1 / 2 l of',
#  'butylate',
#  'potassium',
#  'diethyl ether',
#  '1H',
#  'DMSO-d6',
#  'Celite',
#  'trihydrochloride',
#  '( 2-Chlorophenyl ) diphenyl chloromethane',
#  '2-chlorophenyl',
#  'diphenyl methanol',
#  'Appendix A',
#  '3 H',
#  'DMSO-d6',
#  'nitrogen',
#  'H',
#  '1H',
#  'hydrogen',
#  'carbon',
#  'palladium',
#  '(CD3)2SO',
#  '1H',
#  'methanol',
#  'Ph',
#  '1H',
#  'Me',
#  'tetralone',
#  'dry ether',
#  'CH2Cl2',
#  'sodium sulfate',
#  'tetrahydronaphthalen-1-ol',
#  'hexane',
#  'dry nitrogen',
#  'nitrogen',
#  'ethanol',
#  '3-[[[[[[3,5-bis(trifluoromethyl)phenyl]amino]-carbonyl]amino]sulfonyl]amino]-N-(3,4-difluorophenyl)-4-methoxy-',
#  'ethyl 3-(5-amino-3-(2-fluorophenyl)-1H-pyrazol-1-yl)benzoate',
#  'DMSO-d6',
#  'TBSCl',
#  '2H',
#  '1H',
#  'methanol',
#  'ammonium hydroxide',
#  'trifluoroacetate',
#  'silica gel',
#  'acetonitrile',
#  'DMSO-D6',
#  '2H',
#  '1H',
#  '1-(3′-(2″-methylimidazolinyl)propyl}urea',
#  'dipropylene glycol',
#  'Pd / C',
#  'H2',
#  'acetoxy',
#  'hexane',
#  'ethyl acetate',
#  'hydrochloric acid',
#  '2N NaOH',
#  'Pd / C',
#  'Celite',
#  'CDCl3',
#  '1H',
#  'N',
#  '2-propanol',
#  'glacial acetic acid',
#  'carbon',
#  'H',
#  '2H',
#  '-CH2CH2',
#  'CDCl3',
#  '4H',
#  '22H',
#  'DeGussa',
#  'CDCl3',
#  'H2O',
#  '2H',
#  'Celite',
#  '1H',
#  '1H',
#  'silica gel',
#  '4-chloro-3-nitrobenzenesulphonyl chloride',
#  'sodium sulphite',
#  'hexane',
#  'ethyl acetate',
#  'H2O',
#  'N2',
#  'DMSO',
#  'silica gel',
#  '2H',
#  'EtOAc',
#  '1H',
#  'EtOH',
#  'Et2O',
#  'CDCl3',
#  '1H',
#  'diisopropyl ether',
#  'CH3OH',
#  'NH3',
#  'toluene',
#  '1H',
#  'CDCl3',
#  '2H',
#  'Et2O',
#  '( 3-trifluoromethylbenzyl ) methanesulfonate',
#  'silica gel',
#  'pyridine-3-carbaldehyde hydrazone',
#  'THF',
#  '( R )—N-(1-(7H-pyrrolo[2,3-d]pyrimidin-4-yl)pyrrolidin-3-yl)-2-chloro-N-methylpyrimidin-4-amine',
#  'silica gel',
#  '14H',
#  'THF : m / z 442 [ M − H]−',
#  'DMSO-d6',
#  '2H',
#  'AAA-044',
#  '1H',
#  'methanol',
#  'silica',
#  'methylene chloride',
#  '1,4-dioxane',
#  'CHCl3',
#  "Lawesson 's reagent",
#  'charcoal',
#  'palladium',
#  '[C5H11NO3+H]+',
#  'CD3OD',
#  '1H',
#  '4N hydrogen chloride',
#  'ethyl acetate',
#  'diethyl ether',
#  'toluene',
#  'chloroform',
#  'toluene',
#  'methanol',
#  'nitrogen',
#  'chloroform-hexane',
#  'ethyl acetate',
#  'magnesium sulfate',
#  'sodium hydrogencarbonate',
#  'hexane',
#  'silica gel',
#  ...]
